# %% [markdown]
# # Spike Plotting

# %% [markdown]
# Brief 1-2 sentence description of notebook.

# %%
import glob
import re
import os

# %%
# Imports of all used packages and libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.ndimage.filters import gaussian_filter1d
# Out:
# /tmp/ipykernel_2684291/64613958.py:6: DeprecationWarning: Please use `gaussian_filter1d` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   from scipy.ndimage.filters import gaussian_filter1d

# %% [markdown]
# ## Inputs & Data

# %% [markdown]
# Explanation of each input and where it comes from.

# %%
# Inputs and Required data loading
# input varaible names are in all caps snake case
# Whenever an input changes or is used for processing 
# the vairables are all lower in snake case

TRIAL_LENGTH = 10
SAMPLING_RATE = 20000
TONE_TIMESTAMP_DF = pd.read_excel("../../data/rce_tone_timestamp.xlsx", index_col=0)
OUTPUT_DIR = r"./proc" # where data is saved should always be shown in the inputs

INPUT_DIR=glob.glob("/scratch/back_up/reward_competition_extention/proc/phy_curation/*")

# %%
TRIAL_NUMBER_COL = "trial_number"

# %% [markdown]
# ## Outputs

# %% [markdown]
# Describe each output that the notebook creates.

# %% [markdown]
# - Is it a plot or is it data?

# %% [markdown]
# - How valuable is the output and why is it valuable or useful?

# %% [markdown]
# ## Processing

# %% [markdown]
# Describe what is done to the data here and how inputs are manipulated to generate outputs.

# %%
# As much code and as many cells as required
# includes EDA and playing with data
# GO HAM!

# Ideally functions are defined here first and then data is processed using the functions

# function names are short and in snake case all lowercase
# a function name should be unique but does not have to describe the function
# doc strings describe functions not function names

# %%
def find_closest(target, reference_list):
    """
    Finds the closest number in a reference list to the given target number.

    Parameters:
    - target (float or int): The number for which we want to find the closest value.
    - reference_list (list of float or int): The list of numbers in which we want to search.

    Returns:
    - float or int: The closest number from the reference list to the target.
    """

    # Using the 'min' function with a custom key to determine the closest value by minimal absolute difference
    closest_value = min(reference_list, key=lambda x: abs(x - target))
    
    return closest_value

# %%
def find_index_in_group(group, value_column, new_column_name):
    unique_values = sorted(list(set(group[value_column])))
    group[new_column_name] = group[value_column].apply(lambda x: unique_values.index(x) + 1)
    return group

# %% [markdown]
# ### Getting the subject IDs from the file name

# %% [markdown]
# - Dropping all unlabeled trials

# %%
all_trials_df = TONE_TIMESTAMP_DF.dropna(subset="condition").sort_values(by=["recording_file", "time_stamp_index"]).reset_index(drop=True)

# %% [markdown]
# - Making sure that all timestamps are integers

# %%
all_trials_df["time_stamp_index"] = all_trials_df["time_stamp_index"].astype(int)
all_trials_df["time_stamp_index"] = all_trials_df["time_stamp_index"].astype(int)
all_trials_df["video_frame"] = all_trials_df["video_frame"].astype(int)

# %%
all_trials_df.head()
# Out:
#          time  state                                      recording_dir  \
# 0   6310663.0    1.0  20221202_134600_omission_and_competition_subje...
# 1   7910662.0    1.0  20221202_134600_omission_and_competition_subje...
# 2   9710660.0    1.0  20221202_134600_omission_and_competition_subje...
# 3  11310658.0    1.0  20221202_134600_omission_and_competition_subje...
# 4  12810657.0    1.0  20221202_134600_omission_and_competition_subje...
#
#                                       recording_file           din  \
# 0  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# 1  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# 2  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# 3  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# 4  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
#
#    time_stamp_index                                         video_file  \
# 0           1390826  20221202_134600_omission_and_competition_subje...
# 1           2990825  20221202_134600_omission_and_competition_subje...
# 2           4790823  20221202_134600_omission_and_competition_subje...
# 3           6390821  20221202_134600_omission_and_competition_subje...
# 4           7890820  20221202_134600_omission_and_competition_subje...
#
#    video_frame  video_number      subject_info condition  \
# 0         1734           1.0  6_1_top_2_base_3  rewarded
# 1         3728           1.0  6_1_top_2_base_3  rewarded
# 2         5972           1.0  6_1_top_2_base_3  rewarded
# 3         7966           1.0  6_1_top_2_base_3  omission
# 4         9836           1.0  6_1_top_2_base_3  rewarded
#
#   competition_closeness Unnamed: 13
# 0                   NaN         NaN
# 1                   NaN         NaN
# 2                   NaN         NaN
# 3                   NaN         NaN
# 4                   NaN         NaN

# %%
all_trials_df.tail()
# Out:
#            time  state                                      recording_dir  \
# 738  68781880.0    1.0  20230621_111240_standard_comp_to_omission_D5_s...
# 739  70681909.0    1.0  20230621_111240_standard_comp_to_omission_D5_s...
# 740  70681909.0    1.0  20230621_111240_standard_comp_to_omission_D5_s...
# 741  71681918.0    1.0  20230621_111240_standard_comp_to_omission_D5_s...
# 742  71681918.0    1.0  20230621_111240_standard_comp_to_omission_D5_s...
#
#                                         recording_file           din  \
# 738  20230621_111240_standard_comp_to_omission_D5_s...  dio_ECU_Din1
# 739  20230621_111240_standard_comp_to_omission_D5_s...  dio_ECU_Din1
# 740  20230621_111240_standard_comp_to_omission_D5_s...  dio_ECU_Din1
# 741  20230621_111240_standard_comp_to_omission_D5_s...  dio_ECU_Din1
# 742  20230621_111240_standard_comp_to_omission_D5_s...  dio_ECU_Din1
#
#      time_stamp_index                                         video_file  \
# 738          65588836  20230621_111240_standard_comp_to_omission_D5_s...
# 739          67488865  20230621_111240_standard_comp_to_omission_D5_s...
# 740          67488865  20230621_111240_standard_comp_to_omission_D5_s...
# 741          68488874  20230621_111240_standard_comp_to_omission_D5_s...
# 742          68488874  20230621_111240_standard_comp_to_omission_D5_s...
#
#      video_frame  video_number    subject_info condition  \
# 738        65465           2.0  1-4_t3b3L_box1  rewarded
# 739        67447           1.0  1-4_t3b3L_box1  omission
# 740        67362           2.0  1-4_t3b3L_box1  omission
# 741        68444           1.0  1-4_t3b3L_box1  rewarded
# 742        68359           2.0  1-4_t3b3L_box1  rewarded
#
#     competition_closeness Unnamed: 13
# 738                   NaN    rewarded
# 739                   NaN    omission
# 740                   NaN    omission
# 741                   NaN    rewarded
# 742                   NaN    rewarded

# %%
1390826/20000
# Out:
# 69.5413

# %%
68488874/20000
# Out:
# 3424.4437

# %% [markdown]
# - Original timestamps are based on ephys recordings at 20kHz. The LFP will be at 1kHz, so we will need to divide all the timestamps by 20

# %%
all_trials_df["resampled_index"] = all_trials_df["time_stamp_index"] // 20

# %%
all_trials_df["recording_dir"].unique()
# Out:
# array(['20221202_134600_omission_and_competition_subject_6_1_and_6_2',
#        '20221203_154800_omission_and_competition_subject_6_4_and_6_1',
#        '20221214_125409_om_and_comp_6_1_and_6_3',
#        '20221215_145401_comp_amd_om_6_1_and_6_3',
#        '20230612_101430_standard_comp_to_training_D1_subj_1-4_and_1-3',
#        '20230617_115521_standard_comp_to_omission_D1_subj_1-1_and_1-2',
#        '20230618_100636_standard_comp_to_omission_D2_subj_1-4_and_1-1',
#        '20230619_115321_standard_comp_to_omission_D3_subj_1-2_and_1-4',
#        '20230620_114347_standard_comp_to_omission_D4_subj_1-2_and_1-1',
#        '20230621_111240_standard_comp_to_omission_D5_subj_1-4_and_1-2'],
#       dtype=object)

# %% [markdown]
# - Getting a list of all the subjects through the recording name

# %%
all_trials_df["all_subjects"] = all_trials_df["recording_dir"].apply(lambda x: ["{}.{}".format(tup[0],tup[1]) for tup in re.findall(r'(\d+)-(\d+)', x.replace("_", "-"))[1:]])

# %%
all_trials_df["all_subjects"].head()
# Out:
# 0    [6.1, 6.2]
# 1    [6.1, 6.2]
# 2    [6.1, 6.2]
# 3    [6.1, 6.2]
# 4    [6.1, 6.2]
# Name: all_subjects, dtype: object

# %% [markdown]
# - Getting the current subject of the recording through the ending of the recording name file

# %%
all_trials_df["subject_info"].head()
# Out:
# 0    6_1_top_2_base_3
# 1    6_1_top_2_base_3
# 2    6_1_top_2_base_3
# 3    6_1_top_2_base_3
# 4    6_1_top_2_base_3
# Name: subject_info, dtype: object

# %%
all_trials_df["current_subject"] = all_trials_df["subject_info"].apply(lambda x: ".".join(x.replace("-","_").split("_")[:2]))

# %%
all_trials_df.head()
# Out:
#          time  state                                      recording_dir  \
# 0   6310663.0    1.0  20221202_134600_omission_and_competition_subje...
# 1   7910662.0    1.0  20221202_134600_omission_and_competition_subje...
# 2   9710660.0    1.0  20221202_134600_omission_and_competition_subje...
# 3  11310658.0    1.0  20221202_134600_omission_and_competition_subje...
# 4  12810657.0    1.0  20221202_134600_omission_and_competition_subje...
#
#                                       recording_file           din  \
# 0  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# 1  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# 2  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# 3  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# 4  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
#
#    time_stamp_index                                         video_file  \
# 0           1390826  20221202_134600_omission_and_competition_subje...
# 1           2990825  20221202_134600_omission_and_competition_subje...
# 2           4790823  20221202_134600_omission_and_competition_subje...
# 3           6390821  20221202_134600_omission_and_competition_subje...
# 4           7890820  20221202_134600_omission_and_competition_subje...
#
#    video_frame  video_number      subject_info condition  \
# 0         1734           1.0  6_1_top_2_base_3  rewarded
# 1         3728           1.0  6_1_top_2_base_3  rewarded
# 2         5972           1.0  6_1_top_2_base_3  rewarded
# 3         7966           1.0  6_1_top_2_base_3  omission
# 4         9836           1.0  6_1_top_2_base_3  rewarded
#
#   competition_closeness Unnamed: 13  resampled_index all_subjects  \
# 0                   NaN         NaN            69541   [6.1, 6.2]
# 1                   NaN         NaN           149541   [6.1, 6.2]
# 2                   NaN         NaN           239541   [6.1, 6.2]
# 3                   NaN         NaN           319541   [6.1, 6.2]
# 4                   NaN         NaN           394541   [6.1, 6.2]
#
#   current_subject
# 0             6.1
# 1             6.1
# 2             6.1
# 3             6.1
# 4             6.1

# %% [markdown]
# - Labeling the trial as a winner or loser if the winner matches the subject id or not

# %%
all_trials_df["trial_outcome"] = all_trials_df.apply(
    lambda x: "win" if str(x["condition"]).strip() == str(x["current_subject"]) 
             else ("lose" if str(x["condition"]) in x["all_subjects"] 
                   else x["condition"]), axis=1)

# %%
all_trials_df.head()
# Out:
#          time  state                                      recording_dir  \
# 0   6310663.0    1.0  20221202_134600_omission_and_competition_subje...
# 1   7910662.0    1.0  20221202_134600_omission_and_competition_subje...
# 2   9710660.0    1.0  20221202_134600_omission_and_competition_subje...
# 3  11310658.0    1.0  20221202_134600_omission_and_competition_subje...
# 4  12810657.0    1.0  20221202_134600_omission_and_competition_subje...
#
#                                       recording_file           din  \
# 0  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# 1  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# 2  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# 3  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# 4  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
#
#    time_stamp_index                                         video_file  \
# 0           1390826  20221202_134600_omission_and_competition_subje...
# 1           2990825  20221202_134600_omission_and_competition_subje...
# 2           4790823  20221202_134600_omission_and_competition_subje...
# 3           6390821  20221202_134600_omission_and_competition_subje...
# 4           7890820  20221202_134600_omission_and_competition_subje...
#
#    video_frame  video_number      subject_info condition  \
# 0         1734           1.0  6_1_top_2_base_3  rewarded
# 1         3728           1.0  6_1_top_2_base_3  rewarded
# 2         5972           1.0  6_1_top_2_base_3  rewarded
# 3         7966           1.0  6_1_top_2_base_3  omission
# 4         9836           1.0  6_1_top_2_base_3  rewarded
#
#   competition_closeness Unnamed: 13  resampled_index all_subjects  \
# 0                   NaN         NaN            69541   [6.1, 6.2]
# 1                   NaN         NaN           149541   [6.1, 6.2]
# 2                   NaN         NaN           239541   [6.1, 6.2]
# 3                   NaN         NaN           319541   [6.1, 6.2]
# 4                   NaN         NaN           394541   [6.1, 6.2]
#
#   current_subject trial_outcome
# 0             6.1      rewarded
# 1             6.1      rewarded
# 2             6.1      rewarded
# 3             6.1      omission
# 4             6.1      rewarded

# %%
all_trials_df
# Out:
#            time  state                                      recording_dir  \
# 0     6310663.0    1.0  20221202_134600_omission_and_competition_subje...
# 1     7910662.0    1.0  20221202_134600_omission_and_competition_subje...
# 2     9710660.0    1.0  20221202_134600_omission_and_competition_subje...
# 3    11310658.0    1.0  20221202_134600_omission_and_competition_subje...
# 4    12810657.0    1.0  20221202_134600_omission_and_competition_subje...
# ..          ...    ...                                                ...
# 738  68781880.0    1.0  20230621_111240_standard_comp_to_omission_D5_s...
# 739  70681909.0    1.0  20230621_111240_standard_comp_to_omission_D5_s...
# 740  70681909.0    1.0  20230621_111240_standard_comp_to_omission_D5_s...
# 741  71681918.0    1.0  20230621_111240_standard_comp_to_omission_D5_s...
# 742  71681918.0    1.0  20230621_111240_standard_comp_to_omission_D5_s...
#
#                                         recording_file           din  \
# 0    20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# 1    20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# 2    20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# 3    20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# 4    20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# ..                                                 ...           ...
# 738  20230621_111240_standard_comp_to_omission_D5_s...  dio_ECU_Din1
# 739  20230621_111240_standard_comp_to_omission_D5_s...  dio_ECU_Din1
# 740  20230621_111240_standard_comp_to_omission_D5_s...  dio_ECU_Din1
# 741  20230621_111240_standard_comp_to_omission_D5_s...  dio_ECU_Din1
# 742  20230621_111240_standard_comp_to_omission_D5_s...  dio_ECU_Din1
#
#      time_stamp_index                                         video_file  \
# 0             1390826  20221202_134600_omission_and_competition_subje...
# 1             2990825  20221202_134600_omission_and_competition_subje...
# 2             4790823  20221202_134600_omission_and_competition_subje...
# 3             6390821  20221202_134600_omission_and_competition_subje...
# 4             7890820  20221202_134600_omission_and_competition_subje...
# ..                ...                                                ...
# 738          65588836  20230621_111240_standard_comp_to_omission_D5_s...
# 739          67488865  20230621_111240_standard_comp_to_omission_D5_s...
# 740          67488865  20230621_111240_standard_comp_to_omission_D5_s...
# 741          68488874  20230621_111240_standard_comp_to_omission_D5_s...
# 742          68488874  20230621_111240_standard_comp_to_omission_D5_s...
#
#      video_frame  video_number      subject_info condition  \
# 0           1734           1.0  6_1_top_2_base_3  rewarded
# 1           3728           1.0  6_1_top_2_base_3  rewarded
# 2           5972           1.0  6_1_top_2_base_3  rewarded
# 3           7966           1.0  6_1_top_2_base_3  omission
# 4           9836           1.0  6_1_top_2_base_3  rewarded
# ..           ...           ...               ...       ...
# 738        65465           2.0    1-4_t3b3L_box1  rewarded
# 739        67447           1.0    1-4_t3b3L_box1  omission
# 740        67362           2.0    1-4_t3b3L_box1  omission
# 741        68444           1.0    1-4_t3b3L_box1  rewarded
# 742        68359           2.0    1-4_t3b3L_box1  rewarded
#
#     competition_closeness Unnamed: 13  resampled_index all_subjects  \
# 0                     NaN         NaN            69541   [6.1, 6.2]
# 1                     NaN         NaN           149541   [6.1, 6.2]
# 2                     NaN         NaN           239541   [6.1, 6.2]
# 3                     NaN         NaN           319541   [6.1, 6.2]
# 4                     NaN         NaN           394541   [6.1, 6.2]
# ..                    ...         ...              ...          ...
# 738                   NaN    rewarded          3279441   [1.4, 1.2]
# 739                   NaN    omission          3374443   [1.4, 1.2]
# 740                   NaN    omission          3374443   [1.4, 1.2]
# 741                   NaN    rewarded          3424443   [1.4, 1.2]
# 742                   NaN    rewarded          3424443   [1.4, 1.2]
#
#     current_subject trial_outcome
# 0               6.1      rewarded
# 1               6.1      rewarded
# 2               6.1      rewarded
# 3               6.1      omission
# 4               6.1      rewarded
# ..              ...           ...
# 738             1.4      rewarded
# 739             1.4      omission
# 740             1.4      omission
# 741             1.4      rewarded
# 742             1.4      rewarded
#
# [743 rows x 17 columns]

# %%
all_trials_df["competition_closeness"] = all_trials_df["competition_closeness"].fillna("")

# %%
all_trials_df["competition_closeness"].unique()
# Out:
# array(['', 'Subj 1 Only', 'Subj 2 blocking Subj 1', 'Subj 1 then Subj 2',
#        'Subj 1 blocking Subj 2', 'Subj 2 Only', 'Subj 2 then Subj 1',
#        'Close Call'], dtype=object)

# %%
all_trials_df = all_trials_df[~all_trials_df["competition_closeness"].str.contains("Only")]

# %% [markdown]
# # Reading in Phy

# %% [markdown]
# - Reading in a spreadsheet of all the unit classifications
#     - They are divided up into good units, multi-units, and noise

# %%
INPUT_DIR
# Out:
# ['/scratch/back_up/reward_competition_extention/proc/phy_curation/20230618_100636_standard_comp_to_omission_D2_subj_1_4_t4b3L_box1_merged.rec',
#  '/scratch/back_up/reward_competition_extention/proc/phy_curation/20221202_134600_omission_and_competition_subject_6_1_top_2_base_3_merged.rec',
#  '/scratch/back_up/reward_competition_extention/proc/phy_curation/20230618_100636_standard_comp_to_omission_D2_subj_1_1_t1b2L_box2_merged.rec',
#  '/scratch/back_up/reward_competition_extention/proc/phy_curation/tbc',
#  '/scratch/back_up/reward_competition_extention/proc/phy_curation/20221203_154800_omission_and_competition_subject_6_1_top_1_base_3_merged.rec',
#  '/scratch/back_up/reward_competition_extention/proc/phy_curation/20230621_111240_standard_comp_to_omission_D5_subj_1-4_t3b3L_box1_merged.rec',
#  '/scratch/back_up/reward_competition_extention/proc/phy_curation/20230620_114347_standard_comp_to_omission_D4_subj_1-1_t1b2L_box_2_merged.rec',
#  '/scratch/back_up/reward_competition_extention/proc/phy_curation/20230617_115521_standard_comp_to_omission_D1_subj_1-2_t2b2L_box2_merged.rec',
#  '/scratch/back_up/reward_competition_extention/proc/phy_curation/20230617_115521_standard_comp_to_omission_D1_subj_1-1_t1b3L_box1_merged.rec',
#  '/scratch/back_up/reward_competition_extention/proc/phy_curation/20230620_114347_standard_comp_to_omission_D4_subj_1-2_t3b3L_box_1_merged.rec',
#  '/scratch/back_up/reward_competition_extention/proc/phy_curation/20230619_115321_standard_comp_to_omission_D3_subj_1-4_t3b3L_box2_merged.rec']

# %%
recording_to_cluster_info = {}
for recording_dir in INPUT_DIR:
    try:
        recording_basename = os.path.basename(recording_dir).strip(".rec")
        file_path = os.path.join(recording_dir, "phy", "cluster_info.tsv")
        recording_to_cluster_info[recording_basename] = pd.read_csv(file_path, sep="\t")
    except Exception as e:
        print(e)
# Out:
# [Errno 2] No such file or directory: '/scratch/back_up/reward_competition_extention/proc/phy_curation/tbc/phy/cluster_info.tsv'

# %%
recording_to_cluster_info[list(recording_to_cluster_info.keys())[1]]
# Out:
#     cluster_id  1_5_ms_isi  1ms_isi  2ms_isi        amp  ch  channel_group  \
# 0            0          34       12      114   9.905600   0              0
# 1            1         254       93      613   9.664331   2              0
# 2            2           5        1       11   7.940112   3              0
# 3            3           4        3        8  18.886822   3              0
# 4            4         158       49      496   8.658522   5              0
# 5            7         483      162     1182   9.899465   9              0
# 6            8         297      189      492   4.622509  12              0
# 7            9          36        4      144   9.896030  13              0
# 8           10         425      166      885  11.562847  14              0
# 9           13          23        4       93   7.631701  22              0
# 10          14         172       75      528   9.907733  25              0
# 11          15         124       49      265  11.865698  26              0
# 12          16          45       14      151   8.463471  27              0
# 13          17           0        0        0  25.162426  28              0
# 14          18          20        7       94   7.986902  28              0
# 15          21          27        3      116   7.931630  31              0
# 16          30           5        1       12  13.309378   6              0
# 17          32           9        6       13  13.309378   6              0
# 18          33           1        0        2  13.309378   6              0
# 19          36          46        9      160   8.317023   7              0
# 20          37           0        0        0   8.317023   7              0
# 21          42          13        0       32  11.033840  21              0
# 22          47           0        0        1   9.688529  21              0
# 23          48           0        0        0   9.688529  21              0
# 24          50          59       40      130  11.033840  21              0
# 25          51          15        4       43   8.207144  29              0
# 26          53           0        0        3   8.207144  29              0
# 27          54           0        0        0   8.207144  29              0
# 28          55           0        0        0  18.066862  30              0
# 29          56           0        0        0  18.066862  30              0
#
#     depth         fr  group  n_spikes  sh  si_unit_id
# 0     0.0   5.331166    mua     17857   0           1
# 1    40.0  18.101842    mua     60633   0           2
# 2    60.0   2.168949    mua      7265   0           3
# 3    60.0   0.415280  noise      1391   0           4
# 4   100.0  12.934877    mua     43326   0           5
# 5   180.0  21.764426    mua     72901   0           8
# 6   240.0   0.756520  noise      2534   0           9
# 7   260.0   0.975654    mua      3268   0          10
# 8   280.0   2.755894    mua      9231   0          11
# 9   440.0   5.425209   good     18172   0          15
# 10  500.0  13.115499    mua     43931   0          16
# 11  520.0  10.158981    mua     34028   0          17
# 12  540.0   7.622221    mua     25531   0          18
# 13  560.0   1.787106   good      5986   0          19
# 14  560.0   6.111868    mua     20472   0          20
# 15  620.0  12.246128   good     41019   0          23
# 16  120.0   4.716158   good     15797   0           6
# 17  120.0   1.564390    mua      5240   0           6
# 18  120.0   0.024779  noise        83   0           6
# 19  140.0  10.319301    mua     34565   0           7
# 20  140.0   0.015226  noise        51   0           7
# 21  420.0   3.313282    mua     11098   0          12
# 22  420.0   0.443642   good      1486   0          13
# 23  420.0   0.802496   good      2688   0          13
# 24  420.0   5.493875    mua     18402   0          12
# 25  580.0   7.006616    mua     23469   0          21
# 26  580.0   1.513338   good      5069   0          21
# 27  580.0   0.001791    mua         6   0          21
# 28  600.0   0.102402    mua       343   0          22
# 29  600.0   0.645162   good      2161   0          22

# %% [markdown]
# - Combining all the unit info dataframes and adding the recording name

# %%
recording_to_cluster_info_df = pd.concat(recording_to_cluster_info, names=['recording_name']).reset_index(level=1, drop=True).reset_index()

# %%
recording_to_cluster_info_df.head()
# Out:
#                                       recording_name  cluster_id  1_5_ms_isi  \
# 0  20230618_100636_standard_comp_to_omission_D2_s...           8           0
# 1  20230618_100636_standard_comp_to_omission_D2_s...           9           1
# 2  20230618_100636_standard_comp_to_omission_D2_s...          19           1
# 3  20230618_100636_standard_comp_to_omission_D2_s...          20           0
# 4  20230618_100636_standard_comp_to_omission_D2_s...          21          47
#
#    1ms_isi  2ms_isi        amp  ch  channel_group  depth        fr  group  \
# 0        0        1   9.198713   3            0.0   60.0  0.217516    mua
# 1        1        2  12.508228   3            0.0   60.0  1.605419   good
# 2        0        2  13.435120  15            0.0  300.0  0.503261   good
# 3        0        0   7.342390  20            0.0  400.0  0.219265    mua
# 4       10      122  10.664793  21            0.0  420.0  0.605604  noise
#
#    n_spikes  sh  si_unit_id
# 0       746   0         9.0
# 1      5506   0        10.0
# 2      1726   0        20.0
# 3       752   0        22.0
# 4      2077   0        23.0

# %% [markdown]
# - Filtering for the good units

# %%
good_unit_cluster_info_df = recording_to_cluster_info_df[recording_to_cluster_info_df["group"] == "good"].reset_index(drop=True)

# %%
good_unit_cluster_info_df.head()
# Out:
#                                       recording_name  cluster_id  1_5_ms_isi  \
# 0  20230618_100636_standard_comp_to_omission_D2_s...           9           1
# 1  20230618_100636_standard_comp_to_omission_D2_s...          19           1
# 2  20230618_100636_standard_comp_to_omission_D2_s...          65           2
# 3  20230618_100636_standard_comp_to_omission_D2_s...          83           9
# 4  20230618_100636_standard_comp_to_omission_D2_s...          87           3
#
#    1ms_isi  2ms_isi        amp  ch  channel_group  depth         fr group  \
# 0        1        2  12.508228   3            0.0   60.0   1.605419  good
# 1        0        2  13.435120  15            0.0  300.0   0.503261  good
# 2        1        3   8.466800   2            0.0   40.0   2.628268  good
# 3        3       26  13.022879   2            0.0   40.0  10.683353  good
# 4        0        4  15.160955   0            0.0    0.0   2.416584  good
#
#    n_spikes  sh  si_unit_id
# 0      5506   0        10.0
# 1      1726   0        20.0
# 2      9014   0         8.0
# 3     36640   0         5.0
# 4      8288   0         1.0

# %%
recording_to_good_unit_ids = good_unit_cluster_info_df.groupby('recording_name')['cluster_id'].apply(list).to_dict()

# %% [markdown]
# - A list of all the unit IDs that each spike came from in order
#     - First item is first spike, second item is second spike, etc.

# %%
recording_to_spike_clusters = {}
for recording_dir in INPUT_DIR:
    try:
        recording_basename = os.path.basename(recording_dir).strip(".rec")
        file_path = os.path.join(recording_dir, "phy", "spike_clusters.npy")
        recording_to_spike_clusters[recording_basename] = np.load(file_path)
    except Exception as e:
        print(e)
# Out:
# [Errno 2] No such file or directory: '/scratch/back_up/reward_competition_extention/proc/phy_curation/tbc/phy/spike_clusters.npy'

# %%
recording_to_spike_clusters[list(recording_to_spike_clusters.keys())[0]]
# Out:
# array([82, 82, 82, ..., 87, 83, 99], dtype=int32)

# %%
recording_to_spike_clusters[list(recording_to_spike_clusters.keys())[0]].shape
# Out:
# (251953,)

# %% [markdown]
# - The times that all the spikes happened

# %%
recording_to_spike_times = {}
for recording_dir in INPUT_DIR:
    try:
        recording_basename = os.path.basename(recording_dir).strip(".rec")
        file_path = os.path.join(recording_dir, "phy", "spike_times.npy")
        recording_to_spike_times[recording_basename] = np.load(file_path)
    except Exception as e:
        print(e)
# Out:
# [Errno 2] No such file or directory: '/scratch/back_up/reward_competition_extention/proc/phy_curation/tbc/phy/spike_times.npy'

# %%
recording_to_spike_times[list(recording_to_spike_times.keys())[0]]
# Out:
# array([[      46],
#        [     266],
#        [     437],
#        ...,
#        [67098020],
#        [67098467],
#        [67098849]])

# %%
recording_to_spike_times[list(recording_to_spike_times.keys())[0]].shape
# Out:
# (251953, 1)

# %% [markdown]
# ### Combining everything into a dataframe

# %%
recording_to_spike_df = {}
for recording_dir in INPUT_DIR:
    try:
        recording_basename = os.path.basename(recording_dir).strip(".rec")
        cluster_info_path = os.path.join(recording_dir, "phy", "cluster_info.tsv")
        cluster_info_df = pd.read_csv(cluster_info_path, sep="\t")

        spike_clusters_path = os.path.join(recording_dir, "phy", "spike_clusters.npy")
        spike_clusters = np.load(spike_clusters_path)
        
        spike_times_path = os.path.join(recording_dir, "phy", "spike_times.npy")
        spike_times = np.load(spike_times_path)

        spike_df = pd.DataFrame({'spike_clusters': spike_clusters, 'spike_times': spike_times.T[0]})

        merged_df = spike_df.merge(cluster_info_df, left_on='spike_clusters', right_on='cluster_id', how="left")
        merged_df["recording_name"] = recording_basename

        merged_df["timestamp_isi"] = merged_df.groupby('spike_clusters')["spike_times"].diff()
        merged_df["current_isi"] = merged_df["timestamp_isi"] / SAMPLING_RATE
        
        if not merged_df.empty:
            recording_to_spike_df[recording_basename] = merged_df
       
    except Exception as e:
        print(e)
# Out:
# [Errno 2] No such file or directory: '/scratch/back_up/reward_competition_extention/proc/phy_curation/tbc/phy/cluster_info.tsv'

# %%
cluster_info_df.head()
# Out:
#    cluster_id  1_5_ms_isi  1ms_isi  2ms_isi        amp  ch  channel_group  \
# 0          11           1        0        5   8.923600   3              0
# 1          12           0        0        0   9.733616   3              0
# 2          44           3        1       29   9.739503  17              0
# 3          45          38       12       88   9.464285  18              0
# 4          46          32        5      125  10.028766  18              0
#
#    depth         fr  group  n_spikes  sh  si_unit_id
# 0   60.0   2.805744   good      5778   0          13
# 1   60.0   2.012289  noise      4144   0          14
# 2  340.0  13.732511   good     28280   0          46
# 3  360.0   9.795340    mua     20172   0          47
# 4  360.0   6.568588    mua     13527   0          48

# %%
spike_times
# Out:
# array([[     143],
#        [     168],
#        [     274],
#        ...,
#        [38957896],
#        [38957942],
#        [38957990]])

# %%
spike_clusters
# Out:
# array([252, 246, 279, ...,  62,  60,  62], dtype=int32)

# %% [markdown]
# - Combining the spike time df for all recordings

# %%
all_spike_time_df = pd.concat(recording_to_spike_df.values())

# %%
all_spike_time_df = all_spike_time_df[all_spike_time_df["group"] == "good"].reset_index(drop=True)

# %%
all_spike_time_df.head()
# Out:
#    spike_clusters  spike_times  cluster_id  1_5_ms_isi  1ms_isi  2ms_isi  \
# 0              65          937          65           2        1        3
# 1             123          998         123           1        1        1
# 2             103         1125         103          12        2       32
# 3             123         1327         123           1        1        1
# 4             103         1346         103          12        2       32
#
#          amp  ch  channel_group  depth        fr group  n_spikes  sh  \
# 0   8.466800   2            0.0   40.0  2.628268  good      9014   0
# 1  19.984566  24            0.0  480.0  2.384219  good      8177   0
# 2  14.402934   6            0.0  120.0  8.755451  good     30028   0
# 3  19.984566  24            0.0  480.0  2.384219  good      8177   0
# 4  14.402934   6            0.0  120.0  8.755451  good     30028   0
#
#    si_unit_id                                     recording_name  \
# 0         8.0  20230618_100636_standard_comp_to_omission_D2_s...
# 1        28.0  20230618_100636_standard_comp_to_omission_D2_s...
# 2        11.0  20230618_100636_standard_comp_to_omission_D2_s...
# 3        28.0  20230618_100636_standard_comp_to_omission_D2_s...
# 4        11.0  20230618_100636_standard_comp_to_omission_D2_s...
#
#    timestamp_isi  current_isi
# 0            NaN          NaN
# 1            NaN          NaN
# 2            NaN          NaN
# 3          329.0      0.01645
# 4          221.0      0.01105

# %%
all_spike_time_df.tail()
# Out:
#          spike_clusters  spike_times  cluster_id  1_5_ms_isi  1ms_isi  \
# 2135421             255     38957244         255           0        0
# 2135422             255     38957331         255           0        0
# 2135423             262     38957511         262           1        1
# 2135424              44     38957537          44           3        1
# 2135425             134     38957868         134           5        4
#
#          2ms_isi        amp  ch  channel_group  depth         fr group  \
# 2135421        0  14.943707   6            0.0  120.0   0.691967  good
# 2135422        0  14.943707   6            0.0  120.0   0.691967  good
# 2135423        1  11.366614   6            0.0  120.0   8.020505  good
# 2135424       29   9.739503  17            0.0  340.0  13.732511  good
# 2135425       17   8.562255   2            0.0   40.0  14.537135  good
#
#          n_spikes  sh  si_unit_id  \
# 2135421      1425   0        18.0
# 2135422      1425   0        18.0
# 2135423     16517   0        17.0
# 2135424     28280   0        46.0
# 2135425     29937   0        11.0
#
#                                             recording_name  timestamp_isi  \
# 2135421  20230619_115321_standard_comp_to_omission_D3_s...          173.0
# 2135422  20230619_115321_standard_comp_to_omission_D3_s...           87.0
# 2135423  20230619_115321_standard_comp_to_omission_D3_s...         3072.0
# 2135424  20230619_115321_standard_comp_to_omission_D3_s...         2342.0
# 2135425  20230619_115321_standard_comp_to_omission_D3_s...         1151.0
#
#          current_isi
# 2135421      0.00865
# 2135422      0.00435
# 2135423      0.15360
# 2135424      0.11710
# 2135425      0.05755

# %%
all_spike_time_df["spike_times"].min()
# Out:
# 63

# %%
all_spike_time_df["spike_times"].max()
# Out:
# 79697404

# %%
all_spike_time_df["recording_name"].unique()
# Out:
# array(['20230618_100636_standard_comp_to_omission_D2_subj_1_4_t4b3L_box1_merged',
#        '20221202_134600_omission_and_competition_subject_6_1_top_2_base_3_merged',
#        '20230618_100636_standard_comp_to_omission_D2_subj_1_1_t1b2L_box2_merged',
#        '20221203_154800_omission_and_competition_subject_6_1_top_1_base_3_merged',
#        '20230621_111240_standard_comp_to_omission_D5_subj_1-4_t3b3L_box1_merged',
#        '20230620_114347_standard_comp_to_omission_D4_subj_1-1_t1b2L_box_2_merged',
#        '20230617_115521_standard_comp_to_omission_D1_subj_1-2_t2b2L_box2_merged',
#        '20230617_115521_standard_comp_to_omission_D1_subj_1-1_t1b3L_box1_merged',
#        '20230620_114347_standard_comp_to_omission_D4_subj_1-2_t3b3L_box_1_merged',
#        '20230619_115321_standard_comp_to_omission_D3_subj_1-4_t3b3L_box2_merged'],
#       dtype=object)

# %% [markdown]
# # Merging the trial information

# %% [markdown]
# - Adding a column that is the trial number

# %%
# Apply the function to each group and create the new column
all_trials_df = all_trials_df.groupby(["recording_file"]).apply(lambda x: find_index_in_group(x, "time_stamp_index", TRIAL_NUMBER_COL)).reset_index(drop="True")

# %%
all_trials_df.head()
# Out:
#          time  state                                      recording_dir  \
# 0   6310663.0    1.0  20221202_134600_omission_and_competition_subje...
# 1   7910662.0    1.0  20221202_134600_omission_and_competition_subje...
# 2   9710660.0    1.0  20221202_134600_omission_and_competition_subje...
# 3  11310658.0    1.0  20221202_134600_omission_and_competition_subje...
# 4  12810657.0    1.0  20221202_134600_omission_and_competition_subje...
#
#                                       recording_file           din  \
# 0  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# 1  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# 2  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# 3  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# 4  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
#
#    time_stamp_index                                         video_file  \
# 0           1390826  20221202_134600_omission_and_competition_subje...
# 1           2990825  20221202_134600_omission_and_competition_subje...
# 2           4790823  20221202_134600_omission_and_competition_subje...
# 3           6390821  20221202_134600_omission_and_competition_subje...
# 4           7890820  20221202_134600_omission_and_competition_subje...
#
#    video_frame  video_number      subject_info condition  \
# 0         1734           1.0  6_1_top_2_base_3  rewarded
# 1         3728           1.0  6_1_top_2_base_3  rewarded
# 2         5972           1.0  6_1_top_2_base_3  rewarded
# 3         7966           1.0  6_1_top_2_base_3  omission
# 4         9836           1.0  6_1_top_2_base_3  rewarded
#
#   competition_closeness Unnamed: 13  resampled_index all_subjects  \
# 0                               NaN            69541   [6.1, 6.2]
# 1                               NaN           149541   [6.1, 6.2]
# 2                               NaN           239541   [6.1, 6.2]
# 3                               NaN           319541   [6.1, 6.2]
# 4                               NaN           394541   [6.1, 6.2]
#
#   current_subject trial_outcome  trial_number
# 0             6.1      rewarded             1
# 1             6.1      rewarded             2
# 2             6.1      rewarded             3
# 3             6.1      omission             4
# 4             6.1      rewarded             5

# %%
all_trials_df.tail()
# Out:
#            time  state                                      recording_dir  \
# 515  68781880.0    1.0  20230621_111240_standard_comp_to_omission_D5_s...
# 516  70681909.0    1.0  20230621_111240_standard_comp_to_omission_D5_s...
# 517  70681909.0    1.0  20230621_111240_standard_comp_to_omission_D5_s...
# 518  71681918.0    1.0  20230621_111240_standard_comp_to_omission_D5_s...
# 519  71681918.0    1.0  20230621_111240_standard_comp_to_omission_D5_s...
#
#                                         recording_file           din  \
# 515  20230621_111240_standard_comp_to_omission_D5_s...  dio_ECU_Din1
# 516  20230621_111240_standard_comp_to_omission_D5_s...  dio_ECU_Din1
# 517  20230621_111240_standard_comp_to_omission_D5_s...  dio_ECU_Din1
# 518  20230621_111240_standard_comp_to_omission_D5_s...  dio_ECU_Din1
# 519  20230621_111240_standard_comp_to_omission_D5_s...  dio_ECU_Din1
#
#      time_stamp_index                                         video_file  \
# 515          65588836  20230621_111240_standard_comp_to_omission_D5_s...
# 516          67488865  20230621_111240_standard_comp_to_omission_D5_s...
# 517          67488865  20230621_111240_standard_comp_to_omission_D5_s...
# 518          68488874  20230621_111240_standard_comp_to_omission_D5_s...
# 519          68488874  20230621_111240_standard_comp_to_omission_D5_s...
#
#      video_frame  video_number    subject_info condition  \
# 515        65465           2.0  1-4_t3b3L_box1  rewarded
# 516        67447           1.0  1-4_t3b3L_box1  omission
# 517        67362           2.0  1-4_t3b3L_box1  omission
# 518        68444           1.0  1-4_t3b3L_box1  rewarded
# 519        68359           2.0  1-4_t3b3L_box1  rewarded
#
#     competition_closeness Unnamed: 13  resampled_index all_subjects  \
# 515                          rewarded          3279441   [1.4, 1.2]
# 516                          omission          3374443   [1.4, 1.2]
# 517                          omission          3374443   [1.4, 1.2]
# 518                          rewarded          3424443   [1.4, 1.2]
# 519                          rewarded          3424443   [1.4, 1.2]
#
#     current_subject trial_outcome  trial_number
# 515             1.4      rewarded            28
# 516             1.4      omission            29
# 517             1.4      omission            29
# 518             1.4      rewarded            30
# 519             1.4      rewarded            30

# %% [markdown]
# - Creating 10 ms time bins for each trial

# %%
all_trials_df["trial_chunked_ephys_timestamp"] = all_trials_df["time_stamp_index"].apply(lambda x: [int(x +  SAMPLING_RATE * num * 0.1) for num in range(-100,101)])

# %%
all_trials_df.head()
# Out:
#          time  state                                      recording_dir  \
# 0   6310663.0    1.0  20221202_134600_omission_and_competition_subje...
# 1   7910662.0    1.0  20221202_134600_omission_and_competition_subje...
# 2   9710660.0    1.0  20221202_134600_omission_and_competition_subje...
# 3  11310658.0    1.0  20221202_134600_omission_and_competition_subje...
# 4  12810657.0    1.0  20221202_134600_omission_and_competition_subje...
#
#                                       recording_file           din  \
# 0  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# 1  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# 2  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# 3  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# 4  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
#
#    time_stamp_index                                         video_file  \
# 0           1390826  20221202_134600_omission_and_competition_subje...
# 1           2990825  20221202_134600_omission_and_competition_subje...
# 2           4790823  20221202_134600_omission_and_competition_subje...
# 3           6390821  20221202_134600_omission_and_competition_subje...
# 4           7890820  20221202_134600_omission_and_competition_subje...
#
#    video_frame  video_number      subject_info condition  \
# 0         1734           1.0  6_1_top_2_base_3  rewarded
# 1         3728           1.0  6_1_top_2_base_3  rewarded
# 2         5972           1.0  6_1_top_2_base_3  rewarded
# 3         7966           1.0  6_1_top_2_base_3  omission
# 4         9836           1.0  6_1_top_2_base_3  rewarded
#
#   competition_closeness Unnamed: 13  resampled_index all_subjects  \
# 0                               NaN            69541   [6.1, 6.2]
# 1                               NaN           149541   [6.1, 6.2]
# 2                               NaN           239541   [6.1, 6.2]
# 3                               NaN           319541   [6.1, 6.2]
# 4                               NaN           394541   [6.1, 6.2]
#
#   current_subject trial_outcome  trial_number  \
# 0             6.1      rewarded             1
# 1             6.1      rewarded             2
# 2             6.1      rewarded             3
# 3             6.1      omission             4
# 4             6.1      rewarded             5
#
#                        trial_chunked_ephys_timestamp
# 0  [1190826, 1192826, 1194826, 1196826, 1198826, ...
# 1  [2790825, 2792825, 2794825, 2796825, 2798825, ...
# 2  [4590823, 4592823, 4594823, 4596823, 4598823, ...
# 3  [6190821, 6192821, 6194821, 6196821, 6198821, ...
# 4  [7690820, 7692820, 7694820, 7696820, 7698820, ...

# %% [markdown]
# - Getting the closest trial number for each spike

# %%
# Getting a list of all the trials for each recording
recording_to_trials = {}
# Loop through each unique key
for key in all_trials_df['recording_file'].unique():
    # Filter the DataFrame based on the key and get the 'Value' column as a list
    recording_to_trials[key] = all_trials_df[all_trials_df['recording_file'] == key]['time_stamp_index'].tolist()

# %%
recording_to_trials.keys()
# Out:
# dict_keys(['20221202_134600_omission_and_competition_subject_6_1_top_2_base_3_merged', '20221203_154800_omission_and_competition_subject_6_1_top_1_base_3_merged', '20221214_125409_om_and_comp_6_1_top_1_base_2_vs_6_3', '20221215_145401_comp_amd_om_6_1_top_4_base_3', '20230612_101430_standard_comp_to_training_D1_subj_1-3_t3b3L_box2_merged', '20230612_101430_standard_comp_to_training_D1_subj_1-4_t4b2L_box1_merged', '20230617_115521_standard_comp_to_omission_D1_subj_1-1_t1b3L_box1_merged', '20230617_115521_standard_comp_to_omission_D1_subj_1-2_t2b2L_box2_merged', '20230618_100636_standard_comp_to_omission_D2_subj_1_1_t1b2L_box2_merged', '20230618_100636_standard_comp_to_omission_D2_subj_1_4_t4b3L_box1_merged', '20230619_115321_standard_comp_to_omission_D3_subj_1-4_t3b3L_box2_merged', '20230620_114347_standard_comp_to_omission_D4_subj_1-1_t1b2L_box_2_merged', '20230620_114347_standard_comp_to_omission_D4_subj_1-2_t3b3L_box_1_merged', '20230621_111240_standard_comp_to_omission_D5_subj_1-4_t3b3L_box1_merged'])

# %%
all_spike_time_df = all_spike_time_df[all_spike_time_df["recording_name"].isin(recording_to_trials.keys())]

# %%
# Calculating the timestamp of the closest tone onset for each spike 
all_spike_time_df["closest_trial"] = all_spike_time_df.apply(lambda row: find_closest(row["spike_times"], recording_to_trials[row["recording_name"]]), axis=1)

# %% [markdown]
# - Filtering out all spikes that are now within a 10 second range of the tone

# %%
all_spike_time_df
# Out:
#          spike_clusters  spike_times  cluster_id  1_5_ms_isi  1ms_isi  \
# 0                    65          937          65           2        1
# 1                   123          998         123           1        1
# 2                   103         1125         103          12        2
# 3                   123         1327         123           1        1
# 4                   103         1346         103          12        2
# ...                 ...          ...         ...         ...      ...
# 2135421             255     38957244         255           0        0
# 2135422             255     38957331         255           0        0
# 2135423             262     38957511         262           1        1
# 2135424              44     38957537          44           3        1
# 2135425             134     38957868         134           5        4
#
#          2ms_isi        amp  ch  channel_group  depth         fr group  \
# 0              3   8.466800   2            0.0   40.0   2.628268  good
# 1              1  19.984566  24            0.0  480.0   2.384219  good
# 2             32  14.402934   6            0.0  120.0   8.755451  good
# 3              1  19.984566  24            0.0  480.0   2.384219  good
# 4             32  14.402934   6            0.0  120.0   8.755451  good
# ...          ...        ...  ..            ...    ...        ...   ...
# 2135421        0  14.943707   6            0.0  120.0   0.691967  good
# 2135422        0  14.943707   6            0.0  120.0   0.691967  good
# 2135423        1  11.366614   6            0.0  120.0   8.020505  good
# 2135424       29   9.739503  17            0.0  340.0  13.732511  good
# 2135425       17   8.562255   2            0.0   40.0  14.537135  good
#
#          n_spikes  sh  si_unit_id  \
# 0            9014   0         8.0
# 1            8177   0        28.0
# 2           30028   0        11.0
# 3            8177   0        28.0
# 4           30028   0        11.0
# ...           ...  ..         ...
# 2135421      1425   0        18.0
# 2135422      1425   0        18.0
# 2135423     16517   0        17.0
# 2135424     28280   0        46.0
# 2135425     29937   0        11.0
#
#                                             recording_name  timestamp_isi  \
# 0        20230618_100636_standard_comp_to_omission_D2_s...            NaN
# 1        20230618_100636_standard_comp_to_omission_D2_s...            NaN
# 2        20230618_100636_standard_comp_to_omission_D2_s...            NaN
# 3        20230618_100636_standard_comp_to_omission_D2_s...          329.0
# 4        20230618_100636_standard_comp_to_omission_D2_s...          221.0
# ...                                                    ...            ...
# 2135421  20230619_115321_standard_comp_to_omission_D3_s...          173.0
# 2135422  20230619_115321_standard_comp_to_omission_D3_s...           87.0
# 2135423  20230619_115321_standard_comp_to_omission_D3_s...         3072.0
# 2135424  20230619_115321_standard_comp_to_omission_D3_s...         2342.0
# 2135425  20230619_115321_standard_comp_to_omission_D3_s...         1151.0
#
#          current_isi  closest_trial
# 0                NaN       11599246
# 1                NaN       11599246
# 2                NaN       11599246
# 3            0.01645       11599246
# 4            0.01105       11599246
# ...              ...            ...
# 2135421      0.00865       38477451
# 2135422      0.00435       38477451
# 2135423      0.15360       38477451
# 2135424      0.11710       38477451
# 2135425      0.05755       38477451
#
# [2135426 rows x 19 columns]

# %%
all_spike_time_df.to_csv("./proc/all_spike_time.csv")

# %%
all_spike_time_df = all_spike_time_df[(all_spike_time_df["spike_times"] > all_spike_time_df["closest_trial"] - 10 * SAMPLING_RATE) & (all_spike_time_df["spike_times"] < all_spike_time_df["closest_trial"] + 10 * SAMPLING_RATE)]

# %%
all_spike_time_df
# Out:
#          spike_clusters  spike_times  cluster_id  1_5_ms_isi  1ms_isi  \
# 20759               103     11399273         103          12        2
# 20760                83     11399416          83           9        3
# 20761                65     11399798          65           2        1
# 20762               103     11399996         103          12        2
# 20763               103     11400706         103          12        2
# ...                 ...          ...         ...         ...      ...
# 2134338             262     38675317         262           1        1
# 2134339              44     38675962          44           3        1
# 2134340             262     38676329         262           1        1
# 2134341             134     38677144         134           5        4
# 2134342             134     38677446         134           5        4
#
#          2ms_isi        amp  ch  channel_group  depth         fr group  \
# 20759         32  14.402934   6            0.0  120.0   8.755451  good
# 20760         26  13.022879   2            0.0   40.0  10.683353  good
# 20761          3   8.466800   2            0.0   40.0   2.628268  good
# 20762         32  14.402934   6            0.0  120.0   8.755451  good
# 20763         32  14.402934   6            0.0  120.0   8.755451  good
# ...          ...        ...  ..            ...    ...        ...   ...
# 2134338        1  11.366614   6            0.0  120.0   8.020505  good
# 2134339       29   9.739503  17            0.0  340.0  13.732511  good
# 2134340        1  11.366614   6            0.0  120.0   8.020505  good
# 2134341       17   8.562255   2            0.0   40.0  14.537135  good
# 2134342       17   8.562255   2            0.0   40.0  14.537135  good
#
#          n_spikes  sh  si_unit_id  \
# 20759       30028   0        11.0
# 20760       36640   0         5.0
# 20761        9014   0         8.0
# 20762       30028   0        11.0
# 20763       30028   0        11.0
# ...           ...  ..         ...
# 2134338     16517   0        17.0
# 2134339     28280   0        46.0
# 2134340     16517   0        17.0
# 2134341     29937   0        11.0
# 2134342     29937   0        11.0
#
#                                             recording_name  timestamp_isi  \
# 20759    20230618_100636_standard_comp_to_omission_D2_s...          183.0
# 20760    20230618_100636_standard_comp_to_omission_D2_s...         1165.0
# 20761    20230618_100636_standard_comp_to_omission_D2_s...         7188.0
# 20762    20230618_100636_standard_comp_to_omission_D2_s...          723.0
# 20763    20230618_100636_standard_comp_to_omission_D2_s...          710.0
# ...                                                    ...            ...
# 2134338  20230619_115321_standard_comp_to_omission_D3_s...         1282.0
# 2134339  20230619_115321_standard_comp_to_omission_D3_s...         3707.0
# 2134340  20230619_115321_standard_comp_to_omission_D3_s...         1012.0
# 2134341  20230619_115321_standard_comp_to_omission_D3_s...         1908.0
# 2134342  20230619_115321_standard_comp_to_omission_D3_s...          302.0
#
#          current_isi  closest_trial
# 20759        0.00915       11599246
# 20760        0.05825       11599246
# 20761        0.35940       11599246
# 20762        0.03615       11599246
# 20763        0.03550       11599246
# ...              ...            ...
# 2134338      0.06410       38477451
# 2134339      0.18535       38477451
# 2134340      0.05060       38477451
# 2134341      0.09540       38477451
# 2134342      0.01510       38477451
#
# [295741 rows x 19 columns]

# %%
all_spike_time_df["closest_trial"].min()
# Out:
# 1030879

# %%
all_spike_time_df["recording_name"].unique()
# Out:
# array(['20230618_100636_standard_comp_to_omission_D2_subj_1_4_t4b3L_box1_merged',
#        '20221202_134600_omission_and_competition_subject_6_1_top_2_base_3_merged',
#        '20230618_100636_standard_comp_to_omission_D2_subj_1_1_t1b2L_box2_merged',
#        '20221203_154800_omission_and_competition_subject_6_1_top_1_base_3_merged',
#        '20230621_111240_standard_comp_to_omission_D5_subj_1-4_t3b3L_box1_merged',
#        '20230620_114347_standard_comp_to_omission_D4_subj_1-1_t1b2L_box_2_merged',
#        '20230617_115521_standard_comp_to_omission_D1_subj_1-2_t2b2L_box2_merged',
#        '20230617_115521_standard_comp_to_omission_D1_subj_1-1_t1b3L_box1_merged',
#        '20230620_114347_standard_comp_to_omission_D4_subj_1-2_t3b3L_box_1_merged',
#        '20230619_115321_standard_comp_to_omission_D3_subj_1-4_t3b3L_box2_merged'],
#       dtype=object)

# %% [markdown]
# - Classifying each spike as being before or after the trial

# %%
all_spike_time_df["trial_or_baseline"] = all_spike_time_df.apply(lambda row: "trial" if row["spike_times"] >= row["closest_trial"] else "baseline", axis=1)
# Out:
# /tmp/ipykernel_2684291/979493472.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_spike_time_df["trial_or_baseline"] = all_spike_time_df.apply(lambda row: "trial" if row["spike_times"] >= row["closest_trial"] else "baseline", axis=1)

# %%
all_spike_time_df.head()
# Out:
#        spike_clusters  spike_times  cluster_id  1_5_ms_isi  1ms_isi  2ms_isi  \
# 20759             103     11399273         103          12        2       32
# 20760              83     11399416          83           9        3       26
# 20761              65     11399798          65           2        1        3
# 20762             103     11399996         103          12        2       32
# 20763             103     11400706         103          12        2       32
#
#              amp  ch  channel_group  depth         fr group  n_spikes  sh  \
# 20759  14.402934   6            0.0  120.0   8.755451  good     30028   0
# 20760  13.022879   2            0.0   40.0  10.683353  good     36640   0
# 20761   8.466800   2            0.0   40.0   2.628268  good      9014   0
# 20762  14.402934   6            0.0  120.0   8.755451  good     30028   0
# 20763  14.402934   6            0.0  120.0   8.755451  good     30028   0
#
#        si_unit_id                                     recording_name  \
# 20759        11.0  20230618_100636_standard_comp_to_omission_D2_s...
# 20760         5.0  20230618_100636_standard_comp_to_omission_D2_s...
# 20761         8.0  20230618_100636_standard_comp_to_omission_D2_s...
# 20762        11.0  20230618_100636_standard_comp_to_omission_D2_s...
# 20763        11.0  20230618_100636_standard_comp_to_omission_D2_s...
#
#        timestamp_isi  current_isi  closest_trial trial_or_baseline
# 20759          183.0      0.00915       11599246          baseline
# 20760         1165.0      0.05825       11599246          baseline
# 20761         7188.0      0.35940       11599246          baseline
# 20762          723.0      0.03615       11599246          baseline
# 20763          710.0      0.03550       11599246          baseline

# %% [markdown]
# - Removing duplicate columns

# %%
all_trials_df = all_trials_df.drop_duplicates(subset=["recording_file", "time_stamp_index"], keep="first").reset_index()

# %% [markdown]
# - Merging the trial and spike timestamp dataframe based on shared recording and trial timestamp

# %%
merged_spike_trial_df = pd.merge(left=all_spike_time_df, right=all_trials_df, left_on=["recording_name", "closest_trial"], right_on=["recording_file", "time_stamp_index"], how="inner")

# %%
merged_spike_trial_df["timestamp_bin"] = merged_spike_trial_df.apply(lambda row: np.digitize(row["spike_times"], row["trial_chunked_ephys_timestamp"]) - 101, axis=1)

# %%
merged_spike_trial_df.head()
# Out:
#    spike_clusters  spike_times  cluster_id  1_5_ms_isi  1ms_isi  2ms_isi  \
# 0             103     11399273         103          12        2       32
# 1              83     11399416          83           9        3       26
# 2              65     11399798          65           2        1        3
# 3             103     11399996         103          12        2       32
# 4             103     11400706         103          12        2       32
#
#          amp  ch  channel_group  depth  ...  condition  \
# 0  14.402934   6            0.0  120.0  ...        1.4
# 1  13.022879   2            0.0   40.0  ...        1.4
# 2   8.466800   2            0.0   40.0  ...        1.4
# 3  14.402934   6            0.0  120.0  ...        1.4
# 4  14.402934   6            0.0  120.0  ...        1.4
#
#     competition_closeness  Unnamed: 13  resampled_index  all_subjects  \
# 0  Subj 2 blocking Subj 1          NaN           579962    [1.4, 1.1]
# 1  Subj 2 blocking Subj 1          NaN           579962    [1.4, 1.1]
# 2  Subj 2 blocking Subj 1          NaN           579962    [1.4, 1.1]
# 3  Subj 2 blocking Subj 1          NaN           579962    [1.4, 1.1]
# 4  Subj 2 blocking Subj 1          NaN           579962    [1.4, 1.1]
#
#   current_subject  trial_outcome  trial_number  \
# 0             1.4            win             1
# 1             1.4            win             1
# 2             1.4            win             1
# 3             1.4            win             1
# 4             1.4            win             1
#
#                        trial_chunked_ephys_timestamp timestamp_bin
# 0  [11399246, 11401246, 11403246, 11405246, 11407...          -100
# 1  [11399246, 11401246, 11403246, 11405246, 11407...          -100
# 2  [11399246, 11401246, 11403246, 11405246, 11407...          -100
# 3  [11399246, 11401246, 11403246, 11405246, 11407...          -100
# 4  [11399246, 11401246, 11403246, 11405246, 11407...          -100
#
# [5 rows x 41 columns]

# %%
merged_spike_trial_df.tail()
# Out:
#         spike_clusters  spike_times  cluster_id  1_5_ms_isi  1ms_isi  2ms_isi  \
# 295736             262     38675317         262           1        1        1
# 295737              44     38675962          44           3        1       29
# 295738             262     38676329         262           1        1        1
# 295739             134     38677144         134           5        4       17
# 295740             134     38677446         134           5        4       17
#
#               amp  ch  channel_group  depth  ...  condition  \
# 295736  11.366614   6            0.0  120.0  ...   rewarded
# 295737   9.739503  17            0.0  340.0  ...   rewarded
# 295738  11.366614   6            0.0  120.0  ...   rewarded
# 295739   8.562255   2            0.0   40.0  ...   rewarded
# 295740   8.562255   2            0.0   40.0  ...   rewarded
#
#        competition_closeness  Unnamed: 13  resampled_index  all_subjects  \
# 295736                                NaN          1923872    [1.2, 1.4]
# 295737                                NaN          1923872    [1.2, 1.4]
# 295738                                NaN          1923872    [1.2, 1.4]
# 295739                                NaN          1923872    [1.2, 1.4]
# 295740                                NaN          1923872    [1.2, 1.4]
#
#        current_subject  trial_outcome  trial_number  \
# 295736             1.4       rewarded            16
# 295737             1.4       rewarded            16
# 295738             1.4       rewarded            16
# 295739             1.4       rewarded            16
# 295740             1.4       rewarded            16
#
#                             trial_chunked_ephys_timestamp timestamp_bin
# 295736  [38277451, 38279451, 38281451, 38283451, 38285...            98
# 295737  [38277451, 38279451, 38281451, 38283451, 38285...            99
# 295738  [38277451, 38279451, 38281451, 38283451, 38285...            99
# 295739  [38277451, 38279451, 38281451, 38283451, 38285...            99
# 295740  [38277451, 38279451, 38281451, 38283451, 38285...            99
#
# [5 rows x 41 columns]

# %%
merged_spike_trial_df["relative_time_to_tone"] = merged_spike_trial_df["spike_times"] - merged_spike_trial_df["closest_trial"]

# %%
merged_spike_trial_df["relative_time_to_tone"]
# Out:
# 0        -199973
# 1        -199830
# 2        -199448
# 3        -199250
# 4        -198540
#            ...
# 295736    197866
# 295737    198511
# 295738    198878
# 295739    199693
# 295740    199995
# Name: relative_time_to_tone, Length: 295741, dtype: int64

# %%
merged_spike_trial_df["recording_file"].unique()
# Out:
# array(['20230618_100636_standard_comp_to_omission_D2_subj_1_4_t4b3L_box1_merged',
#        '20221202_134600_omission_and_competition_subject_6_1_top_2_base_3_merged',
#        '20230618_100636_standard_comp_to_omission_D2_subj_1_1_t1b2L_box2_merged',
#        '20221203_154800_omission_and_competition_subject_6_1_top_1_base_3_merged',
#        '20230621_111240_standard_comp_to_omission_D5_subj_1-4_t3b3L_box1_merged',
#        '20230620_114347_standard_comp_to_omission_D4_subj_1-1_t1b2L_box_2_merged',
#        '20230617_115521_standard_comp_to_omission_D1_subj_1-2_t2b2L_box2_merged',
#        '20230617_115521_standard_comp_to_omission_D1_subj_1-1_t1b3L_box1_merged',
#        '20230620_114347_standard_comp_to_omission_D4_subj_1-2_t3b3L_box_1_merged',
#        '20230619_115321_standard_comp_to_omission_D3_subj_1-4_t3b3L_box2_merged'],
#       dtype=object)

# %%
merged_spike_trial_df.head()
# Out:
#    spike_clusters  spike_times  cluster_id  1_5_ms_isi  1ms_isi  2ms_isi  \
# 0             103     11399273         103          12        2       32
# 1              83     11399416          83           9        3       26
# 2              65     11399798          65           2        1        3
# 3             103     11399996         103          12        2       32
# 4             103     11400706         103          12        2       32
#
#          amp  ch  channel_group  depth  ...   competition_closeness  \
# 0  14.402934   6            0.0  120.0  ...  Subj 2 blocking Subj 1
# 1  13.022879   2            0.0   40.0  ...  Subj 2 blocking Subj 1
# 2   8.466800   2            0.0   40.0  ...  Subj 2 blocking Subj 1
# 3  14.402934   6            0.0  120.0  ...  Subj 2 blocking Subj 1
# 4  14.402934   6            0.0  120.0  ...  Subj 2 blocking Subj 1
#
#   Unnamed: 13  resampled_index  all_subjects  current_subject trial_outcome  \
# 0         NaN           579962    [1.4, 1.1]              1.4           win
# 1         NaN           579962    [1.4, 1.1]              1.4           win
# 2         NaN           579962    [1.4, 1.1]              1.4           win
# 3         NaN           579962    [1.4, 1.1]              1.4           win
# 4         NaN           579962    [1.4, 1.1]              1.4           win
#
#    trial_number                      trial_chunked_ephys_timestamp  \
# 0             1  [11399246, 11401246, 11403246, 11405246, 11407...
# 1             1  [11399246, 11401246, 11403246, 11405246, 11407...
# 2             1  [11399246, 11401246, 11403246, 11405246, 11407...
# 3             1  [11399246, 11401246, 11403246, 11405246, 11407...
# 4             1  [11399246, 11401246, 11403246, 11405246, 11407...
#
#    timestamp_bin relative_time_to_tone
# 0           -100               -199973
# 1           -100               -199830
# 2           -100               -199448
# 3           -100               -199250
# 4           -100               -198540
#
# [5 rows x 42 columns]

# %%
merged_spike_trial_df
# Out:
#         spike_clusters  spike_times  cluster_id  1_5_ms_isi  1ms_isi  2ms_isi  \
# 0                  103     11399273         103          12        2       32
# 1                   83     11399416          83           9        3       26
# 2                   65     11399798          65           2        1        3
# 3                  103     11399996         103          12        2       32
# 4                  103     11400706         103          12        2       32
# ...                ...          ...         ...         ...      ...      ...
# 295736             262     38675317         262           1        1        1
# 295737              44     38675962          44           3        1       29
# 295738             262     38676329         262           1        1        1
# 295739             134     38677144         134           5        4       17
# 295740             134     38677446         134           5        4       17
#
#               amp  ch  channel_group  depth  ...   competition_closeness  \
# 0       14.402934   6            0.0  120.0  ...  Subj 2 blocking Subj 1
# 1       13.022879   2            0.0   40.0  ...  Subj 2 blocking Subj 1
# 2        8.466800   2            0.0   40.0  ...  Subj 2 blocking Subj 1
# 3       14.402934   6            0.0  120.0  ...  Subj 2 blocking Subj 1
# 4       14.402934   6            0.0  120.0  ...  Subj 2 blocking Subj 1
# ...           ...  ..            ...    ...  ...                     ...
# 295736  11.366614   6            0.0  120.0  ...
# 295737   9.739503  17            0.0  340.0  ...
# 295738  11.366614   6            0.0  120.0  ...
# 295739   8.562255   2            0.0   40.0  ...
# 295740   8.562255   2            0.0   40.0  ...
#
#        Unnamed: 13  resampled_index  all_subjects  current_subject  \
# 0              NaN           579962    [1.4, 1.1]              1.4
# 1              NaN           579962    [1.4, 1.1]              1.4
# 2              NaN           579962    [1.4, 1.1]              1.4
# 3              NaN           579962    [1.4, 1.1]              1.4
# 4              NaN           579962    [1.4, 1.1]              1.4
# ...            ...              ...           ...              ...
# 295736         NaN          1923872    [1.2, 1.4]              1.4
# 295737         NaN          1923872    [1.2, 1.4]              1.4
# 295738         NaN          1923872    [1.2, 1.4]              1.4
# 295739         NaN          1923872    [1.2, 1.4]              1.4
# 295740         NaN          1923872    [1.2, 1.4]              1.4
#
#        trial_outcome  trial_number  \
# 0                win             1
# 1                win             1
# 2                win             1
# 3                win             1
# 4                win             1
# ...              ...           ...
# 295736      rewarded            16
# 295737      rewarded            16
# 295738      rewarded            16
# 295739      rewarded            16
# 295740      rewarded            16
#
#                             trial_chunked_ephys_timestamp  timestamp_bin  \
# 0       [11399246, 11401246, 11403246, 11405246, 11407...           -100
# 1       [11399246, 11401246, 11403246, 11405246, 11407...           -100
# 2       [11399246, 11401246, 11403246, 11405246, 11407...           -100
# 3       [11399246, 11401246, 11403246, 11405246, 11407...           -100
# 4       [11399246, 11401246, 11403246, 11405246, 11407...           -100
# ...                                                   ...            ...
# 295736  [38277451, 38279451, 38281451, 38283451, 38285...             98
# 295737  [38277451, 38279451, 38281451, 38283451, 38285...             99
# 295738  [38277451, 38279451, 38281451, 38283451, 38285...             99
# 295739  [38277451, 38279451, 38281451, 38283451, 38285...             99
# 295740  [38277451, 38279451, 38281451, 38283451, 38285...             99
#
#        relative_time_to_tone
# 0                    -199973
# 1                    -199830
# 2                    -199448
# 3                    -199250
# 4                    -198540
# ...                      ...
# 295736                197866
# 295737                198511
# 295738                198878
# 295739                199693
# 295740                199995
#
# [295741 rows x 42 columns]

# %%
merged_spike_trial_df.columns
# Out:
# Index(['spike_clusters', 'spike_times', 'cluster_id', '1_5_ms_isi', '1ms_isi',
#        '2ms_isi', 'amp', 'ch', 'channel_group', 'depth', 'fr', 'group',
#        'n_spikes', 'sh', 'si_unit_id', 'recording_name', 'timestamp_isi',
#        'current_isi', 'closest_trial', 'trial_or_baseline', 'index', 'time',
#        'state', 'recording_dir', 'recording_file', 'din', 'time_stamp_index',
#        'video_file', 'video_frame', 'video_number', 'subject_info',
#        'condition', 'competition_closeness', 'Unnamed: 13', 'resampled_index',
#        'all_subjects', 'current_subject', 'trial_outcome', 'trial_number',
#        'trial_chunked_ephys_timestamp', 'timestamp_bin',
#        'relative_time_to_tone'],
#       dtype='object')

# %%
merged_spike_trial_df.to_pickle("./proc/merged_spike_trial.pkl")

# %%
from collections import defaultdict

# %%
total_number_of_trials_dict = all_trials_df.groupby(["recording_file", "trial_outcome"]).count()["index"].to_dict()

# %%
total_number_of_trials_dict
# Out:
# {('20221202_134600_omission_and_competition_subject_6_1_top_2_base_3_merged',
#   'omission'): 3,
#  ('20221202_134600_omission_and_competition_subject_6_1_top_2_base_3_merged',
#   'rewarded'): 11,
#  ('20221203_154800_omission_and_competition_subject_6_1_top_1_base_3_merged',
#   'omission'): 3,
#  ('20221203_154800_omission_and_competition_subject_6_1_top_1_base_3_merged',
#   'rewarded'): 11,
#  ('20221203_154800_omission_and_competition_subject_6_1_top_1_base_3_merged',
#   'win'): 4,
#  ('20221214_125409_om_and_comp_6_1_top_1_base_2_vs_6_3', 'omission'): 3,
#  ('20221214_125409_om_and_comp_6_1_top_1_base_2_vs_6_3', 'rewarded'): 11,
#  ('20221215_145401_comp_amd_om_6_1_top_4_base_3', 'omission'): 3,
#  ('20221215_145401_comp_amd_om_6_1_top_4_base_3', 'rewarded'): 11,
#  ('20230612_101430_standard_comp_to_training_D1_subj_1-3_t3b3L_box2_merged',
#   'lose'): 1,
#  ('20230612_101430_standard_comp_to_training_D1_subj_1-3_t3b3L_box2_merged',
#   'rewarded'): 20,
#  ('20230612_101430_standard_comp_to_training_D1_subj_1-3_t3b3L_box2_merged',
#   'win'): 8,
#  ('20230612_101430_standard_comp_to_training_D1_subj_1-4_t4b2L_box1_merged',
#   'lose'): 8,
#  ('20230612_101430_standard_comp_to_training_D1_subj_1-4_t4b2L_box1_merged',
#   'rewarded'): 20,
#  ('20230612_101430_standard_comp_to_training_D1_subj_1-4_t4b2L_box1_merged',
#   'win'): 1,
#  ('20230617_115521_standard_comp_to_omission_D1_subj_1-1_t1b3L_box1_merged',
#   'lose'): 1,
#  ('20230617_115521_standard_comp_to_omission_D1_subj_1-1_t1b3L_box1_merged',
#   'win'): 14,
#  ('20230617_115521_standard_comp_to_omission_D1_subj_1-2_t2b2L_box2_merged',
#   'lose'): 14,
#  ('20230617_115521_standard_comp_to_omission_D1_subj_1-2_t2b2L_box2_merged',
#   'win'): 1,
#  ('20230618_100636_standard_comp_to_omission_D2_subj_1_1_t1b2L_box2_merged',
#   'lose'): 3,
#  ('20230618_100636_standard_comp_to_omission_D2_subj_1_1_t1b2L_box2_merged',
#   'omission'): 3,
#  ('20230618_100636_standard_comp_to_omission_D2_subj_1_1_t1b2L_box2_merged',
#   'rewarded'): 15,
#  ('20230618_100636_standard_comp_to_omission_D2_subj_1_1_t1b2L_box2_merged',
#   'win'): 6,
#  ('20230618_100636_standard_comp_to_omission_D2_subj_1_4_t4b3L_box1_merged',
#   'lose'): 6,
#  ('20230618_100636_standard_comp_to_omission_D2_subj_1_4_t4b3L_box1_merged',
#   'omission'): 3,
#  ('20230618_100636_standard_comp_to_omission_D2_subj_1_4_t4b3L_box1_merged',
#   'rewarded'): 17,
#  ('20230618_100636_standard_comp_to_omission_D2_subj_1_4_t4b3L_box1_merged',
#   'win'): 3,
#  ('20230619_115321_standard_comp_to_omission_D3_subj_1-4_t3b3L_box2_merged',
#   'lose'): 12,
#  ('20230619_115321_standard_comp_to_omission_D3_subj_1-4_t3b3L_box2_merged',
#   'rewarded'): 6,
#  ('20230620_114347_standard_comp_to_omission_D4_subj_1-1_t1b2L_box_2_merged',
#   'lose'): 4,
#  ('20230620_114347_standard_comp_to_omission_D4_subj_1-1_t1b2L_box_2_merged',
#   'omission'): 4,
#  ('20230620_114347_standard_comp_to_omission_D4_subj_1-1_t1b2L_box_2_merged',
#   'rewarded'): 16,
#  ('20230620_114347_standard_comp_to_omission_D4_subj_1-1_t1b2L_box_2_merged',
#   'win'): 7,
#  ('20230620_114347_standard_comp_to_omission_D4_subj_1-2_t3b3L_box_1_merged',
#   'lose'): 7,
#  ('20230620_114347_standard_comp_to_omission_D4_subj_1-2_t3b3L_box_1_merged',
#   'omission'): 4,
#  ('20230620_114347_standard_comp_to_omission_D4_subj_1-2_t3b3L_box_1_merged',
#   'rewarded'): 16,
#  ('20230620_114347_standard_comp_to_omission_D4_subj_1-2_t3b3L_box_1_merged',
#   'win'): 4,
#  ('20230621_111240_standard_comp_to_omission_D5_subj_1-4_t3b3L_box1_merged',
#   'lose'): 10,
#  ('20230621_111240_standard_comp_to_omission_D5_subj_1-4_t3b3L_box1_merged',
#   'omission'): 4,
#  ('20230621_111240_standard_comp_to_omission_D5_subj_1-4_t3b3L_box1_merged',
#   'rewarded'): 16}

# %%
grouped_df = merged_spike_trial_df.groupby(["recording_file", "trial_number", "spike_clusters", "trial_outcome"])['relative_time_to_tone'].agg(list).reset_index()

# Rename the aggregated column

# %%
grouped_df["total_number_of_trials"] = grouped_df.apply(lambda row: total_number_of_trials_dict[(row["recording_file"], row["trial_outcome"])], axis=1)

# %%
grouped_df
# Out:
#                                          recording_file  trial_number  \
# 0     20221202_134600_omission_and_competition_subje...             1
# 1     20221202_134600_omission_and_competition_subje...             1
# 2     20221202_134600_omission_and_competition_subje...             1
# 3     20221202_134600_omission_and_competition_subje...             1
# 4     20221202_134600_omission_and_competition_subje...             1
# ...                                                 ...           ...
# 3829  20230621_111240_standard_comp_to_omission_D5_s...            30
# 3830  20230621_111240_standard_comp_to_omission_D5_s...            30
# 3831  20230621_111240_standard_comp_to_omission_D5_s...            30
# 3832  20230621_111240_standard_comp_to_omission_D5_s...            30
# 3833  20230621_111240_standard_comp_to_omission_D5_s...            30
#
#       spike_clusters trial_outcome  \
# 0                 13      rewarded
# 1                 17      rewarded
# 2                 21      rewarded
# 3                 30      rewarded
# 4                 47      rewarded
# ...              ...           ...
# 3829              82      rewarded
# 3830              84      rewarded
# 3831              86      rewarded
# 3832              87      rewarded
# 3833              89      rewarded
#
#                                   relative_time_to_tone  \
# 0     [-198948, -198101, -196619, -195563, -186600, ...
# 1     [-199717, -195595, -193115, -190883, -187986, ...
# 2     [-199320, -197707, -196750, -196215, -195829, ...
# 3     [-198559, -195783, -193221, -189261, -180235, ...
# 4     [-190746, -190250, -64865, -36776, -5916, 4015...
# ...                                                 ...
# 3829                           [102971, 193802, 195159]
# 3830  [-131873, 84327, 132230, 148984, 149985, 15250...
# 3831  [-143711, 106766, 116691, 121007, 122168, 1243...
# 3832  [-189573, -163223, 60099, 105396, 109280, 1141...
# 3833  [-195325, -193408, -188085, -183830, -182541, ...
#
#       total_number_of_trials
# 0                         11
# 1                         11
# 2                         11
# 3                         11
# 4                         11
# ...                      ...
# 3829                      16
# 3830                      16
# 3831                      16
# 3832                      16
# 3833                      16
#
# [3834 rows x 6 columns]

# %%
example_file = grouped_df["recording_file"].unique()[1]
example_trial = grouped_df["trial_number"].unique()[3]

# %%
example_df = grouped_df[(grouped_df["recording_file"] == example_file) & (grouped_df["trial_number"] == example_trial)]

# %%
plt.eventplot(example_df["relative_time_to_tone"])
# Out:
# [<matplotlib.collections.EventCollection at 0x7fc4a6989cc0>,
#  <matplotlib.collections.EventCollection at 0x7fc4a698a620>,
#  <matplotlib.collections.EventCollection at 0x7fc4a698ab30>,
#  <matplotlib.collections.EventCollection at 0x7fc4a698af50>,
#  <matplotlib.collections.EventCollection at 0x7fc4a698b3d0>,
#  <matplotlib.collections.EventCollection at 0x7fc4a698bc70>]

# %% [markdown]
# # Calculating average firing rate

# %%
merged_spike_trial_df
# Out:
#         spike_clusters  spike_times  cluster_id  1_5_ms_isi  1ms_isi  2ms_isi  \
# 0                  103     11399273         103          12        2       32
# 1                   83     11399416          83           9        3       26
# 2                   65     11399798          65           2        1        3
# 3                  103     11399996         103          12        2       32
# 4                  103     11400706         103          12        2       32
# ...                ...          ...         ...         ...      ...      ...
# 295736             262     38675317         262           1        1        1
# 295737              44     38675962          44           3        1       29
# 295738             262     38676329         262           1        1        1
# 295739             134     38677144         134           5        4       17
# 295740             134     38677446         134           5        4       17
#
#               amp  ch  channel_group  depth  ...   competition_closeness  \
# 0       14.402934   6            0.0  120.0  ...  Subj 2 blocking Subj 1
# 1       13.022879   2            0.0   40.0  ...  Subj 2 blocking Subj 1
# 2        8.466800   2            0.0   40.0  ...  Subj 2 blocking Subj 1
# 3       14.402934   6            0.0  120.0  ...  Subj 2 blocking Subj 1
# 4       14.402934   6            0.0  120.0  ...  Subj 2 blocking Subj 1
# ...           ...  ..            ...    ...  ...                     ...
# 295736  11.366614   6            0.0  120.0  ...
# 295737   9.739503  17            0.0  340.0  ...
# 295738  11.366614   6            0.0  120.0  ...
# 295739   8.562255   2            0.0   40.0  ...
# 295740   8.562255   2            0.0   40.0  ...
#
#        Unnamed: 13  resampled_index  all_subjects  current_subject  \
# 0              NaN           579962    [1.4, 1.1]              1.4
# 1              NaN           579962    [1.4, 1.1]              1.4
# 2              NaN           579962    [1.4, 1.1]              1.4
# 3              NaN           579962    [1.4, 1.1]              1.4
# 4              NaN           579962    [1.4, 1.1]              1.4
# ...            ...              ...           ...              ...
# 295736         NaN          1923872    [1.2, 1.4]              1.4
# 295737         NaN          1923872    [1.2, 1.4]              1.4
# 295738         NaN          1923872    [1.2, 1.4]              1.4
# 295739         NaN          1923872    [1.2, 1.4]              1.4
# 295740         NaN          1923872    [1.2, 1.4]              1.4
#
#        trial_outcome  trial_number  \
# 0                win             1
# 1                win             1
# 2                win             1
# 3                win             1
# 4                win             1
# ...              ...           ...
# 295736      rewarded            16
# 295737      rewarded            16
# 295738      rewarded            16
# 295739      rewarded            16
# 295740      rewarded            16
#
#                             trial_chunked_ephys_timestamp  timestamp_bin  \
# 0       [11399246, 11401246, 11403246, 11405246, 11407...           -100
# 1       [11399246, 11401246, 11403246, 11405246, 11407...           -100
# 2       [11399246, 11401246, 11403246, 11405246, 11407...           -100
# 3       [11399246, 11401246, 11403246, 11405246, 11407...           -100
# 4       [11399246, 11401246, 11403246, 11405246, 11407...           -100
# ...                                                   ...            ...
# 295736  [38277451, 38279451, 38281451, 38283451, 38285...             98
# 295737  [38277451, 38279451, 38281451, 38283451, 38285...             99
# 295738  [38277451, 38279451, 38281451, 38283451, 38285...             99
# 295739  [38277451, 38279451, 38281451, 38283451, 38285...             99
# 295740  [38277451, 38279451, 38281451, 38283451, 38285...             99
#
#        relative_time_to_tone
# 0                    -199973
# 1                    -199830
# 2                    -199448
# 3                    -199250
# 4                    -198540
# ...                      ...
# 295736                197866
# 295737                198511
# 295738                198878
# 295739                199693
# 295740                199995
#
# [295741 rows x 42 columns]

# %%
grouped_df = merged_spike_trial_df.groupby(["recording_file", "timestamp_bin", "spike_clusters", "trial_outcome", "fr"]).count()[["spike_times"]].reset_index()
# Rename the aggregated column

# %%
grouped_df["total_number_of_trials"] = grouped_df.apply(lambda row: total_number_of_trials_dict[(row["recording_file"], row["trial_outcome"])], axis=1)

# %%
grouped_df["spike_times"] = grouped_df["spike_times"] / grouped_df["total_number_of_trials"] / grouped_df["fr"]

# %%
grouped_df
# Out:
#                                           recording_file  timestamp_bin  \
# 0      20221202_134600_omission_and_competition_subje...           -100
# 1      20221202_134600_omission_and_competition_subje...           -100
# 2      20221202_134600_omission_and_competition_subje...           -100
# 3      20221202_134600_omission_and_competition_subje...           -100
# 4      20221202_134600_omission_and_competition_subje...           -100
# ...                                                  ...            ...
# 58370  20230621_111240_standard_comp_to_omission_D5_s...             99
# 58371  20230621_111240_standard_comp_to_omission_D5_s...             99
# 58372  20230621_111240_standard_comp_to_omission_D5_s...             99
# 58373  20230621_111240_standard_comp_to_omission_D5_s...             99
# 58374  20230621_111240_standard_comp_to_omission_D5_s...             99
#
#        spike_clusters trial_outcome         fr  spike_times  \
# 0                  13      omission   5.425209     0.061442
# 1                  13      rewarded   5.425209     0.201081
# 2                  17      rewarded   1.787106     0.050869
# 3                  21      omission  12.246128     0.081658
# 4                  21      rewarded  12.246128     0.126199
# ...               ...           ...        ...          ...
# 58370              86      rewarded   0.805067     1.009233
# 58371              87          lose   0.622853     1.123861
# 58372              87      rewarded   0.622853     0.602069
# 58373              89      omission   3.099078     0.080669
# 58374              89      rewarded   3.099078     0.121004
#
#        total_number_of_trials
# 0                           3
# 1                          11
# 2                          11
# 3                           3
# 4                          11
# ...                       ...
# 58370                      16
# 58371                      10
# 58372                      16
# 58373                       4
# 58374                      16
#
# [58375 rows x 7 columns]

# %%
grouped_df["spike_times"].mean()
# Out:
# 0.17451846930669088

# %%
pivot_df = grouped_df.pivot_table(index=['recording_file', 'spike_clusters', 'trial_outcome'], columns='timestamp_bin', values='spike_times', fill_value=0).reset_index().set_index("spike_clusters")

# %%
pivot_df
# Out:
# timestamp_bin                                      recording_file  \
# spike_clusters
# 13              20221202_134600_omission_and_competition_subje...
# 13              20221202_134600_omission_and_competition_subje...
# 17              20221202_134600_omission_and_competition_subje...
# 17              20221202_134600_omission_and_competition_subje...
# 21              20221202_134600_omission_and_competition_subje...
# ...                                                           ...
# 87              20230621_111240_standard_comp_to_omission_D5_s...
# 87              20230621_111240_standard_comp_to_omission_D5_s...
# 89              20230621_111240_standard_comp_to_omission_D5_s...
# 89              20230621_111240_standard_comp_to_omission_D5_s...
# 89              20230621_111240_standard_comp_to_omission_D5_s...
#
# timestamp_bin  trial_outcome      -100       -99       -98       -97  \
# spike_clusters
# 13                  omission  0.061442  0.061442  0.122883  0.000000
# 13                  rewarded  0.201081  0.251352  0.117298  0.100541
# 17                  omission  0.000000  0.000000  0.000000  0.000000
# 17                  rewarded  0.050869  0.152608  0.254347  0.203478
# 21                  omission  0.081658  0.027219  0.136097  0.108878
# ...                      ...       ...       ...       ...       ...
# 87                  omission  0.000000  0.000000  0.000000  0.000000
# 87                  rewarded  0.100345  0.100345  0.100345  0.100345
# 89                      lose  0.096803  0.032268  0.129071  0.258141
# 89                  omission  0.080669  0.403346  0.242007  0.242007
# 89                  rewarded  0.141171  0.121004  0.161338  0.161338
#
# timestamp_bin        -96       -95       -94       -93  ...        90  \
# spike_clusters                                          ...
# 13              0.061442  0.000000  0.122883  0.061442  ...  0.061442
# 13              0.117298  0.083784  0.083784  0.201081  ...  0.117298
# 17              0.000000  0.000000  0.000000  0.000000  ...  0.373042
# 17              0.305217  0.254347  0.406955  0.203478  ...  0.305217
# 21              0.081658  0.217756  0.136097  0.244975  ...  0.081658
# ...                  ...       ...       ...       ...  ...       ...
# 87              0.000000  0.000000  0.000000  0.000000  ...  0.000000
# 87              0.100345  0.200690  0.100345  0.100345  ...  0.802758
# 89              0.032268  0.032268  0.064535  0.064535  ...  0.000000
# 89              0.242007  0.000000  0.000000  0.161338  ...  0.000000
# 89              0.080669  0.121004  0.201673  0.060502  ...  0.060502
#
# timestamp_bin         91        92        93        94        95        96  \
# spike_clusters
# 13              0.061442  0.061442  0.122883  0.122883  0.000000  0.061442
# 13              0.150811  0.117298  0.201081  0.117298  0.167568  0.134054
# 17              0.186521  0.186521  0.373042  0.373042  0.186521  0.186521
# 17              0.050869  0.101739  0.305217  0.203478  0.152608  0.203478
# 21              0.136097  0.081658  0.081658  0.081658  0.108878  0.163317
# ...                  ...       ...       ...       ...       ...       ...
# 87              0.000000  0.000000  0.000000  0.000000  0.401379  0.000000
# 87              0.602069  0.903103  0.401379  0.702413  0.602069  1.003448
# 89              0.000000  0.000000  0.000000  0.000000  0.032268  0.000000
# 89              0.242007  0.080669  0.161338  0.080669  0.080669  0.161338
# 89              0.040335  0.020167  0.040335  0.100836  0.080669  0.040335
#
# timestamp_bin         97        98        99
# spike_clusters
# 13              0.184325  0.000000  0.061442
# 13              0.033514  0.150811  0.150811
# 17              0.373042  0.559564  0.932606
# 17              0.152608  0.050869  0.050869
# 21              0.108878  0.136097  0.054439
# ...                  ...       ...       ...
# 87              0.000000  0.401379  0.000000
# 87              0.602069  0.501724  0.602069
# 89              0.000000  0.032268  0.000000
# 89              0.161338  0.242007  0.080669
# 89              0.020167  0.020167  0.121004
#
# [509 rows x 202 columns]

# %%
from matplotlib.colors import LogNorm, Normalize

# %%
for recording_file in pivot_df["recording_file"].unique():
    recording_df = pivot_df[pivot_df["recording_file"] == recording_file].copy()
    for outcome in recording_df["trial_outcome"].unique():
        outcome_df = recording_df[recording_df["trial_outcome"] == outcome].drop(columns=["recording_file", "trial_outcome"])
        
        sns.heatmap(outcome_df, annot=False, cmap='rocket_r', cbar_kws={'label': 'Firing Rate'}, norm=LogNorm())
        
        # Customizing the plot
        plt.title('Neuronal Firing Rates {} {}'.format(outcome, recording_file))
        plt.xlabel('Time Bin')
        plt.ylabel('Neuron ID')
        
        # Show the plot
        plt.show()

# %% [markdown]
# # Plotting PCA

# %%
merged_spike_trial_df["unique_neuron"] = "id" + merged_spike_trial_df["spike_clusters"].astype(str) + "_" + merged_spike_trial_df["recording_file"]

merged_spike_trial_df["time_bin_and_outcome"] = merged_spike_trial_df["timestamp_bin"].astype(str) + "_" + merged_spike_trial_df["trial_outcome"]

# %%
grouped_df = merged_spike_trial_df.groupby(["time_bin_and_outcome", "unique_neuron", "recording_file", "trial_outcome"]).count()[["spike_times"]].reset_index()
# Rename the aggregated column

# %%
grouped_df
# Out:
#       time_bin_and_outcome                                      unique_neuron  \
# 0                -100_lose  id100_20230617_115521_standard_comp_to_omissio...
# 1                -100_lose  id103_20230618_100636_standard_comp_to_omissio...
# 2                -100_lose  id105_20230617_115521_standard_comp_to_omissio...
# 3                -100_lose  id105_20230618_100636_standard_comp_to_omissio...
# 4                -100_lose  id106_20230618_100636_standard_comp_to_omissio...
# ...                    ...                                                ...
# 58370                9_win  id89_20230620_114347_standard_comp_to_omission...
# 58371                9_win  id90_20230618_100636_standard_comp_to_omission...
# 58372                9_win  id98_20230620_114347_standard_comp_to_omission...
# 58373                9_win  id99_20230618_100636_standard_comp_to_omission...
# 58374                9_win  id9_20230618_100636_standard_comp_to_omission_...
#
#                                           recording_file trial_outcome  \
# 0      20230617_115521_standard_comp_to_omission_D1_s...          lose
# 1      20230618_100636_standard_comp_to_omission_D2_s...          lose
# 2      20230617_115521_standard_comp_to_omission_D1_s...          lose
# 3      20230618_100636_standard_comp_to_omission_D2_s...          lose
# 4      20230618_100636_standard_comp_to_omission_D2_s...          lose
# ...                                                  ...           ...
# 58370  20230620_114347_standard_comp_to_omission_D4_s...           win
# 58371  20230618_100636_standard_comp_to_omission_D2_s...           win
# 58372  20230620_114347_standard_comp_to_omission_D4_s...           win
# 58373  20230618_100636_standard_comp_to_omission_D2_s...           win
# 58374  20230618_100636_standard_comp_to_omission_D2_s...           win
#
#        spike_times
# 0                2
# 1                9
# 2                1
# 3                1
# 4                1
# ...            ...
# 58370            5
# 58371            3
# 58372            1
# 58373            1
# 58374            1
#
# [58375 rows x 5 columns]

# %%
grouped_df["total_number_of_trials"] = grouped_df.apply(lambda row: total_number_of_trials_dict[(row["recording_file"], row["trial_outcome"])], axis=1)

# %%
grouped_df["spike_times"] = grouped_df["spike_times"] / grouped_df["total_number_of_trials"]

# %%
grouped_df["spike_times"].mean()
# Out:
# 0.625234845131356

# %%
pivot_df = grouped_df.pivot_table(index=['unique_neuron'], columns='time_bin_and_outcome', values='spike_times', fill_value=0).reset_index().set_index("unique_neuron")

# %%
pivot_df.head()
# Out:
# time_bin_and_outcome                                -100_lose  -100_omission  \
# unique_neuron
# id100_20230617_115521_standard_comp_to_omission...   0.142857            0.0
# id100_20230620_114347_standard_comp_to_omission...   0.000000            0.0
# id103_20230618_100636_standard_comp_to_omission...   1.500000            0.0
# id105_20230617_115521_standard_comp_to_omission...   0.071429            0.0
# id105_20230618_100636_standard_comp_to_omission...   0.166667            0.0
#
# time_bin_and_outcome                                -100_rewarded  -100_win  \
# unique_neuron
# id100_20230617_115521_standard_comp_to_omission...       0.000000       0.0
# id100_20230620_114347_standard_comp_to_omission...       0.125000       0.0
# id103_20230618_100636_standard_comp_to_omission...       0.470588       1.0
# id105_20230617_115521_standard_comp_to_omission...       0.000000       0.0
# id105_20230618_100636_standard_comp_to_omission...       0.000000       0.0
#
# time_bin_and_outcome                                -10_lose  -10_omission  \
# unique_neuron
# id100_20230617_115521_standard_comp_to_omission...  0.000000           0.0
# id100_20230620_114347_standard_comp_to_omission...  0.000000           0.0
# id103_20230618_100636_standard_comp_to_omission...  0.666667           0.0
# id105_20230617_115521_standard_comp_to_omission...  0.142857           0.0
# id105_20230618_100636_standard_comp_to_omission...  0.333333           0.0
#
# time_bin_and_outcome                                -10_rewarded   -10_win  \
# unique_neuron
# id100_20230617_115521_standard_comp_to_omission...      0.000000  0.000000
# id100_20230620_114347_standard_comp_to_omission...      0.062500  0.000000
# id103_20230618_100636_standard_comp_to_omission...      0.235294  0.666667
# id105_20230617_115521_standard_comp_to_omission...      0.000000  0.000000
# id105_20230618_100636_standard_comp_to_omission...      0.000000  0.000000
#
# time_bin_and_outcome                                -11_lose  -11_omission  \
# unique_neuron
# id100_20230617_115521_standard_comp_to_omission...  0.071429           0.0
# id100_20230620_114347_standard_comp_to_omission...  0.000000           0.5
# id103_20230618_100636_standard_comp_to_omission...  1.000000           1.0
# id105_20230617_115521_standard_comp_to_omission...  0.071429           0.0
# id105_20230618_100636_standard_comp_to_omission...  0.333333           0.0
#
# time_bin_and_outcome                                ...  98_rewarded  98_win  \
# unique_neuron                                       ...
# id100_20230617_115521_standard_comp_to_omission...  ...     0.000000     0.0
# id100_20230620_114347_standard_comp_to_omission...  ...     0.000000     0.0
# id103_20230618_100636_standard_comp_to_omission...  ...     1.176471     1.0
# id105_20230617_115521_standard_comp_to_omission...  ...     0.000000     0.0
# id105_20230618_100636_standard_comp_to_omission...  ...     0.000000     0.0
#
# time_bin_and_outcome                                 99_lose  99_omission  \
# unique_neuron
# id100_20230617_115521_standard_comp_to_omission...  0.000000          0.0
# id100_20230620_114347_standard_comp_to_omission...  0.000000          0.0
# id103_20230618_100636_standard_comp_to_omission...  1.500000          0.0
# id105_20230617_115521_standard_comp_to_omission...  0.000000          0.0
# id105_20230618_100636_standard_comp_to_omission...  0.166667          0.0
#
# time_bin_and_outcome                                99_rewarded    99_win  \
# unique_neuron
# id100_20230617_115521_standard_comp_to_omission...     0.000000  0.000000
# id100_20230620_114347_standard_comp_to_omission...     0.000000  0.000000
# id103_20230618_100636_standard_comp_to_omission...     1.176471  1.333333
# id105_20230617_115521_standard_comp_to_omission...     0.000000  0.000000
# id105_20230618_100636_standard_comp_to_omission...     0.000000  0.000000
#
# time_bin_and_outcome                                  9_lose  9_omission  \
# unique_neuron
# id100_20230617_115521_standard_comp_to_omission...  0.000000        0.00
# id100_20230620_114347_standard_comp_to_omission...  0.000000        0.25
# id103_20230618_100636_standard_comp_to_omission...  0.833333        0.00
# id105_20230617_115521_standard_comp_to_omission...  0.285714        0.00
# id105_20230618_100636_standard_comp_to_omission...  0.333333        0.00
#
# time_bin_and_outcome                                9_rewarded  9_win
# unique_neuron
# id100_20230617_115521_standard_comp_to_omission...       0.000    0.0
# id100_20230620_114347_standard_comp_to_omission...       0.125    0.0
# id103_20230618_100636_standard_comp_to_omission...       0.000    1.0
# id105_20230617_115521_standard_comp_to_omission...       0.000    0.0
# id105_20230618_100636_standard_comp_to_omission...       0.000    0.0
#
# [5 rows x 800 columns]

# %%
# performing preprocessing part
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
pivot_df.to_numpy()
# Out:
# array([[0.14285714, 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.125     , ..., 0.25      , 0.125     ,
#         0.        ],
#        [1.5       , 0.        , 0.47058824, ..., 0.        , 0.        ,
#         1.        ],
#        ...,
#        [1.        , 0.        , 0.25      , ..., 0.25      , 0.4375    ,
#         0.14285714],
#        [0.        , 1.        , 0.47058824, ..., 0.66666667, 0.64705882,
#         0.33333333],
#        [0.16666667, 0.        , 0.41176471, ..., 0.        , 0.17647059,
#         0.33333333]])

# %%
scaled_firing_rates = sc.fit_transform(pivot_df.to_numpy())

# %%
# Applying PCA function on training
# and testing set of X component
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components = 2)

# %%
pca_firing_rates = pca.fit_transform(scaled_firing_rates)

# %%
principal_df = pd.DataFrame(data = pca_firing_rates
             , columns = ['principal component 1', 'principal component 2'])

# %%
principal_df.head()
# Out:
#    principal component 1  principal component 2
# 0             -11.041674               3.564091
# 1              -8.219141               6.750606
# 2              16.798447             -21.356340
# 3             -10.606348               3.687117
# 4              -9.240245               3.406114

# %%
pc1_product = pivot_df.reset_index(drop=True).multiply(principal_df["principal component 1"], axis="index")

# %%
pc2_product = pivot_df.reset_index(drop=True).multiply(principal_df["principal component 2"], axis="index")

# %%
pc_product = pd.concat([pc1_product.mean(), pc2_product.mean()], axis=1).reset_index()

# %%
pc_product
# Out:
#     time_bin_and_outcome          0         1
# 0              -100_lose  11.628410 -3.009242
# 1          -100_omission  10.187785  1.337087
# 2          -100_rewarded  12.992737  1.789811
# 3               -100_win   3.786619 -3.501946
# 4               -10_lose  10.169209 -1.829922
# ..                   ...        ...       ...
# 795               99_win   3.455876 -3.708995
# 796               9_lose  11.309803 -0.924059
# 797           9_omission  11.461217  1.909803
# 798           9_rewarded  13.540893  1.784005
# 799                9_win   2.899913 -3.633947
#
# [800 rows x 3 columns]

# %%
pc_product["bin_time"] = pc_product["time_bin_and_outcome"].apply(lambda x: int(x.split("_")[0]))
pc_product["trial_type"] = pc_product["time_bin_and_outcome"].apply(lambda x: (x.split("_")[1]))

# %%
outcome_to_color = {"lose": "orange", "rewarded": "green", "win": "blue", "omission": "red"}

# %%
pc_product["color"] = pc_product["trial_type"].map(outcome_to_color)

# %%
pc_product
# Out:
#     time_bin_and_outcome          0         1  bin_time trial_type   color
# 0              -100_lose  11.628410 -3.009242      -100       lose  orange
# 1          -100_omission  10.187785  1.337087      -100   omission     red
# 2          -100_rewarded  12.992737  1.789811      -100   rewarded   green
# 3               -100_win   3.786619 -3.501946      -100        win    blue
# 4               -10_lose  10.169209 -1.829922       -10       lose  orange
# ..                   ...        ...       ...       ...        ...     ...
# 795               99_win   3.455876 -3.708995        99        win    blue
# 796               9_lose  11.309803 -0.924059         9       lose  orange
# 797           9_omission  11.461217  1.909803         9   omission     red
# 798           9_rewarded  13.540893  1.784005         9   rewarded   green
# 799                9_win   2.899913 -3.633947         9        win    blue
#
# [800 rows x 6 columns]

# %%
pc_product["bin_time"] = pc_product["bin_time"].astype(int)

all_outcome_df = []
for outcome in pc_product["trial_type"].unique():
    outcome_df = pc_product[pc_product["trial_type"] == outcome]
    outcome_df = outcome_df.sort_values(["bin_time"])
    outcome_df['0'] = outcome_df[0].rolling(10).mean()    
    outcome_df['1'] = outcome_df[1].rolling(10).mean()
    all_outcome_df.append(outcome_df)

# %%
pc_product = pd.concat(all_outcome_df).dropna()

# %%
pc_product
# Out:
#     time_bin_and_outcome          0         1  bin_time trial_type   color  \
# 360             -91_lose  10.883993 -1.202656       -91       lose  orange
# 356             -90_lose  10.311722 -0.793754       -90       lose  orange
# 348             -89_lose  11.892236 -1.306037       -89       lose  orange
# 344             -88_lose  12.196126 -0.507415       -88       lose  orange
# 340             -87_lose  13.305122 -1.900571       -87       lose  orange
# ..                   ...        ...       ...       ...        ...     ...
# 779               95_win   2.461727 -3.085625        95        win    blue
# 783               96_win   2.932898 -4.166835        96        win    blue
# 787               97_win   2.644491 -3.358496        97        win    blue
# 791               98_win   4.137074 -4.547845        98        win    blue
# 795               99_win   3.455876 -3.708995        99        win    blue
#
#              0         1
# 360  11.447102 -1.674205
# 356  11.315433 -1.452656
# 348  11.390635 -1.417977
# 344  11.544658 -1.251473
# 340  11.756716 -1.267522
# ..         ...       ...
# 779   2.796054 -3.454087
# 783   2.807771 -3.534761
# 787   2.811347 -3.559058
# 791   2.955210 -3.673984
# 795   3.032739 -3.688473
#
# [764 rows x 8 columns]

# %%
sigma = 3
divider = 5

# %%
# Create scatter plot
# plt.plot(pc_product[0], pc_product[1], color=pc_product["color"])

for outcome in pc_product["trial_type"].unique():
    
    outcome_df = pc_product[pc_product["trial_type"] == outcome].sort_values("bin_time")
    plt.scatter(outcome_df[0], outcome_df[1], color=outcome_to_color[outcome], alpha=0.1)
    
    smoothed_x = gaussian_filter1d(outcome_df[0][::divider], sigma=sigma)
    
    # smoothed_x = outcome_df[0].rolling(window=10).mean()[::10]
    smoothed_y = gaussian_filter1d(outcome_df[1][::divider], sigma=sigma)
    # smoothed_y = outcome_df[1].rolling(window=10).mean()[::10]

    plt.scatter(smoothed_x[0], smoothed_y[0], color=outcome_to_color[outcome], marker = 'o', s=100)
    plt.scatter(smoothed_x[len(smoothed_x)//2], smoothed_y[len(smoothed_y)//2], color=outcome_to_color[outcome], marker = '^', s=100)
    plt.scatter(smoothed_x[len(smoothed_x)-1], smoothed_y[len(smoothed_y)-1], color=outcome_to_color[outcome], marker = 's', s=100)

    
    # Create smoothed line plot
    plt.plot(smoothed_x, smoothed_y, color=outcome_to_color[outcome], ls=':', label=outcome, linewidth=3)

plt.legend()
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("PCA projection of neural activity (Square >> Triangle >> Circle)")
plt.savefig("./pca_rce.png")
# Show plot
plt.show()

# %%
raise ValueError()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 raise ValueError()
#
# ValueError:
