# %% [markdown]
# # Granger Causality

# %% [markdown]
# Brief 1-2 sentence description of notebook.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import os
import glob
from collections import defaultdict
import re

# %%
# Imports of all used packages and libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
from scipy import stats
import itertools
from scipy.stats import linregress

# %%
import spikeinterface.extractors as se
import spikeinterface.preprocessing as sp
from spectral_connectivity import Multitaper, Connectivity
import spectral_connectivity

# %%
from statsmodels.tsa.stattools import grangercausalitytests

# %% [markdown]
# ## Inputs & Data

# %% [markdown]
# Explanation of each input and where it comes from.

# %%
# Inputs and Required data loading
# input varaible names are in all caps snake case
# Whenever an input changes or is used for processing 
# the vairables are all lower in snake case

# %%
BBOX_TO_ANCHOR=(1.5, 0.9)
LOC='upper right'

# %%
ALL_BANDS = ["theta", "beta", "gamma"]
BAND_TO_FREQ = {"theta": {"low_freq": 4, "high_freq": 12}, "beta": {"low_freq": 13, "high_freq": 30}, "gamma": {"low_freq": 30, "high_freq": 70}}

# %%
# variables for LFP extraction
FREQ_MIN=0.5
FREQ_MAX=300
NOTCH_FREQ=60
ORIGINAL_SAMPLE_RATE = 20000
RESAMPLE_RATE=1000
TRIAL_DURATION=10

# %%
INPUT_VARIABLE = 1

TIME_HALFBANDWIDTH_PRODUCT = 2
TIME_WINDOW_DURATION = 3
TIME_WINDOW_STEP = 1.5 

TRIAL_TIME_STAMP_DURATION = 1000*10

# %%
BIN_TO_COLOR = {0: {"baseline": "lightblue", "trial": "blue"}, 1: {"baseline": "lightgreen", "trial": "green"}, 2: {"baseline": "lightcoral", "trial": "red"}}
TRIAL_OR_BASELINE_TO_STYLE = {'baseline': "--", "trial": "-"}
BIN_TO_VELOCITY = {0: "0 to 2.5cm/s", 1: "2.5 to 5cm/s", 2: "5cm/s+"}

# %%
NUM_LINES = 3

# %%
# Generate colors from the "Blues" colormap
LOSING_COLORS = cm.Oranges(np.linspace(0.5, 1, NUM_LINES))
# Generate colors from the "Blues" colormap
WINNING_COLORS = cm.Blues(np.linspace(0.5, 1, NUM_LINES))
# Generate colors from the "Blues" colormap
REWARDED_COLORS = cm.Greens(np.linspace(0.5, 1, NUM_LINES))
# Generate colors from the "Blues" colormap
OMISSION_COLORS = cm.Reds(np.linspace(0.5, 1, NUM_LINES))

# %%
BASELINE_OUTCOME_TO_COLOR = {'lose': "orange",
 'lose_baseline': LOSING_COLORS[0],
 'omission': "red",
 'omission_baseline': "hotpink",
 'rewarded': "green",
 'rewarded_baseline': REWARDED_COLORS[0],
 'win': "blue",
 'win_baseline': WINNING_COLORS[0]}

# %%
BASELINE_OUTCOME_TO_COLOR = {'lose_trial': "orange",
 'lose_baseline': LOSING_COLORS[0],
 'omission_trial': "red",
 'omission_baseline': "hotpink",
 'rewarded_trial': "green",
 'rewarded_baseline': REWARDED_COLORS[0],
 'win_trial': "blue",
 'win_baseline': WINNING_COLORS[0]}

# %%
COMPETITIVE_OUTCOME_TO_COLOR = {'lose_comp': "orange", 
'lose_non_comp': "yellow",
'omission': "red",
'rewarded': "green",
'win_comp': "blue", 
'win_non_comp': WINNING_COLORS[0]}

# %%
TRIAL_OR_BASELINE_TO_STYLE = {'baseline': "--", "trial": "-"}

# %%
CHANNEL_MAPPING_DF = pd.read_excel("../../channel_mapping.xlsx")
CHANNEL_MAPPING_DF["Subject"] = CHANNEL_MAPPING_DF["Subject"].astype(str)

TONE_TIMESTAMP_DF = pd.read_excel("../../rce_tone_timestamp.xlsx", index_col=0)
OUTPUT_DIR = r"./proc" # where data is saved should always be shown in the inputs

# %%
CHANNEL_MAPPING_DF = pd.read_excel("../../channel_mapping.xlsx")
CHANNEL_MAPPING_DF["Subject"] = CHANNEL_MAPPING_DF["Subject"].astype(str)

TONE_TIMESTAMP_DF = pd.read_excel("../../rce_tone_timestamp.xlsx", index_col=0)
OUTPUT_DIR = r"./proc" # where data is saved should always be shown in the inputs

# %%
FULL_LFP_TRACES = pd.read_pickle("./proc/full_baseline_and_trial_lfp_traces.pkl")

# %%
FULL_LFP_TRACES = FULL_LFP_TRACES.drop_duplicates(subset=["recording_file", "time"], keep="first")

# %%
GROUPINGS = "competition_closeness"

# %% [markdown]
# ## Outputs

# %% [markdown]
# Describe each output that the notebook creates.

# %% [markdown]
# - Is it a plot or is it data?

# %% [markdown]
# - How valuable is the output and why is it valuable or useful?

# %% [markdown]
# ## Functions

# %% [markdown]
# - Ideally functions are defined here first and then data is processed using the functions
#     - function names are short and in snake case all lowercase
#     - a function name should be unique but does not have to describe the function
#     - doc strings describe functions not function names

# %%
def generate_pairs(lst):
    pairs = []
    n = len(lst)
    for i in range(n):
        for j in range(i+1, n):
            pairs.append((lst[i], lst[j]))
    return pairs

# %%
def nested_dict():
    return defaultdict(dict)

triple_nested_dict = defaultdict(nested_dict)

# %% [markdown]
# ## Processing

# %% [markdown]
# Describe what is done to the data here and how inputs are manipulated to generate outputs.

# %%
# As much code and as many cells as required
# includes EDA and playing with data
# GO HAM!

# %% [markdown]
# ## Granger Causality

# %%
baseline_cols = FULL_LFP_TRACES.columns

# %%
brain_region_cols = [col for col in FULL_LFP_TRACES.columns if "spike_interface" in col]

# %%
brain_region_cols
# Out:
# ['spike_interface_mPFC',
#  'spike_interface_vHPC',
#  'spike_interface_BLA',
#  'spike_interface_LH',
#  'spike_interface_MD']

# %%
baseline_pairs = generate_pairs(sorted([col for col in FULL_LFP_TRACES.columns if "baseline_lfp_trace" in col]))
trial_pairs = generate_pairs(sorted([col for col in FULL_LFP_TRACES.columns if "trial_lfp_trace" in col]))

# %%
baseline_pairs
# Out:
# [('BLA_baseline_lfp_trace', 'LH_baseline_lfp_trace'),
#  ('BLA_baseline_lfp_trace', 'MD_baseline_lfp_trace'),
#  ('BLA_baseline_lfp_trace', 'mPFC_baseline_lfp_trace'),
#  ('BLA_baseline_lfp_trace', 'vHPC_baseline_lfp_trace'),
#  ('LH_baseline_lfp_trace', 'MD_baseline_lfp_trace'),
#  ('LH_baseline_lfp_trace', 'mPFC_baseline_lfp_trace'),
#  ('LH_baseline_lfp_trace', 'vHPC_baseline_lfp_trace'),
#  ('MD_baseline_lfp_trace', 'mPFC_baseline_lfp_trace'),
#  ('MD_baseline_lfp_trace', 'vHPC_baseline_lfp_trace'),
#  ('mPFC_baseline_lfp_trace', 'vHPC_baseline_lfp_trace')]

# %%
def get_granger(row, region_1, region_2, max_lag=3):
    """
    """
    try:
        return grangercausalitytests(np.hstack([row[region_1][np.newaxis].T, row[region_2][np.newaxis].T]), maxlag=[max_lag])[max_lag][0]["ssr_ftest"][0]
    except:
        return np.nan

# %%
MAX_LAG = 10

# %%
baseline_or_trial = "trial"
for region_1, region_2 in trial_pairs:
    region_1_name = region_1.split("_")[0]
    region_2_name = region_2.split("_")[0]
    
    
    FULL_LFP_TRACES["{}_{}_{}_granger".format(region_1_name, region_2_name, baseline_or_trial)] = FULL_LFP_TRACES.apply(lambda row: get_granger(row, region_1, region_2, max_lag=MAX_LAG), axis=1)

    FULL_LFP_TRACES["{}_{}_{}_granger".format(region_2_name, region_1_name, baseline_or_trial)] = FULL_LFP_TRACES.apply(lambda row: get_granger(row, region_2, region_1, max_lag=MAX_LAG), axis=1)
# Out:
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=27.2717 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=273.2910, p=0.0000  , df=10
# likelihood ratio test: chi2=269.6197, p=0.0000  , df=10
# parameter F test:         F=27.2717 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=23.2615 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=233.1050, p=0.0000  , df=10
# likelihood ratio test: chi2=230.4269, p=0.0000  , df=10
# parameter F test:         F=23.2615 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=20.0520 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=200.9424, p=0.0000  , df=10
# likelihood ratio test: chi2=198.9482, p=0.0000  , df=10
# parameter F test:         F=20.0520 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=24.5643 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=246.1602, p=0.0000  , df=10
# likelihood ratio test: chi2=243.1763, p=0.0000  , df=10
# parameter F test:         F=24.5643 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=29.1722 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=292.3370, p=0.0000  , df=10
# likelihood ratio test: chi2=288.1413, p=0.0000  , df=10
# parameter F test:         F=29.1722 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=20.4162 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=204.5917, p=0.0000  , df=10
# likelihood ratio test: chi2=202.5249, p=0.0000  , df=10
# parameter F test:         F=20.4162 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=26.0522 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=261.0705, p=0.0000  , df=10
# likelihood ratio test: chi2=257.7175, p=0.0000  , df=10
# parameter F test:         F=26.0522 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=16.8967 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=169.3225, p=0.0000  , df=10
# likelihood ratio test: chi2=167.9036, p=0.0000  , df=10
# parameter F test:         F=16.8967 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=17.7742 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=178.1167, p=0.0000  , df=10
# likelihood ratio test: chi2=176.5474, p=0.0000  , df=10
# parameter F test:         F=17.7742 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=23.2909 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=233.4000, p=0.0000  , df=10
# likelihood ratio test: chi2=230.7153, p=0.0000  , df=10
# parameter F test:         F=23.2909 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=20.6689 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=207.1240, p=0.0000  , df=10
# likelihood ratio test: chi2=205.0061, p=0.0000  , df=10
# parameter F test:         F=20.6689 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=14.4565 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=144.8695, p=0.0000  , df=10
# likelihood ratio test: chi2=143.8292, p=0.0000  , df=10
# parameter F test:         F=14.4565 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=15.6193 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=156.5225, p=0.0000  , df=10
# likelihood ratio test: chi2=155.3090, p=0.0000  , df=10
# parameter F test:         F=15.6193 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=15.6447 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=156.7765, p=0.0000  , df=10
# likelihood ratio test: chi2=155.5591, p=0.0000  , df=10
# parameter F test:         F=15.6447 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=15.9648 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=159.9841, p=0.0000  , df=10
# likelihood ratio test: chi2=158.7165, p=0.0000  , df=10
# parameter F test:         F=15.9648 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=26.0073 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=260.6207, p=0.0000  , df=10
# likelihood ratio test: chi2=257.2791, p=0.0000  , df=10
# parameter F test:         F=26.0073 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=23.4195 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=234.6881, p=0.0000  , df=10
# likelihood ratio test: chi2=231.9738, p=0.0000  , df=10
# parameter F test:         F=23.4195 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=22.6788 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=227.2658, p=0.0000  , df=10
# likelihood ratio test: chi2=224.7193, p=0.0000  , df=10
# parameter F test:         F=22.6788 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=14.1589 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=141.8876, p=0.0000  , df=10
# likelihood ratio test: chi2=140.8895, p=0.0000  , df=10
# parameter F test:         F=14.1589 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=19.0135 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=190.5356, p=0.0000  , df=10
# likelihood ratio test: chi2=188.7414, p=0.0000  , df=10
# parameter F test:         F=19.0135 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=16.4685 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=165.0322, p=0.0000  , df=10
# likelihood ratio test: chi2=163.6839, p=0.0000  , df=10
# parameter F test:         F=16.4685 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=6.1990  , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=62.1204 , p=0.0000  , df=10
# likelihood ratio test: chi2=61.9281 , p=0.0000  , df=10
# parameter F test:         F=6.1990  , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=34.1588 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=342.3072, p=0.0000  , df=10
# likelihood ratio test: chi2=336.5733, p=0.0000  , df=10
# parameter F test:         F=34.1588 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=40.5825 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=406.6797, p=0.0000  , df=10
# likelihood ratio test: chi2=398.6200, p=0.0000  , df=10
# parameter F test:         F=40.5825 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=12.6856 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=127.1237, p=0.0000  , df=10
# likelihood ratio test: chi2=126.3216, p=0.0000  , df=10
# parameter F test:         F=12.6856 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=50.1222 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=502.2778, p=0.0000  , df=10
# likelihood ratio test: chi2=490.0589, p=0.0000  , df=10
# parameter F test:         F=50.1222 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=51.3018 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=514.0990, p=0.0000  , df=10
# likelihood ratio test: chi2=501.3079, p=0.0000  , df=10
# parameter F test:         F=51.3018 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=36.8534 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=369.3100, p=0.0000  , df=10
# likelihood ratio test: chi2=362.6474, p=0.0000  , df=10
# parameter F test:         F=36.8534 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=48.9372 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=490.4026, p=0.0000  , df=10
# likelihood ratio test: chi2=478.7457, p=0.0000  , df=10
# parameter F test:         F=48.9372 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=30.1294 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=301.9287, p=0.0000  , df=10
# likelihood ratio test: chi2=297.4560, p=0.0000  , df=10
# parameter F test:         F=30.1294 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=57.6230 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=577.4438, p=0.0000  , df=10
# likelihood ratio test: chi2=561.3715, p=0.0000  , df=10
# parameter F test:         F=57.6230 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=38.2623 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=383.4287, p=0.0000  , df=10
# likelihood ratio test: chi2=376.2535, p=0.0000  , df=10
# parameter F test:         F=38.2623 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=59.7844 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=599.1030, p=0.0000  , df=10
# likelihood ratio test: chi2=581.8262, p=0.0000  , df=10
# parameter F test:         F=59.7844 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=56.4253 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=565.4413, p=0.0000  , df=10
# likelihood ratio test: chi2=550.0184, p=0.0000  , df=10
# parameter F test:         F=56.4253 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=52.2588 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=523.6884, p=0.0000  , df=10
# likelihood ratio test: chi2=510.4238, p=0.0000  , df=10
# parameter F test:         F=52.2588 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=36.3897 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=364.6640, p=0.0000  , df=10
# likelihood ratio test: chi2=358.1660, p=0.0000  , df=10
# parameter F test:         F=36.3897 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=38.2382 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=383.1875, p=0.0000  , df=10
# likelihood ratio test: chi2=376.0212, p=0.0000  , df=10
# parameter F test:         F=38.2382 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=33.3077 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=333.7789, p=0.0000  , df=10
# likelihood ratio test: chi2=328.3241, p=0.0000  , df=10
# parameter F test:         F=33.3077 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=43.1503 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=432.4120, p=0.0000  , df=10
# likelihood ratio test: chi2=423.3152, p=0.0000  , df=10
# parameter F test:         F=43.1503 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=17.2056 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=172.4189, p=0.0000  , df=10
# likelihood ratio test: chi2=170.9479, p=0.0000  , df=10
# parameter F test:         F=17.2056 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=83.5064 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=836.8233, p=0.0000  , df=10
# likelihood ratio test: chi2=803.6166, p=0.0000  , df=10
# parameter F test:         F=83.5064 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=34.3432 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=344.1554, p=0.0000  , df=10
# likelihood ratio test: chi2=338.3600, p=0.0000  , df=10
# parameter F test:         F=34.3432 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=25.0362 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=250.8890, p=0.0000  , df=10
# likelihood ratio test: chi2=247.7904, p=0.0000  , df=10
# parameter F test:         F=25.0362 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=26.0133 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=260.6814, p=0.0000  , df=10
# likelihood ratio test: chi2=257.3383, p=0.0000  , df=10
# parameter F test:         F=26.0133 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=18.9755 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=190.1548, p=0.0000  , df=10
# likelihood ratio test: chi2=188.3677, p=0.0000  , df=10
# parameter F test:         F=18.9755 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=33.9478 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=340.1934, p=0.0000  , df=10
# likelihood ratio test: chi2=334.5292, p=0.0000  , df=10
# parameter F test:         F=33.9478 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=21.8195 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=218.6544, p=0.0000  , df=10
# likelihood ratio test: chi2=216.2959, p=0.0000  , df=10
# parameter F test:         F=21.8195 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=23.6320 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=236.8178, p=0.0000  , df=10
# likelihood ratio test: chi2=234.0544, p=0.0000  , df=10
# parameter F test:         F=23.6320 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=27.2795 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=273.3696, p=0.0000  , df=10
# likelihood ratio test: chi2=269.6962, p=0.0000  , df=10
# parameter F test:         F=27.2795 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=31.0326 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=310.9797, p=0.0000  , df=10
# likelihood ratio test: chi2=306.2376, p=0.0000  , df=10
# parameter F test:         F=31.0326 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=19.0499 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=190.9006, p=0.0000  , df=10
# likelihood ratio test: chi2=189.0995, p=0.0000  , df=10
# parameter F test:         F=19.0499 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=18.7271 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=187.6659, p=0.0000  , df=10
# likelihood ratio test: chi2=185.9249, p=0.0000  , df=10
# parameter F test:         F=18.7271 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=20.9762 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=210.2039, p=0.0000  , df=10
# likelihood ratio test: chi2=208.0229, p=0.0000  , df=10
# parameter F test:         F=20.9762 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=20.6884 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=207.3199, p=0.0000  , df=10
# likelihood ratio test: chi2=205.1980, p=0.0000  , df=10
# parameter F test:         F=20.6884 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=22.3733 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=224.2042, p=0.0000  , df=10
# likelihood ratio test: chi2=221.7253, p=0.0000  , df=10
# parameter F test:         F=22.3733 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=18.0891 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=181.2721, p=0.0000  , df=10
# likelihood ratio test: chi2=179.6471, p=0.0000  , df=10
# parameter F test:         F=18.0891 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=19.0375 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=190.7758, p=0.0000  , df=10
# likelihood ratio test: chi2=188.9771, p=0.0000  , df=10
# parameter F test:         F=19.0375 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=50.7099 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=508.1671, p=0.0000  , df=10
# likelihood ratio test: chi2=495.6647, p=0.0000  , df=10
# parameter F test:         F=50.7099 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=15.9741 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=160.0778, p=0.0000  , df=10
# likelihood ratio test: chi2=158.8088, p=0.0000  , df=10
# parameter F test:         F=15.9741 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=31.9806 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=320.4795, p=0.0000  , df=10
# likelihood ratio test: chi2=315.4464, p=0.0000  , df=10
# parameter F test:         F=31.9806 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=24.6673 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=247.1930, p=0.0000  , df=10
# likelihood ratio test: chi2=244.1842, p=0.0000  , df=10
# parameter F test:         F=24.6673 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=22.8209 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=228.6895, p=0.0000  , df=10
# likelihood ratio test: chi2=226.1112, p=0.0000  , df=10
# parameter F test:         F=22.8209 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=23.4633 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=235.1277, p=0.0000  , df=10
# likelihood ratio test: chi2=232.4034, p=0.0000  , df=10
# parameter F test:         F=23.4633 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=16.8348 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=168.7028, p=0.0000  , df=10
# likelihood ratio test: chi2=167.2942, p=0.0000  , df=10
# parameter F test:         F=16.8348 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=22.7521 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=228.0000, p=0.0000  , df=10
# likelihood ratio test: chi2=225.4371, p=0.0000  , df=10
# parameter F test:         F=22.7521 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=22.6036 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=226.5122, p=0.0000  , df=10
# likelihood ratio test: chi2=223.9824, p=0.0000  , df=10
# parameter F test:         F=22.6036 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=12.4752 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=125.0150, p=0.0000  , df=10
# likelihood ratio test: chi2=124.2393, p=0.0000  , df=10
# parameter F test:         F=12.4752 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=22.1022 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=221.4872, p=0.0000  , df=10
# likelihood ratio test: chi2=219.0676, p=0.0000  , df=10
# parameter F test:         F=22.1022 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=23.1731 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=232.2189, p=0.0000  , df=10
# likelihood ratio test: chi2=229.5610, p=0.0000  , df=10
# parameter F test:         F=23.1731 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=12.0176 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=120.4294, p=0.0000  , df=10
# likelihood ratio test: chi2=119.7092, p=0.0000  , df=10
# parameter F test:         F=12.0176 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=24.2573 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=243.0837, p=0.0000  , df=10
# likelihood ratio test: chi2=240.1734, p=0.0000  , df=10
# parameter F test:         F=24.2573 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=15.4491 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=154.8169, p=0.0000  , df=10
# likelihood ratio test: chi2=153.6295, p=0.0000  , df=10
# parameter F test:         F=15.4491 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=18.6261 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=186.6532, p=0.0000  , df=10
# likelihood ratio test: chi2=184.9309, p=0.0000  , df=10
# parameter F test:         F=18.6261 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=14.2020 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=142.3194, p=0.0000  , df=10
# likelihood ratio test: chi2=141.3152, p=0.0000  , df=10
# parameter F test:         F=14.2020 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=16.0436 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=160.7742, p=0.0000  , df=10
# likelihood ratio test: chi2=159.4942, p=0.0000  , df=10
# parameter F test:         F=16.0436 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=17.6575 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=176.9469, p=0.0000  , df=10
# likelihood ratio test: chi2=175.3981, p=0.0000  , df=10
# parameter F test:         F=17.6575 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=22.2005 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=222.4726, p=0.0000  , df=10
# likelihood ratio test: chi2=220.0316, p=0.0000  , df=10
# parameter F test:         F=22.2005 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=12.0856 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=121.1110, p=0.0000  , df=10
# likelihood ratio test: chi2=120.3827, p=0.0000  , df=10
# parameter F test:         F=12.0856 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=30.2391 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=303.0281, p=0.0000  , df=10
# likelihood ratio test: chi2=298.5231, p=0.0000  , df=10
# parameter F test:         F=30.2391 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=33.1608 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=332.3064, p=0.0000  , df=10
# likelihood ratio test: chi2=326.8991, p=0.0000  , df=10
# parameter F test:         F=33.1608 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=26.8739 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=269.3053, p=0.0000  , df=10
# likelihood ratio test: chi2=265.7394, p=0.0000  , df=10
# parameter F test:         F=26.8739 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=45.5795 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=456.7556, p=0.0000  , df=10
# likelihood ratio test: chi2=446.6216, p=0.0000  , df=10
# parameter F test:         F=45.5795 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=48.9728 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=490.7600, p=0.0000  , df=10
# likelihood ratio test: chi2=479.0864, p=0.0000  , df=10
# parameter F test:         F=48.9728 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=15.8544 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=158.8780, p=0.0000  , df=10
# likelihood ratio test: chi2=157.6279, p=0.0000  , df=10
# parameter F test:         F=15.8544 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=13.7723 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=138.0136, p=0.0000  , df=10
# likelihood ratio test: chi2=137.0689, p=0.0000  , df=10
# parameter F test:         F=13.7723 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=17.6988 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=177.3605, p=0.0000  , df=10
# likelihood ratio test: chi2=175.8045, p=0.0000  , df=10
# parameter F test:         F=17.6988 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=18.9682 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=190.0816, p=0.0000  , df=10
# likelihood ratio test: chi2=188.2958, p=0.0000  , df=10
# parameter F test:         F=18.9682 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=20.1481 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=201.9058, p=0.0000  , df=10
# likelihood ratio test: chi2=199.8926, p=0.0000  , df=10
# parameter F test:         F=20.1481 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=13.7947 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=138.2373, p=0.0000  , df=10
# likelihood ratio test: chi2=137.2896, p=0.0000  , df=10
# parameter F test:         F=13.7947 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=23.3149 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=233.6405, p=0.0000  , df=10
# likelihood ratio test: chi2=230.9502, p=0.0000  , df=10
# parameter F test:         F=23.3149 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=21.6761 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=217.2174, p=0.0000  , df=10
# likelihood ratio test: chi2=214.8896, p=0.0000  , df=10
# parameter F test:         F=21.6761 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=26.3637 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=264.1920, p=0.0000  , df=10
# likelihood ratio test: chi2=260.7591, p=0.0000  , df=10
# parameter F test:         F=26.3637 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=24.6263 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=246.7820, p=0.0000  , df=10
# likelihood ratio test: chi2=243.7832, p=0.0000  , df=10
# parameter F test:         F=24.6263 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=19.2405 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=192.8104, p=0.0000  , df=10
# likelihood ratio test: chi2=190.9733, p=0.0000  , df=10
# parameter F test:         F=19.2405 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=10.3339 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=103.5569, p=0.0000  , df=10
# likelihood ratio test: chi2=103.0238, p=0.0000  , df=10
# parameter F test:         F=10.3339 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=37.6299 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=377.0917, p=0.0000  , df=10
# likelihood ratio test: chi2=370.1488, p=0.0000  , df=10
# parameter F test:         F=37.6299 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=21.9743 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=220.2061, p=0.0000  , df=10
# likelihood ratio test: chi2=217.8143, p=0.0000  , df=10
# parameter F test:         F=21.9743 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=36.1357 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=362.1180, p=0.0000  , df=10
# likelihood ratio test: chi2=355.7094, p=0.0000  , df=10
# parameter F test:         F=36.1357 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=29.6920 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=297.5459, p=0.0000  , df=10
# likelihood ratio test: chi2=293.2008, p=0.0000  , df=10
# parameter F test:         F=29.6920 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=35.6770 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=357.5214, p=0.0000  , df=10
# likelihood ratio test: chi2=351.2726, p=0.0000  , df=10
# parameter F test:         F=35.6770 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=53.7399 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=538.5310, p=0.0000  , df=10
# likelihood ratio test: chi2=524.5171, p=0.0000  , df=10
# parameter F test:         F=53.7399 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=40.5419 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=406.2729, p=0.0000  , df=10
# likelihood ratio test: chi2=398.2291, p=0.0000  , df=10
# parameter F test:         F=40.5419 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=39.4557 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=395.3878, p=0.0000  , df=10
# likelihood ratio test: chi2=387.7639, p=0.0000  , df=10
# parameter F test:         F=39.4557 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=49.2155 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=493.1913, p=0.0000  , df=10
# likelihood ratio test: chi2=481.4037, p=0.0000  , df=10
# parameter F test:         F=49.2155 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=55.3831 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=554.9980, p=0.0000  , df=10
# likelihood ratio test: chi2=540.1296, p=0.0000  , df=10
# parameter F test:         F=55.3831 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=45.6601 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=457.5629, p=0.0000  , df=10
# likelihood ratio test: chi2=447.3936, p=0.0000  , df=10
# parameter F test:         F=45.6601 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=36.6907 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=367.6803, p=0.0000  , df=10
# likelihood ratio test: chi2=361.0757, p=0.0000  , df=10
# parameter F test:         F=36.6907 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=39.4079 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=394.9092, p=0.0000  , df=10
# likelihood ratio test: chi2=387.3035, p=0.0000  , df=10
# parameter F test:         F=39.4079 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=39.2761 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=393.5883, p=0.0000  , df=10
# likelihood ratio test: chi2=386.0328, p=0.0000  , df=10
# parameter F test:         F=39.2761 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=74.4246 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=745.8137, p=0.0000  , df=10
# likelihood ratio test: chi2=719.2863, p=0.0000  , df=10
# parameter F test:         F=74.4246 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=34.3414 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=344.1376, p=0.0000  , df=10
# likelihood ratio test: chi2=338.3428, p=0.0000  , df=10
# parameter F test:         F=34.3414 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=31.2157 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=312.8144, p=0.0000  , df=10
# likelihood ratio test: chi2=308.0167, p=0.0000  , df=10
# parameter F test:         F=31.2157 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=70.3339 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=704.8209, p=0.0000  , df=10
# likelihood ratio test: chi2=681.0683, p=0.0000  , df=10
# parameter F test:         F=70.3339 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=32.6473 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=327.1604, p=0.0000  , df=10
# likelihood ratio test: chi2=321.9175, p=0.0000  , df=10
# parameter F test:         F=32.6473 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=25.6732 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=257.2728, p=0.0000  , df=10
# likelihood ratio test: chi2=254.0159, p=0.0000  , df=10
# parameter F test:         F=25.6732 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=37.9286 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=380.0846, p=0.0000  , df=10
# likelihood ratio test: chi2=373.0325, p=0.0000  , df=10
# parameter F test:         F=37.9286 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=58.1309 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=582.5337, p=0.0000  , df=10
# likelihood ratio test: chi2=566.1821, p=0.0000  , df=10
# parameter F test:         F=58.1309 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=29.6740 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=297.3648, p=0.0000  , df=10
# likelihood ratio test: chi2=293.0250, p=0.0000  , df=10
# parameter F test:         F=29.6740 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=187.1531, p=0.0000  , df_denom=9970, df_num=10
# ssr based chi2 test:   chi2=1875.4729, p=0.0000  , df=10
# likelihood ratio test: chi2=1718.7750, p=0.0000  , df=10
# parameter F test:         F=187.1531, p=0.0000  , df_denom=9970, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=26.4939 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=265.4974, p=0.0000  , df=10
# likelihood ratio test: chi2=262.0307, p=0.0000  , df=10
# parameter F test:         F=26.4939 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=18.3755 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=184.1421, p=0.0000  , df=10
# likelihood ratio test: chi2=182.4655, p=0.0000  , df=10
# parameter F test:         F=18.3755 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=25.0054 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=250.5806, p=0.0000  , df=10
# likelihood ratio test: chi2=247.4895, p=0.0000  , df=10
# parameter F test:         F=25.0054 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=21.7302 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=217.7599, p=0.0000  , df=10
# likelihood ratio test: chi2=215.4205, p=0.0000  , df=10
# parameter F test:         F=21.7302 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=17.8989 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=179.3660, p=0.0000  , df=10
# likelihood ratio test: chi2=177.7748, p=0.0000  , df=10
# parameter F test:         F=17.8989 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=24.4943 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=245.4594, p=0.0000  , df=10
# likelihood ratio test: chi2=242.4924, p=0.0000  , df=10
# parameter F test:         F=24.4943 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=22.8284 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=228.7646, p=0.0000  , df=10
# likelihood ratio test: chi2=226.1846, p=0.0000  , df=10
# parameter F test:         F=22.8284 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=23.7932 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=238.4328, p=0.0000  , df=10
# likelihood ratio test: chi2=235.6319, p=0.0000  , df=10
# parameter F test:         F=23.7932 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=17.7566 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=177.9397, p=0.0000  , df=10
# likelihood ratio test: chi2=176.3735, p=0.0000  , df=10
# parameter F test:         F=17.7566 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=43.3551 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=434.4641, p=0.0000  , df=10
# likelihood ratio test: chi2=425.2820, p=0.0000  , df=10
# parameter F test:         F=43.3551 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=27.7202 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=277.7858, p=0.0000  , df=10
# likelihood ratio test: chi2=273.9939, p=0.0000  , df=10
# parameter F test:         F=27.7202 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=17.8013 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=178.3884, p=0.0000  , df=10
# likelihood ratio test: chi2=176.8144, p=0.0000  , df=10
# parameter F test:         F=17.8013 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=13.3070 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=133.3502, p=0.0000  , df=10
# likelihood ratio test: chi2=132.4681, p=0.0000  , df=10
# parameter F test:         F=13.3070 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=22.4684 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=225.1573, p=0.0000  , df=10
# likelihood ratio test: chi2=222.6575, p=0.0000  , df=10
# parameter F test:         F=22.4684 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=17.1004 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=171.3642, p=0.0000  , df=10
# likelihood ratio test: chi2=169.9110, p=0.0000  , df=10
# parameter F test:         F=17.1004 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=24.1652 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=242.1609, p=0.0000  , df=10
# likelihood ratio test: chi2=239.2724, p=0.0000  , df=10
# parameter F test:         F=24.1652 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=33.1458 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=332.1564, p=0.0000  , df=10
# likelihood ratio test: chi2=326.7540, p=0.0000  , df=10
# parameter F test:         F=33.1458 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=21.3322 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=213.7709, p=0.0000  , df=10
# likelihood ratio test: chi2=211.5158, p=0.0000  , df=10
# parameter F test:         F=21.3322 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=20.4055 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=204.4844, p=0.0000  , df=10
# likelihood ratio test: chi2=202.4197, p=0.0000  , df=10
# parameter F test:         F=20.4055 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=30.4204 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=304.8443, p=0.0000  , df=10
# likelihood ratio test: chi2=300.2857, p=0.0000  , df=10
# parameter F test:         F=30.4204 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=18.8242 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=188.6381, p=0.0000  , df=10
# likelihood ratio test: chi2=186.8792, p=0.0000  , df=10
# parameter F test:         F=18.8242 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=37.1095 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=371.8763, p=0.0000  , df=10
# likelihood ratio test: chi2=365.1219, p=0.0000  , df=10
# parameter F test:         F=37.1095 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=24.0573 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=241.0794, p=0.0000  , df=10
# likelihood ratio test: chi2=238.2165, p=0.0000  , df=10
# parameter F test:         F=24.0573 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
#
# Granger Causality
# number of lags (no zero) 10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=20.1780 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=202.2050, p=0.0000  , df=10
# likelihood ratio test: chi2=200.1858, p=0.0000  , df=10
# parameter F test:         F=20.1780 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=22.6281 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=226.7573, p=0.0000  , df=10
# likelihood ratio test: chi2=224.2221, p=0.0000  , df=10
# parameter F test:         F=22.6281 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=21.8736 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=219.1970, p=0.0000  , df=10
# likelihood ratio test: chi2=216.8268, p=0.0000  , df=10
# parameter F test:         F=21.8736 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=28.5065 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=285.6654, p=0.0000  , df=10
# likelihood ratio test: chi2=281.6573, p=0.0000  , df=10
# parameter F test:         F=28.5065 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=22.7481 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=227.9598, p=0.0000  , df=10
# likelihood ratio test: chi2=225.3978, p=0.0000  , df=10
# parameter F test:         F=22.7481 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=18.9389 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=189.7880, p=0.0000  , df=10
# likelihood ratio test: chi2=188.0077, p=0.0000  , df=10
# parameter F test:         F=18.9389 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=16.8349 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=168.7032, p=0.0000  , df=10
# likelihood ratio test: chi2=167.2946, p=0.0000  , df=10
# parameter F test:         F=16.8349 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=19.4469 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=194.8783, p=0.0000  , df=10
# likelihood ratio test: chi2=193.0019, p=0.0000  , df=10
# parameter F test:         F=19.4469 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=22.1896 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=222.3638, p=0.0000  , df=10
# likelihood ratio test: chi2=219.9251, p=0.0000  , df=10
# parameter F test:         F=22.1896 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=18.8776 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=189.1739, p=0.0000  , df=10
# likelihood ratio test: chi2=187.4051, p=0.0000  , df=10
# parameter F test:         F=18.8776 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=14.2750 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=143.0505, p=0.0000  , df=10
# likelihood ratio test: chi2=142.0360, p=0.0000  , df=10
# parameter F test:         F=14.2750 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=17.1078 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=171.4379, p=0.0000  , df=10
# likelihood ratio test: chi2=169.9835, p=0.0000  , df=10
# parameter F test:         F=17.1078 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=21.2230 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=212.6767, p=0.0000  , df=10
# likelihood ratio test: chi2=210.4445, p=0.0000  , df=10
# ...
# parameter F test:         F=25.5172 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=19.0223 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=190.6234, p=0.0000  , df=10
# likelihood ratio test: chi2=188.8275, p=0.0000  , df=10
# parameter F test:         F=19.0223 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=23.0302 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=230.7876, p=0.0000  , df=10
# likelihood ratio test: chi2=228.1622, p=0.0000  , df=10
# parameter F test:         F=23.0302 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=27.9589 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=280.1779, p=0.0000  , df=10
# likelihood ratio test: chi2=276.3209, p=0.0000  , df=10
# parameter F test:         F=27.9589 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=16.7775 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=168.1286, p=0.0000  , df=10
# likelihood ratio test: chi2=166.7295, p=0.0000  , df=10
# parameter F test:         F=16.7775 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=22.5169 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=225.6430, p=0.0000  , df=10
# likelihood ratio test: chi2=223.1324, p=0.0000  , df=10
# parameter F test:         F=22.5169 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=19.0746 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=191.1481, p=0.0000  , df=10
# likelihood ratio test: chi2=189.3424, p=0.0000  , df=10
# parameter F test:         F=19.0746 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=20.0037 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=200.4585, p=0.0000  , df=10
# likelihood ratio test: chi2=198.4738, p=0.0000  , df=10
# parameter F test:         F=20.0037 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=26.1652 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=262.2029, p=0.0000  , df=10
# likelihood ratio test: chi2=258.8210, p=0.0000  , df=10
# parameter F test:         F=26.1652 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=13.1154 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=131.4301, p=0.0000  , df=10
# likelihood ratio test: chi2=130.5730, p=0.0000  , df=10
# parameter F test:         F=13.1154 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=12.8112 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=128.3817, p=0.0000  , df=10
# likelihood ratio test: chi2=127.5638, p=0.0000  , df=10
# parameter F test:         F=12.8112 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=35.6742 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=357.4931, p=0.0000  , df=10
# likelihood ratio test: chi2=351.2453, p=0.0000  , df=10
# parameter F test:         F=35.6742 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=12.6876 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=127.1437, p=0.0000  , df=10
# likelihood ratio test: chi2=126.3414, p=0.0000  , df=10
# parameter F test:         F=12.6876 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=21.6905 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=217.3617, p=0.0000  , df=10
# likelihood ratio test: chi2=215.0308, p=0.0000  , df=10
# parameter F test:         F=21.6905 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=20.6292 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=206.7265, p=0.0000  , df=10
# likelihood ratio test: chi2=204.6167, p=0.0000  , df=10
# parameter F test:         F=20.6292 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=28.1662 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=282.2549, p=0.0000  , df=10
# likelihood ratio test: chi2=278.3410, p=0.0000  , df=10
# parameter F test:         F=28.1662 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=12.2379 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=122.6367, p=0.0000  , df=10
# likelihood ratio test: chi2=121.8901, p=0.0000  , df=10
# parameter F test:         F=12.2379 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=78.1814 , p=0.0000  , df_denom=9970, df_num=10
# ssr based chi2 test:   chi2=783.4610, p=0.0000  , df=10
# likelihood ratio test: chi2=754.2598, p=0.0000  , df=10
# parameter F test:         F=78.1814 , p=0.0000  , df_denom=9970, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=12.6162 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=126.4273, p=0.0000  , df=10
# likelihood ratio test: chi2=125.6340, p=0.0000  , df=10
# parameter F test:         F=12.6162 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=9.6189  , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=96.3914 , p=0.0000  , df=10
# likelihood ratio test: chi2=95.9294 , p=0.0000  , df=10
# parameter F test:         F=9.6189  , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=13.8105 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=138.3963, p=0.0000  , df=10
# likelihood ratio test: chi2=137.4465, p=0.0000  , df=10
# parameter F test:         F=13.8105 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=10.1900 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=102.1146, p=0.0000  , df=10
# likelihood ratio test: chi2=101.5963, p=0.0000  , df=10
# parameter F test:         F=10.1900 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=7.3033  , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=73.1866 , p=0.0000  , df=10
# likelihood ratio test: chi2=72.9198 , p=0.0000  , df=10
# parameter F test:         F=7.3033  , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=11.4998 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=115.2404, p=0.0000  , df=10
# likelihood ratio test: chi2=114.5808, p=0.0000  , df=10
# parameter F test:         F=11.4998 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=7.8792  , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=78.9584 , p=0.0000  , df=10
# likelihood ratio test: chi2=78.6480 , p=0.0000  , df=10
# parameter F test:         F=7.8792  , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=10.0998 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=101.2104, p=0.0000  , df=10
# likelihood ratio test: chi2=100.7012, p=0.0000  , df=10
# parameter F test:         F=10.0998 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=5.6014  , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=56.1325 , p=0.0000  , df=10
# likelihood ratio test: chi2=55.9754 , p=0.0000  , df=10
# parameter F test:         F=5.6014  , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=15.6890 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=157.2207, p=0.0000  , df=10
# likelihood ratio test: chi2=155.9963, p=0.0000  , df=10
# parameter F test:         F=15.6890 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=7.0535  , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=70.6832 , p=0.0000  , df=10
# likelihood ratio test: chi2=70.4343 , p=0.0000  , df=10
# parameter F test:         F=7.0535  , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=9.8405  , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=98.6119 , p=0.0000  , df=10
# likelihood ratio test: chi2=98.1284 , p=0.0000  , df=10
# parameter F test:         F=9.8405  , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=8.8588  , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=88.7746 , p=0.0000  , df=10
# likelihood ratio test: chi2=88.3825 , p=0.0000  , df=10
# parameter F test:         F=8.8588  , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=9.4751  , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=94.9509 , p=0.0000  , df=10
# likelihood ratio test: chi2=94.5025 , p=0.0000  , df=10
# parameter F test:         F=9.4751  , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=4.1596  , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=41.6840 , p=0.0000  , df=10
# likelihood ratio test: chi2=41.5973 , p=0.0000  , df=10
# parameter F test:         F=4.1596  , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=9.6944  , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=97.1479 , p=0.0000  , df=10
# likelihood ratio test: chi2=96.6786 , p=0.0000  , df=10
# parameter F test:         F=9.6944  , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=17.1319 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=171.6803, p=0.0000  , df=10
# likelihood ratio test: chi2=170.2218, p=0.0000  , df=10
# parameter F test:         F=17.1319 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=12.0833 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=121.0872, p=0.0000  , df=10
# likelihood ratio test: chi2=120.3592, p=0.0000  , df=10
# parameter F test:         F=12.0833 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=7.7823  , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=77.9874 , p=0.0000  , df=10
# likelihood ratio test: chi2=77.6845 , p=0.0000  , df=10
# parameter F test:         F=7.7823  , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=22.5084 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=225.5579, p=0.0000  , df=10
# likelihood ratio test: chi2=223.0492, p=0.0000  , df=10
# parameter F test:         F=22.5084 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=10.4229 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=104.4485, p=0.0000  , df=10
# likelihood ratio test: chi2=103.9062, p=0.0000  , df=10
# parameter F test:         F=10.4229 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=13.3233 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=133.5134, p=0.0000  , df=10
# likelihood ratio test: chi2=132.6291, p=0.0000  , df=10
# parameter F test:         F=13.3233 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=4.7777  , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=47.8774 , p=0.0000  , df=10
# likelihood ratio test: chi2=47.7630 , p=0.0000  , df=10
# parameter F test:         F=4.7777  , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
#
# Granger Causality
# number of lags (no zero) 10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=5.2621  , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=52.7315 , p=0.0000  , df=10
# likelihood ratio test: chi2=52.5929 , p=0.0000  , df=10
# parameter F test:         F=5.2621  , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=13.9341 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=139.6341, p=0.0000  , df=10
# likelihood ratio test: chi2=138.6672, p=0.0000  , df=10
# parameter F test:         F=13.9341 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=10.9154 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=109.3843, p=0.0000  , df=10
# likelihood ratio test: chi2=108.7898, p=0.0000  , df=10
# parameter F test:         F=10.9154 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=11.8777 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=119.0270, p=0.0000  , df=10
# likelihood ratio test: chi2=118.3235, p=0.0000  , df=10
# parameter F test:         F=11.8777 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=8.2499  , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=82.6725 , p=0.0000  , df=10
# likelihood ratio test: chi2=82.3323 , p=0.0000  , df=10
# parameter F test:         F=8.2499  , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=6.7011  , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=67.1522 , p=0.0000  , df=10
# likelihood ratio test: chi2=66.9276 , p=0.0000  , df=10
# parameter F test:         F=6.7011  , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=12.8144 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=128.4141, p=0.0000  , df=10
# likelihood ratio test: chi2=127.5958, p=0.0000  , df=10
# parameter F test:         F=12.8144 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=10.4247 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=104.4671, p=0.0000  , df=10
# likelihood ratio test: chi2=103.9246, p=0.0000  , df=10
# parameter F test:         F=10.4247 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=7.6895  , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=77.0569 , p=0.0000  , df=10
# likelihood ratio test: chi2=76.7612 , p=0.0000  , df=10
# parameter F test:         F=7.6895  , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=10.6241 , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=106.4651, p=0.0000  , df=10
# likelihood ratio test: chi2=105.9018, p=0.0000  , df=10
# parameter F test:         F=10.6241 , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=6.3085  , p=0.0000  , df_denom=9969, df_num=10
# ssr based chi2 test:   chi2=63.2177 , p=0.0000  , df=10
# likelihood ratio test: chi2=63.0185 , p=0.0000  , df=10
# parameter F test:         F=6.3085  , p=0.0000  , df_denom=9969, df_num=10
#
# Granger Causality
# number of lags (no zero) 10

# %%
baseline_or_trial = "baseline"
for region_1, region_2 in baseline_pairs:
    region_1_name = region_1.split("_")[0]
    region_2_name = region_2.split("_")[0]
    
    
    FULL_LFP_TRACES["{}_{}_{}_granger".format(region_1_name, region_2_name, baseline_or_trial)] = FULL_LFP_TRACES.apply(lambda row: get_granger(row, region_1, region_2, max_lag=MAX_LAG), axis=1)

    FULL_LFP_TRACES["{}_{}_{}_granger".format(region_2_name, region_1_name, baseline_or_trial)] = FULL_LFP_TRACES.apply(lambda row: get_granger(row, region_2, region_1, max_lag=MAX_LAG), axis=1)

# %%
FULL_LFP_TRACES

# %%
raise ValueError()

# %%
baseline_or_trial = "baseline"
for region_1, region_2 in baseline_pairs:
    region_1_name = region_1.split("_")[0]
    region_2_name = region_2.split("_")[0]
    
    
    FULL_LFP_TRACES["{}_{}_granger".format(region_1_name, region_2_name)] = FULL_LFP_TRACES.apply(lambda row: get_granger(row, region_1, region_2), axis=1)

    FULL_LFP_TRACES["{}_{}_granger".format(region_2_name, region_1_name)] = FULL_LFP_TRACES.apply(lambda row: get_granger(row, region_2, region_1), axis=1)

# %%
FULL_LFP_TRACES["BLA_LH_granger"].iloc[5][3][0]

# %%
FULL_LFP_TRACES["LH_BLA_granger"].iloc[0][3][0]

# %%
baseline_or_trial = "baseline"
for region_1, region_2 in baseline_pairs:
    region_1_name = region_1.split("_")[0]
    region_2_name = region_2.split("_")[0]

    FULL_LFP_TRACES["{}_{}_granger".format(region_1_name, region_2_name)] = FULL_LFP_TRACES.apply(lambda row: np.hstack([row[region_1][np.newaxis].T, row[region_2][np.newaxis].T]), axis=1)


    
    break
    FULL_LFP_TRACES["{}_{}_granger".format(region_1_name, region_2_name)] = FULL_LFP_TRACES.apply(lambda row: grangercausalitytests(np.hstack([row[region_1][np.newaxis].T, row[region_2][np.newaxis].T]), maxlag=[3]), axis=1)

    FULL_LFP_TRACES["{}_{}_granger".format(region_2_name, region_1_name)] = FULL_LFP_TRACES.apply(lambda row: grangercausalitytests(np.hstack([row[region_2][np.newaxis].T, row[region_1][np.newaxis].T]), maxlag=[3]), axis=1)
    break

# %%
FULL_LFP_TRACES["BLA_LH_granger"].iloc[0].shape

# %%
example_arr.shape

# %%
example_arr = np.hstack([FULL_LFP_TRACES["BLA_trial_lfp_trace"].iloc[0][np.newaxis].T, FULL_LFP_TRACES["MD_trial_lfp_trace"].iloc[0][np.newaxis].T])

# %%
example_arr = np.hstack([FULL_LFP_TRACES["MD_trial_lfp_trace"].iloc[0][np.newaxis].T, FULL_LFP_TRACES["BLA_trial_lfp_trace"].iloc[0][np.newaxis].T])

# %%
grangercausalitytests(example_arr, maxlag=[3])

# %%
grangercausalitytests(example_arr, maxlag=[3])

# %%
region_1_name

# %%
#perform Granger-Causality test
grangercausalitytests(FULL_LFP_TRACES[[baseline_pairs[0][0], baseline_pairs[0][1]]], maxlag=[3])

# %%
raise ValueError()

# %%
trace_columns = [col for col in channel_map_and_all_trials_df.columns if "trace" in col]

# %%
trace_columns

# %% [raw]
# for region in trace_columns:
#     region_base_name = "{}".format(region.strip("trace").strip("_"))
#     print(region_base_name)
#     # Getting the multitaper from each brain region
#     multitaper_col = "{}_multitaper".format(region_base_name)
#     channel_map_and_all_trials_df[multitaper_col] = channel_map_and_all_trials_df[region].apply(lambda x: Multitaper(time_series=x, sampling_frequency=RESAMPLE_RATE))
#     # Getting the connectivity from each brain region,
#     # which has the power for the trace
#     connectivity_col = "{}_connectivity".format(region_base_name)
#     channel_map_and_all_trials_df[connectivity_col] = channel_map_and_all_trials_df[multitaper_col].apply(lambda x: Connectivity.from_multitaper(x))
#     channel_map_and_all_trials_df["{}_power".format(region_base_name)] = channel_map_and_all_trials_df[connectivity_col].apply(lambda x: x.power().squeeze())
#     # Getting the frequencies for each power
#     channel_map_and_all_trials_df["{}_frequencies".format(region_base_name)] = channel_map_and_all_trials_df[connectivity_col].apply(lambda x: x.frequencies)

# %% [raw]
# for region in trace_columns:
#     region_base_name = "{}".format(region.strip("trace").strip("_"))
#
#     connectivity_col = "{}_connectivity".format(region_base_name)
#
#     channel_map_and_all_trials_df["{}_power".format(region_base_name)] = channel_map_and_all_trials_df[connectivity_col].apply(lambda x: x.power().squeeze())

# %% [raw]
# - Averaging the powers for each band

# %% [raw]
# ALL_BANDS

# %% [raw]
# BAND_TO_FREQ

# %% [raw]
# for region in trace_columns:
#     region_base_name = "{}".format(region.strip("trace").strip("_"))
#     print(region_base_name)
#
#     for band in ALL_BANDS:
#         channel_map_and_all_trials_df["{}_averaged_{}_power".format(region_base_name, band)] = channel_map_and_all_trials_df["{}_power".format(region_base_name)].apply(lambda x: np.mean(x[BAND_TO_FREQ[band]["low_freq"]*10:BAND_TO_FREQ[band]["high_freq"]*10+1]))

# %% [markdown]
# ## Power correlation between brain regions calculation

# %% [markdown]
# - Combining the trial/baseline and outcome label for coloring

# %%
channel_map_and_all_trials_df["outcome_and_trial_or_baseline"] = channel_map_and_all_trials_df.apply(lambda x: "_".join([x["trial_outcome"], x["trial_or_baseline"]]), axis=1)

# %%
from statsmodels.tsa.stattools import grangercausalitytests

# %%
channel_map_and_all_trials_df.columns

# %%
trace_columns = [col for col in channel_map_and_all_trials_df.columns if "trace" in col]

# %%
trace_columns

# %%
brain_region_pairs = generate_pairs(trace_columns)

# %%
brain_region_pairs

# %%
grangercausalitytests(df[['column1', 'column2']], maxlag=[3])

# %%
channel_map_and_all_trials_df[region_1].iloc[0]

# %%
def granger

# %%
for region_1, region_2 in brain_region_pairs:
    pair_base_name = "{}_{}".format(region_1.strip("trace").strip("_"), region_2.strip("trace").strip("_"))
    print(pair_base_name)
    try:
        
        # granger_value = grangercausalitytests(channel_map_and_all_trials_df[[region_1, region_2]], maxlag=[3])
        channel_map_and_all_trials_df["{}_granger".format(pair_base_name)] = channel_map_and_all_trials_df.apply(lambda row: grangercausalitytests(np.array([row[region_1], row[region_2]]).T, maxlag=[3]), axis=1)
        print()
    except Exception as e: 
        print(e)
    break

# %%
channel_map_and_all_trials_df[""]

# %%
channel_map_and_all_trials_df

# %%
granger_value

# %% [markdown]
# - Filtering out the outliers

# %%
band_to_power_correlation = defaultdict(dict)
for band in ALL_BANDS:
    # Getting all the pairs of brain regions
    band_averaged_columns = [col for col in channel_map_and_all_trials_df.columns if "averaged_{}".format(band) in col]
    band_to_power_correlation[band]["brain_region_pairs"] = generate_pairs(band_averaged_columns)
    print(band_to_power_correlation[band]["brain_region_pairs"])

    # Removing rows that are outliers
    filtered_df = channel_map_and_all_trials_df.copy()
    
    for col in band_averaged_columns:
        # filtered_df = filtered_df[filtered_df[col] <= 3]
        # Assuming data is a 1D numpy array
        Q1 = np.percentile(filtered_df[col], 25)
        Q3 = np.percentile(filtered_df[col], 75)
        IQR = Q3 - Q1
        band_to_power_correlation[band]["outlier_removed_df"] = filtered_df[(filtered_df[col] >= Q1 - 1.5 * IQR) & (filtered_df[col] <= Q3 + 1.5 * IQR)]


    
    # Getting the mean and standard deviation

# %%
band_to_power_correlation = defaultdict(dict)
for band in ALL_BANDS:
    # Getting all the pairs of brain regions
    band_averaged_columns = [col for col in channel_map_and_all_trials_df.columns if "averaged_{}".format(band) in col]
    band_to_power_correlation[band]["brain_region_pairs"] = generate_pairs(band_averaged_columns)
    print(band_to_power_correlation[band]["brain_region_pairs"])

    # Removing rows that are outliers
    filtered_df = channel_map_and_all_trials_df.copy()
    
    for col in band_averaged_columns:
        # filtered_df = filtered_df[filtered_df[col] <= 3]
        # Assuming data is a 1D numpy array
        Q1 = np.percentile(filtered_df[col], 25)
        Q3 = np.percentile(filtered_df[col], 75)
        IQR = Q3 - Q1
        filtered_df = filtered_df[(filtered_df[col] >= Q1 - 1.5 * IQR) & (filtered_df[col] <= Q3 + 1.5 * IQR)]
    band_to_power_correlation[band]["outlier_removed_df"] = filtered_df

# %% [raw]
# band_to_power_correlation = defaultdict(dict)
# for band in ALL_BANDS:
#     # Getting all the pairs of brain regions
#     band_averaged_columns = [col for col in channel_map_and_all_trials_df.columns if "averaged_{}".format(band) in col]
#     band_to_power_correlation[band]["brain_region_pairs"] = generate_pairs(band_averaged_columns)
#     print(band_to_power_correlation[band]["brain_region_pairs"])
#
#     # code to filter based on std
#     filtered_df = channel_map_and_all_trials_df.copy()
#     for col in band_averaged_columns:
#         # Assuming data is a 1D numpy array
#         threshold = 1
#         mean = np.median(filtered_df[col])
#         std = np.std(filtered_df[col])
#         filtered_df = filtered_df[np.abs(filtered_df[col] - mean) < threshold * std]
#     band_to_power_correlation[band]["outlier_removed_df"] = filtered_df

# %%
channel_map_and_all_trials_df.shape

# %%
band_to_power_correlation[band]["outlier_removed_df"].shape

# %% [raw]
# # code to filter based on std
# filtered_df = channel_map_and_all_trials_df.copy()
# for col in averaged_col:
#     # Assuming data is a 1D numpy array
#     threshold = 3.5
#     mean = np.mean(filtered_df[col])
#     std = np.std(filtered_df[col])
#     filtered_df = filtered_df[np.abs(filtered_df[col] - mean) < threshold * std]

# %% [markdown]
# - Plotting all of the conditions

# %%
for band in ALL_BANDS:
    for region_1, region_2 in band_to_power_correlation[band]["brain_region_pairs"]:
        region_1_basename = region_1.split("_")[0]
        region_2_basename = region_2.split("_")[0]
        x = band_to_power_correlation[band]["outlier_removed_df"][region_1]
        y = band_to_power_correlation[band]["outlier_removed_df"][region_2]
        
        # Perform linear regression to get the slope, intercept and r-value (correlation coefficient)
        slope, intercept, r_value, p_value, std_err = linregress(x, y)
        
        # Create a line of best fit using the slope and intercept
        line = slope * x + intercept
        
        # Create scatter plot
        sns.scatterplot(x=x, y=y, data=band_to_power_correlation[band]["outlier_removed_df"], hue='outcome_and_trial_or_baseline', palette=BASELINE_OUTCOME_TO_COLOR)
        
        # Plot line of best fit
        plt.plot(x, line, color='red')
        
        # Add R² value to the plot
        plt.text(0.1, 0.9, f'R = {r_value:.2f}', transform=plt.gca().transAxes)
        
        # Add labels and legend
        plt.title("Power correlation of Z-scored {} band LFP: {} and {}".format(band, region_2_basename, region_1_basename))
        plt.xlabel('{} {} power of Z-scored LFP'.format(band, region_1_basename))
        plt.ylabel('{} {} power of Z-scored LFP'.format(band, region_2_basename))
        plt.legend(loc="lower right")
        plt.tight_layout()
        plt.savefig("./proc/power_correlation/zscored/{}/all_condition_{}_{}_power_correlation_of_zscored_{}_lfp.png".format(band, region_1_basename, region_2_basename, band))
        # Display the plot
        plt.show()

# %%
raise ValueError()

# %%
channel_map_and_all_trials_df = filtered_df

# %%
channel_map_and_all_trials_df["trial_outcome"].unique()

# %%
channel_map_and_all_trials_df["trial_or_baseline"]

# %% [raw]
# for band in ALL_BANDS:
#     for region_1, region_2 in band_to_power_correlation[band]["brain_region_pairs"]:
#         region_1_basename = region_1.split("_")[0]
#         region_2_basename = region_2.split("_")[0]
#         x = band_to_power_correlation[band]["outlier_removed_df"][region_1]
#         y = band_to_power_correlation[band]["outlier_removed_df"][region_2]
#
#         # Perform linear regression to get the slope, intercept and r-value (correlation coefficient)
#         slope, intercept, r_value, p_value, std_err = linregress(x, y)
#
#         # Create a line of best fit using the slope and intercept
#         line = slope * x + intercept
#
#         # Create scatter plot
#         sns.scatterplot(x=x, y=y, data=band_to_power_correlation[band]["outlier_removed_df"], hue='outcome_and_trial_or_baseline', palette=BASELINE_OUTCOME_TO_COLOR)
#
#         # Plot line of best fit
#         plt.plot(x, line, color='red')
#
#         # Add R² value to the plot
#         plt.text(0.1, 0.9, f'R = {r_value:.2f}', transform=plt.gca().transAxes)
#
#         # Add labels and legend
#         plt.title("Power correlation of Z-scored {} band LFP: {} and {}".format(band, region_2_basename, region_1_basename))
#         plt.xlabel('{} {} power of Z-scored LFP'.format(band, region_1_basename))
#         plt.ylabel('{} {} power of Z-scored LFP'.format(band, region_2_basename))
#         plt.legend(loc="lower right")
#         # plt.savefig("./proc/power_correlation/zscored/all_condition_{}_{}_power_correlation_of_zscored_theta_lfp.png".format(region_1_basename, region_2_basename))
#         # Display the plot
#         plt.show()

# %%
for band in ALL_BANDS:
    band_df = band_to_power_correlation[band]["outlier_removed_df"]
    band_to_power_correlation[band]["region_pair_to_outcome_to_r2"] = defaultdict(nested_dict)
    for outcome in band_df["trial_outcome"].unique():
        outcome_df = band_df[band_df["trial_outcome"] == outcome]
        for region_1, region_2 in brain_region_pairs:
            region_1_basename = region_1.split("_")[0]
            region_2_basename = region_2.split("_")[0]
            
            x = outcome_df[region_1]
            y = outcome_df[region_2]
            
            # Perform linear regression to get the slope, intercept and r-value (correlation coefficient)
            slope, intercept, r_value, p_value, std_err = linregress(x, y)
            # Square the r value to get the r squared value
            r2_value = r_value**2
            band_to_power_correlation[band]["region_pair_to_outcome_to_r2"]["{}_{}".format(region_1.split("_")[0], region_2.split("_")[0])][outcome]["r"] = r_value
            band_to_power_correlation[band]["region_pair_to_outcome_to_r2"]["{}_{}".format(region_1.split("_")[0], region_2.split("_")[0])][outcome]["std"] = std_err
            
            # Create a line of best fit using the slope and intercept
            line = slope * x + intercept
            
            # Create scatter plot
            sns.scatterplot(x=x, y=y, data=outcome_df, hue='outcome_and_trial_or_baseline', palette=BASELINE_OUTCOME_TO_COLOR, style='outcome_and_trial_or_baseline', markers=['^', 'o'])
            
            # Plot line of best fit
            plt.plot(x, line, color='red')
            
            # Add R² value to the plot
            plt.text(0.1, 0.9, f'R = {r_value:.2f}', transform=plt.gca().transAxes)
            
            # Add labels and legend
            plt.title("Power Correlation of Z-scored {} LFP: {} and {}".format(band, region_2_basename, region_1_basename))
            plt.xlabel('{} {} Power of Z-scored LFP'.format(region_1_basename, band))
            plt.ylabel('{} {} Power of Z-scored LFP'.format(region_2_basename, band))
            plt.legend(loc="lower right")
            plt.tight_layout()
            plt.savefig("./proc/power_correlation/zscored/{}/{}_{}_{}_power_correlation_of_zscored_{}_lfp.png".format(band, outcome, region_1_basename, region_2_basename, band))
            # Display the plot
            plt.show()

# %%
for band in ALL_BANDS:
    # Convert the nested dictionary to a DataFrame
    data = []
    for group_name, group_data in band_to_power_correlation[band]['region_pair_to_outcome_to_r2'].items():
        for bar_name, bar_dict in group_data.items():
            data.append({"Group": group_name, "Bar": bar_name, "r": bar_dict["r"], "std": bar_dict["std"]})
    df = pd.DataFrame(data)
    
    # Create the bar plot using seaborn
    # sns.catplot(
    #     data=df, 
    #     x='Group', 
    #     y='r2', 
    #     hue='Bar', 
    #     kind='bar', 
    #     height=4, 
    #     aspect=2,
    #     legend=False,
    #     # yerr=df['std'].values,  # This line adds the SEM bars
    #     # capsize=0.1  # This line adds caps on the error bars
    # )
    
    # Create barplot
    ax = sns.barplot(x='Group', y='r', hue='Bar', data=df, ci=None)
    
    # Adding error bars
    groups = df['Group'].unique()
    bars_per_group = df['Bar'].nunique()
    bar_width = 0.8 / bars_per_group
    x_positions = []
    
    for i, group in enumerate(groups):
        num_bars = df[df['Group'] == group].shape[0]
        group_positions = np.linspace(i - bar_width*(num_bars-1)/2, i + bar_width*(num_bars-1)/2, num_bars)
        x_positions.extend(group_positions)
    
    for i, (r2, sem) in enumerate(zip(df['r'], df['std'])):
        plt.errorbar(x_positions[i], r2, yerr=sem, fmt='none', color='black', capsize=5)
    
    
    plt.xticks(rotation=90)
    plt.xlabel("Brain region pairs")
    plt.ylabel("Power correlation r")
    plt.legend(title="Trial Conditions")
    plt.title("{} Power correlations".format(band))
    plt.tight_layout()
    plt.grid()
    
    plt.savefig("./proc/power_correlation/zscored/all_zscored_{}_lfp_power_correlation.png".format(band))
    # Show the plot
    plt.show()

# %%
# Convert the nested dictionary to a DataFrame
data = []
for group_name, group_data in region_pair_to_outcome_to_r2.items():
    for bar_name, bar_dict in group_data.items():
        data.append({"Group": group_name, "Bar": bar_name, "r": bar_dict["r"], "std": bar_dict["std"]})
df = pd.DataFrame(data)

# Create the bar plot using seaborn
# sns.catplot(
#     data=df, 
#     x='Group', 
#     y='r2', 
#     hue='Bar', 
#     kind='bar', 
#     height=4, 
#     aspect=2,
#     legend=False,
#     # yerr=df['std'].values,  # This line adds the SEM bars
#     # capsize=0.1  # This line adds caps on the error bars
# )

# Create barplot
ax = sns.barplot(x='Group', y='r', hue='Bar', data=df, ci=None)

# Adding error bars
groups = df['Group'].unique()
bars_per_group = df['Bar'].nunique()
bar_width = 0.8 / bars_per_group
x_positions = []

for i, group in enumerate(groups):
    num_bars = df[df['Group'] == group].shape[0]
    group_positions = np.linspace(i - bar_width*(num_bars-1)/2, i + bar_width*(num_bars-1)/2, num_bars)
    x_positions.extend(group_positions)

for i, (r2, sem) in enumerate(zip(df['r'], df['std'])):
    plt.errorbar(x_positions[i], r2, yerr=sem, fmt='none', color='black', capsize=5)


plt.xticks(rotation=90)
plt.xlabel("Brain region pairs")
plt.ylabel("Power correlation r")
plt.legend(title="Trial Conditions")
plt.title("Power correlations")
plt.tight_layout()
plt.grid()

plt.savefig("./proc/power_correlation/zscored/all_zscored_lfp_power_correlation.png")
# Show the plot
plt.show()
