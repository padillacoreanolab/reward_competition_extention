# %%
import numpy as np
import matplotlib.pyplot as plt

# Sample 2D array
data = np.array([
    [1, 2, 3, 10],
    [4, 5, 6, 10],
    [7, 8, 9, 10]
])

plt.imshow(data, cmap='viridis')  # 'viridis' is one of many color maps you can choose
plt.colorbar()  # adds a colorbar which shows the value-color mapping
plt.show()
