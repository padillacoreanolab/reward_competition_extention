# %% [markdown]
# # Omission LFP Analysis

# %% [markdown]
# Brief 1-2 sentence description of notebook.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import os
import glob
from collections import defaultdict
import re

# %%
# Imports of all used packages and libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
from scipy import stats
import itertools
from scipy.stats import linregress

# %%
import spikeinterface.extractors as se
import spikeinterface.preprocessing as sp
from spectral_connectivity import Multitaper, Connectivity
import spectral_connectivity

# %% [markdown]
# ## Inputs & Data

# %% [markdown]
# Explanation of each input and where it comes from.

# %%
# Inputs and Required data loading
# input varaible names are in all caps snake case
# Whenever an input changes or is used for processing 
# the vairables are all lower in snake case

# %%
BBOX_TO_ANCHOR=(1.5, 0.9)
LOC='upper right'

# %%
ALL_BANDS = ["theta", "beta", "gamma"]
BAND_TO_FREQ = {"theta": {"low_freq": 4, "high_freq": 12}, "beta": {"low_freq": 13, "high_freq": 30}, "gamma": {"low_freq": 30, "high_freq": 70}}

# %%
# variables for LFP extraction
FREQ_MIN=0.5
FREQ_MAX=300
NOTCH_FREQ=60
ORIGINAL_SAMPLE_RATE = 20000
RESAMPLE_RATE=1000
TRIAL_DURATION=10

# %%
INPUT_VARIABLE = 1

TIME_HALFBANDWIDTH_PRODUCT = 2
TIME_WINDOW_DURATION = 3
TIME_WINDOW_STEP = 1.5 

TRIAL_TIME_STAMP_DURATION = 1000*10

# %%
BIN_TO_COLOR = {0: {"baseline": "lightblue", "trial": "blue"}, 1: {"baseline": "lightgreen", "trial": "green"}, 2: {"baseline": "lightcoral", "trial": "red"}}
TRIAL_OR_BASELINE_TO_STYLE = {'baseline': "--", "trial": "-"}
BIN_TO_VELOCITY = {0: "0 to 2.5cm/s", 1: "2.5 to 5cm/s", 2: "5cm/s+"}

# %%
NUM_LINES = 3

# %%
# Generate colors from the "Blues" colormap
LOSING_COLORS = cm.Oranges(np.linspace(0.5, 1, NUM_LINES))
# Generate colors from the "Blues" colormap
WINNING_COLORS = cm.Blues(np.linspace(0.5, 1, NUM_LINES))
# Generate colors from the "Blues" colormap
REWARDED_COLORS = cm.Greens(np.linspace(0.5, 1, NUM_LINES))
# Generate colors from the "Blues" colormap
OMISSION_COLORS = cm.Reds(np.linspace(0.5, 1, NUM_LINES))

# %%
BASELINE_OUTCOME_TO_COLOR = {'lose': "orange",
 'lose_baseline': LOSING_COLORS[0],
 'omission': "red",
 'omission_baseline': "hotpink",
 'rewarded': "green",
 'rewarded_baseline': REWARDED_COLORS[0],
 'win': "blue",
 'win_baseline': WINNING_COLORS[0]}

# %%
BASELINE_OUTCOME_TO_COLOR = {'lose_trial': "orange",
 'lose_baseline': LOSING_COLORS[0],
 'omission_trial': "red",
 'omission_baseline': "hotpink",
 'rewarded_trial': "green",
 'rewarded_baseline': REWARDED_COLORS[0],
 'win_trial': "blue",
 'win_baseline': WINNING_COLORS[0]}

# %%
COMPETITIVE_OUTCOME_TO_COLOR = {'lose_comp': "orange", 
'lose_non_comp': "yellow",
'omission': "red",
'rewarded': "green",
'win_comp': "blue", 
'win_non_comp': WINNING_COLORS[0]}

# %%
TRIAL_OR_BASELINE_TO_STYLE = {'baseline': "--", "trial": "-"}

# %%
CHANNEL_MAPPING_DF = pd.read_excel("../../channel_mapping.xlsx")
CHANNEL_MAPPING_DF["Subject"] = CHANNEL_MAPPING_DF["Subject"].astype(str)

TONE_TIMESTAMP_DF = pd.read_excel("../../rce_tone_timestamp.xlsx", index_col=0)
OUTPUT_DIR = r"./proc" # where data is saved should always be shown in the inputs

# %%
all_session_dir = ['/scratch/back_up/reward_competition_extention/data/pilot/20221214_125409_om_and_comp_6_1_and_6_3.rec',
'/scratch/back_up/reward_competition_extention/data/pilot/20221215_145401_comp_amd_om_6_1_and_6_3.rec',
'/scratch/back_up/reward_competition_extention/data/standard/2023_06_12/20230612_101430_standard_comp_to_training_D1_subj_1-4_and_1-3.rec',
'/scratch/back_up/reward_competition_extention/data/omission/2023_06_17/20230617_115521_standard_comp_to_omission_D1_subj_1-1_and_1-2.rec',
'/scratch/back_up/reward_competition_extention/data/omission/2023_06_18/20230618_100636_standard_comp_to_omission_D2_subj_1-4_and_1-1.rec',
'/scratch/back_up/reward_competition_extention/data/omission/2023_06_19/20230619_115321_standard_comp_to_omission_D3_subj_1-2_and_1-4.rec',
'/scratch/back_up/reward_competition_extention/data/omission/2023_06_20/20230620_114347_standard_comp_to_omission_D4_subj_1-2_and_1-1.rec',
'/scratch/back_up/reward_competition_extention/data/omission/2023_06_21/20230621_111240_standard_comp_to_omission_D5_subj_1-4_and_1-2.rec']

# %% [raw]
# all_session_dir = ['/scratch/back_up/reward_competition_extention/data/omission/2023_06_17/20230617_115521_standard_comp_to_omission_D1_subj_1-1_and_1-2.rec',
# '/scratch/back_up/reward_competition_extention/data/omission/2023_06_18/20230618_100636_standard_comp_to_omission_D2_subj_1-4_and_1-1.rec',
# '/scratch/back_up/reward_competition_extention/data/omission/2023_06_19/20230619_115321_standard_comp_to_omission_D3_subj_1-2_and_1-4.rec',
# '/scratch/back_up/reward_competition_extention/data/omission/2023_06_20/20230620_114347_standard_comp_to_omission_D4_subj_1-2_and_1-1.rec',
# '/scratch/back_up/reward_competition_extention/data/omission/2023_06_21/20230621_111240_standard_comp_to_omission_D5_subj_1-4_and_1-2.rec']

# %%
all_session_dir
# Out:
# ['/scratch/back_up/reward_competition_extention/data/pilot/20221214_125409_om_and_comp_6_1_and_6_3.rec',
#  '/scratch/back_up/reward_competition_extention/data/pilot/20221215_145401_comp_amd_om_6_1_and_6_3.rec',
#  '/scratch/back_up/reward_competition_extention/data/standard/2023_06_12/20230612_101430_standard_comp_to_training_D1_subj_1-4_and_1-3.rec',
#  '/scratch/back_up/reward_competition_extention/data/omission/2023_06_17/20230617_115521_standard_comp_to_omission_D1_subj_1-1_and_1-2.rec',
#  '/scratch/back_up/reward_competition_extention/data/omission/2023_06_18/20230618_100636_standard_comp_to_omission_D2_subj_1-4_and_1-1.rec',
#  '/scratch/back_up/reward_competition_extention/data/omission/2023_06_19/20230619_115321_standard_comp_to_omission_D3_subj_1-2_and_1-4.rec',
#  '/scratch/back_up/reward_competition_extention/data/omission/2023_06_20/20230620_114347_standard_comp_to_omission_D4_subj_1-2_and_1-1.rec',
#  '/scratch/back_up/reward_competition_extention/data/omission/2023_06_21/20230621_111240_standard_comp_to_omission_D5_subj_1-4_and_1-2.rec']

# %% [markdown]
# ## Outputs

# %% [markdown]
# Describe each output that the notebook creates.

# %% [markdown]
# - Is it a plot or is it data?

# %% [markdown]
# - How valuable is the output and why is it valuable or useful?

# %% [markdown]
# ## Functions

# %% [markdown]
# - Ideally functions are defined here first and then data is processed using the functions
#     - function names are short and in snake case all lowercase
#     - a function name should be unique but does not have to describe the function
#     - doc strings describe functions not function names

# %%
def generate_pairs(lst):
    pairs = []
    n = len(lst)
    for i in range(n):
        for j in range(i+1, n):
            pairs.append((lst[i], lst[j]))
    return pairs

# %%
def nested_dict():
    return defaultdict(dict)

triple_nested_dict = defaultdict(nested_dict)

# %% [markdown]
# ## Processing

# %% [markdown]
# Describe what is done to the data here and how inputs are manipulated to generate outputs.

# %%
# As much code and as many cells as required
# includes EDA and playing with data
# GO HAM!

# %%
CHANNEL_MAPPING_DF
# Out:
#    Cohort Subject  eib_mPFC  eib_vHPC  eib_BLA  eib_LH  eib_MD  \
# 0       1     6.1       NaN        15       14      13      31
# 1       1     6.2       NaN        15       14      13      31
# 2       1     6.3       NaN        15       14      13      31
# 3       1     6.4       NaN        15       14      13      31
# 4       2     1.1       NaN        16       17      18      19
# 5       2     1.2       NaN        31       30      29      28
# 6       2     1.3       NaN        15       14      13      12
# 7       2     1.4       NaN        15       14      13      12
#
#    spike_interface_mPFC  spike_interface_vHPC  spike_interface_BLA  \
# 0                  21.0                  15.0                 14.0
# 1                   NaN                   NaN                  NaN
# 2                   NaN                   NaN                  NaN
# 3                   NaN                   NaN                  NaN
# 4                   5.0                  31.0                 30.0
# 5                  10.0                  31.0                 30.0
# 6                   9.0                  31.0                 30.0
# 7                  15.0                  31.0                 30.0
#
#    spike_interface_LH  spike_interface_MD
# 0                13.0                16.0
# 1                 NaN                 NaN
# 2                 NaN                 NaN
# 3                 NaN                 NaN
# 4                29.0                28.0
# 5                29.0                28.0
# 6                29.0                28.0
# 7                29.0                28.0

# %% [markdown]
# ### Getting the subject IDs from the file name

# %% [raw]
# TONE_TIMESTAMP_DF = pd.read_pickle("./proc/melted_trials_and_video.pkl")

# %%
all_trials_df = TONE_TIMESTAMP_DF.dropna(subset="condition").reset_index(drop=True)

# %%
all_trials_df.head()
# Out:
#          time  state                                      recording_dir  \
# 0   6310663.0    1.0  20221202_134600_omission_and_competition_subje...
# 1   7910662.0    1.0  20221202_134600_omission_and_competition_subje...
# 2   9710660.0    1.0  20221202_134600_omission_and_competition_subje...
# 3  11310658.0    1.0  20221202_134600_omission_and_competition_subje...
# 4  12810657.0    1.0  20221202_134600_omission_and_competition_subje...
#
#                                       recording_file           din  \
# 0  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# 1  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# 2  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# 3  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# 4  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
#
#    time_stamp_index                                         video_file  \
# 0         1390826.0  20221202_134600_omission_and_competition_subje...
# 1         2990825.0  20221202_134600_omission_and_competition_subje...
# 2         4790823.0  20221202_134600_omission_and_competition_subje...
# 3         6390821.0  20221202_134600_omission_and_competition_subje...
# 4         7890820.0  20221202_134600_omission_and_competition_subje...
#
#    video_frame  video_number      subject_info condition  \
# 0       1734.0           1.0  6_1_top_2_base_3  rewarded
# 1       3728.0           1.0  6_1_top_2_base_3  rewarded
# 2       5972.0           1.0  6_1_top_2_base_3  rewarded
# 3       7966.0           1.0  6_1_top_2_base_3  omission
# 4       9836.0           1.0  6_1_top_2_base_3  rewarded
#
#   competition_closeness Unnamed: 13
# 0                   NaN         NaN
# 1                   NaN         NaN
# 2                   NaN         NaN
# 3                   NaN         NaN
# 4                   NaN         NaN

# %% [markdown]
# - Original timestamps are based on ephys recordings at 20kHz. The LFP will be at 1kHz, so we will need to divide all the timestamps by 20

# %%
all_trials_df["resampled_index"] = all_trials_df["time_stamp_index"] // (ORIGINAL_SAMPLE_RATE // RESAMPLE_RATE)

# %%
all_trials_df["recording_dir"].unique()
# Out:
# array(['20221202_134600_omission_and_competition_subject_6_1_and_6_2',
#        '20221203_154800_omission_and_competition_subject_6_4_and_6_1',
#        '20221214_125409_om_and_comp_6_1_and_6_3',
#        '20221215_145401_comp_amd_om_6_1_and_6_3',
#        '20230612_101430_standard_comp_to_training_D1_subj_1-4_and_1-3',
#        '20230617_115521_standard_comp_to_omission_D1_subj_1-1_and_1-2',
#        '20230618_100636_standard_comp_to_omission_D2_subj_1-4_and_1-1',
#        '20230619_115321_standard_comp_to_omission_D3_subj_1-2_and_1-4',
#        '20230620_114347_standard_comp_to_omission_D4_subj_1-2_and_1-1',
#        '20230621_111240_standard_comp_to_omission_D5_subj_1-4_and_1-2'],
#       dtype=object)

# %% [markdown]
# - Getting a list of all the subjects through the recording name

# %%
all_trials_df["all_subjects"] = all_trials_df["recording_dir"].apply(lambda x: ["{}.{}".format(tup[0],tup[1]) for tup in re.findall(r'(\d+)-(\d+)', x.replace("_", "-"))[1:]])

# %%
all_trials_df["all_subjects"].head()
# Out:
# 0    [6.1, 6.2]
# 1    [6.1, 6.2]
# 2    [6.1, 6.2]
# 3    [6.1, 6.2]
# 4    [6.1, 6.2]
# Name: all_subjects, dtype: object

# %% [markdown]
# - Getting the current subject of the recording through the ending of the recording name file

# %%
all_trials_df["subject_info"].head()
# Out:
# 0    6_1_top_2_base_3
# 1    6_1_top_2_base_3
# 2    6_1_top_2_base_3
# 3    6_1_top_2_base_3
# 4    6_1_top_2_base_3
# Name: subject_info, dtype: object

# %%
all_trials_df["current_subject"] = all_trials_df["subject_info"].apply(lambda x: ".".join(x.replace("-","_").split("_")[:2]))

# %%
all_trials_df.head()
# Out:
#          time  state                                      recording_dir  \
# 0   6310663.0    1.0  20221202_134600_omission_and_competition_subje...
# 1   7910662.0    1.0  20221202_134600_omission_and_competition_subje...
# 2   9710660.0    1.0  20221202_134600_omission_and_competition_subje...
# 3  11310658.0    1.0  20221202_134600_omission_and_competition_subje...
# 4  12810657.0    1.0  20221202_134600_omission_and_competition_subje...
#
#                                       recording_file           din  \
# 0  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# 1  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# 2  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# 3  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# 4  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
#
#    time_stamp_index                                         video_file  \
# 0         1390826.0  20221202_134600_omission_and_competition_subje...
# 1         2990825.0  20221202_134600_omission_and_competition_subje...
# 2         4790823.0  20221202_134600_omission_and_competition_subje...
# 3         6390821.0  20221202_134600_omission_and_competition_subje...
# 4         7890820.0  20221202_134600_omission_and_competition_subje...
#
#    video_frame  video_number      subject_info condition  \
# 0       1734.0           1.0  6_1_top_2_base_3  rewarded
# 1       3728.0           1.0  6_1_top_2_base_3  rewarded
# 2       5972.0           1.0  6_1_top_2_base_3  rewarded
# 3       7966.0           1.0  6_1_top_2_base_3  omission
# 4       9836.0           1.0  6_1_top_2_base_3  rewarded
#
#   competition_closeness Unnamed: 13  resampled_index all_subjects  \
# 0                   NaN         NaN          69541.0   [6.1, 6.2]
# 1                   NaN         NaN         149541.0   [6.1, 6.2]
# 2                   NaN         NaN         239541.0   [6.1, 6.2]
# 3                   NaN         NaN         319541.0   [6.1, 6.2]
# 4                   NaN         NaN         394541.0   [6.1, 6.2]
#
#   current_subject
# 0             6.1
# 1             6.1
# 2             6.1
# 3             6.1
# 4             6.1

# %% [markdown]
# - Labeling the trial as a winner or loser if the winner matches the subject id or not

# %%
all_trials_df["trial_outcome"] = all_trials_df.apply(
    lambda x: "win" if str(x["condition"]).strip() == str(x["current_subject"]) 
             else ("lose" if str(x["condition"]) in x["all_subjects"] 
                   else x["condition"]), axis=1)

# %%
all_trials_df.head()
# Out:
#          time  state                                      recording_dir  \
# 0   6310663.0    1.0  20221202_134600_omission_and_competition_subje...
# 1   7910662.0    1.0  20221202_134600_omission_and_competition_subje...
# 2   9710660.0    1.0  20221202_134600_omission_and_competition_subje...
# 3  11310658.0    1.0  20221202_134600_omission_and_competition_subje...
# 4  12810657.0    1.0  20221202_134600_omission_and_competition_subje...
#
#                                       recording_file           din  \
# 0  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# 1  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# 2  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# 3  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
# 4  20221202_134600_omission_and_competition_subje...  dio_ECU_Din1
#
#    time_stamp_index                                         video_file  \
# 0         1390826.0  20221202_134600_omission_and_competition_subje...
# 1         2990825.0  20221202_134600_omission_and_competition_subje...
# 2         4790823.0  20221202_134600_omission_and_competition_subje...
# 3         6390821.0  20221202_134600_omission_and_competition_subje...
# 4         7890820.0  20221202_134600_omission_and_competition_subje...
#
#    video_frame  video_number      subject_info condition  \
# 0       1734.0           1.0  6_1_top_2_base_3  rewarded
# 1       3728.0           1.0  6_1_top_2_base_3  rewarded
# 2       5972.0           1.0  6_1_top_2_base_3  rewarded
# 3       7966.0           1.0  6_1_top_2_base_3  omission
# 4       9836.0           1.0  6_1_top_2_base_3  rewarded
#
#   competition_closeness Unnamed: 13  resampled_index all_subjects  \
# 0                   NaN         NaN          69541.0   [6.1, 6.2]
# 1                   NaN         NaN         149541.0   [6.1, 6.2]
# 2                   NaN         NaN         239541.0   [6.1, 6.2]
# 3                   NaN         NaN         319541.0   [6.1, 6.2]
# 4                   NaN         NaN         394541.0   [6.1, 6.2]
#
#   current_subject trial_outcome
# 0             6.1      rewarded
# 1             6.1      rewarded
# 2             6.1      rewarded
# 3             6.1      omission
# 4             6.1      rewarded

# %%
competition_closeness_map = {k: "non_comp" if "only" in str(k).lower() else "comp" if type(k) is str else np.nan for k in all_trials_df["competition_closeness"].unique()}

# %%
competition_closeness_map
# Out:
# {nan: nan,
#  'Subj 1 Only': 'non_comp',
#  'Subj 2 blocking Subj 1': 'comp',
#  'Subj 1 then Subj 2': 'comp',
#  'Subj 1 blocking Subj 2': 'comp',
#  'Subj 2 Only': 'non_comp',
#  'Subj 2 then Subj 1': 'comp',
#  'Close Call': 'comp'}

# %%
all_trials_df["competition_closeness"] = all_trials_df["competition_closeness"].map(competition_closeness_map)

# %%
all_trials_df["competition_closeness"]
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#          ...
# 698    non_comp
# 699    non_comp
# 700        comp
# 701        comp
# 702        comp
# Name: competition_closeness, Length: 703, dtype: object

# %%
all_trials_df["competition_closeness"] = all_trials_df.apply(lambda x: "_".join([str(x["trial_outcome"]), str(x["competition_closeness"])]).strip("nan").strip("_"), axis=1)

# %% [markdown]
# ### Extracting the LFP

# %%
recording_name_to_all_ch_lfp = {}
# Going through all the recording sessions 
for session_dir in all_session_dir:
    # Going through all the recordings in each session
    for recording_path in glob.glob(os.path.join(session_dir, "*.rec")):
        try:
            recording_basename = os.path.splitext(os.path.basename(recording_path))[0]
            # checking to see if the recording has an ECU component
            # if it doesn't, then the next one be extracted
            current_recording = se.read_spikegadgets(recording_path, stream_id="ECU")
            current_recording = se.read_spikegadgets(recording_path, stream_id="trodes")
            print(recording_basename)
            # Preprocessing the LFP
            current_recording = sp.bandpass_filter(current_recording, freq_min=FREQ_MIN, freq_max=FREQ_MAX)
            current_recording = sp.notch_filter(current_recording, freq=NOTCH_FREQ)
            current_recording = sp.resample(current_recording, resample_rate=RESAMPLE_RATE)
            current_recording = sp.zscore(current_recording)
            recording_name_to_all_ch_lfp[recording_basename] = current_recording
        except:
            pass
# Out:
# 20221214_125409_om_and_comp_6_1_top_1_base_2_vs_6_3
# 20221215_145401_comp_amd_om_6_1_top_4_base_3
# 20230612_101430_standard_comp_to_training_D1_subj_1-4_t4b2L_box1_merged
# 20230612_101430_standard_comp_to_training_D1_subj_1-3_t3b3L_box2_merged
# 20230617_115521_standard_comp_to_omission_D1_subj_1-2_t2b2L_box2_merged
# 20230617_115521_standard_comp_to_omission_D1_subj_1-1_t1b3L_box1_merged
# 20230618_100636_standard_comp_to_omission_D2_subj_1_4_t4b3L_box1_merged
# 20230618_100636_standard_comp_to_omission_D2_subj_1_1_t1b2L_box2_merged
# 20230619_115321_standard_comp_to_omission_D3_subj_1-4_t3b3L_box2_merged
# 20230620_114347_standard_comp_to_omission_D4_subj_1-1_t1b2L_box_2_merged
# 20230620_114347_standard_comp_to_omission_D4_subj_1-2_t3b3L_box_1_merged
# 20230621_111240_standard_comp_to_omission_D5_subj_1-4_t3b3L_box1_merged

# %% [markdown]
# - Filtering for all trials that have labels

# %%
all_trials_df = all_trials_df[all_trials_df["recording_file"].isin(recording_name_to_all_ch_lfp.keys())].reset_index(drop=True)

# %%
all_trials_df.head()
# Out:
#          time  state                            recording_dir  \
# 0   4359951.0    1.0  20221214_125409_om_and_comp_6_1_and_6_3
# 1   5959954.0    1.0  20221214_125409_om_and_comp_6_1_and_6_3
# 2   7759946.0    1.0  20221214_125409_om_and_comp_6_1_and_6_3
# 3   9359945.0    1.0  20221214_125409_om_and_comp_6_1_and_6_3
# 4  10859943.0    1.0  20221214_125409_om_and_comp_6_1_and_6_3
#
#                                       recording_file           din  \
# 0  20221214_125409_om_and_comp_6_1_top_1_base_2_v...  dio_ECU_Din1
# 1  20221214_125409_om_and_comp_6_1_top_1_base_2_v...  dio_ECU_Din1
# 2  20221214_125409_om_and_comp_6_1_top_1_base_2_v...  dio_ECU_Din1
# 3  20221214_125409_om_and_comp_6_1_top_1_base_2_v...  dio_ECU_Din1
# 4  20221214_125409_om_and_comp_6_1_top_1_base_2_v...  dio_ECU_Din1
#
#    time_stamp_index                                         video_file  \
# 0         1408048.0  20221214_125409_om_and_comp_6_1_and_6_3.1.vide...
# 1         3008051.0  20221214_125409_om_and_comp_6_1_and_6_3.1.vide...
# 2         4808043.0  20221214_125409_om_and_comp_6_1_and_6_3.1.vide...
# 3         6408042.0  20221214_125409_om_and_comp_6_1_and_6_3.1.vide...
# 4         7908040.0  20221214_125409_om_and_comp_6_1_and_6_3.1.vide...
#
#    video_frame  video_number             subject_info condition  \
# 0       1405.0           1.0  6_1_top_1_base_2_vs_6_3  rewarded
# 1       3002.0           1.0  6_1_top_1_base_2_vs_6_3  rewarded
# 2       4798.0           1.0  6_1_top_1_base_2_vs_6_3  rewarded
# 3       6395.0           1.0  6_1_top_1_base_2_vs_6_3  omission
# 4       7892.0           1.0  6_1_top_1_base_2_vs_6_3  rewarded
#
#   competition_closeness Unnamed: 13  resampled_index all_subjects  \
# 0              rewarded         NaN          70402.0   [6.1, 6.3]
# 1              rewarded         NaN         150402.0   [6.1, 6.3]
# 2              rewarded         NaN         240402.0   [6.1, 6.3]
# 3              omission         NaN         320402.0   [6.1, 6.3]
# 4              rewarded         NaN         395402.0   [6.1, 6.3]
#
#   current_subject trial_outcome
# 0             6.1      rewarded
# 1             6.1      rewarded
# 2             6.1      rewarded
# 3             6.1      omission
# 4             6.1      rewarded

# %%
all_trials_df["trial_outcome"].unique()
# Out:
# array(['rewarded', 'omission', 'win', 'lose'], dtype=object)

# %% [markdown]
# # Extracting the LFP

# %%
all_trials_df.head()
# Out:
#          time  state                            recording_dir  \
# 0   4359951.0    1.0  20221214_125409_om_and_comp_6_1_and_6_3
# 1   5959954.0    1.0  20221214_125409_om_and_comp_6_1_and_6_3
# 2   7759946.0    1.0  20221214_125409_om_and_comp_6_1_and_6_3
# 3   9359945.0    1.0  20221214_125409_om_and_comp_6_1_and_6_3
# 4  10859943.0    1.0  20221214_125409_om_and_comp_6_1_and_6_3
#
#                                       recording_file           din  \
# 0  20221214_125409_om_and_comp_6_1_top_1_base_2_v...  dio_ECU_Din1
# 1  20221214_125409_om_and_comp_6_1_top_1_base_2_v...  dio_ECU_Din1
# 2  20221214_125409_om_and_comp_6_1_top_1_base_2_v...  dio_ECU_Din1
# 3  20221214_125409_om_and_comp_6_1_top_1_base_2_v...  dio_ECU_Din1
# 4  20221214_125409_om_and_comp_6_1_top_1_base_2_v...  dio_ECU_Din1
#
#    time_stamp_index                                         video_file  \
# 0         1408048.0  20221214_125409_om_and_comp_6_1_and_6_3.1.vide...
# 1         3008051.0  20221214_125409_om_and_comp_6_1_and_6_3.1.vide...
# 2         4808043.0  20221214_125409_om_and_comp_6_1_and_6_3.1.vide...
# 3         6408042.0  20221214_125409_om_and_comp_6_1_and_6_3.1.vide...
# 4         7908040.0  20221214_125409_om_and_comp_6_1_and_6_3.1.vide...
#
#    video_frame  video_number             subject_info condition  \
# 0       1405.0           1.0  6_1_top_1_base_2_vs_6_3  rewarded
# 1       3002.0           1.0  6_1_top_1_base_2_vs_6_3  rewarded
# 2       4798.0           1.0  6_1_top_1_base_2_vs_6_3  rewarded
# 3       6395.0           1.0  6_1_top_1_base_2_vs_6_3  omission
# 4       7892.0           1.0  6_1_top_1_base_2_vs_6_3  rewarded
#
#   competition_closeness Unnamed: 13  resampled_index all_subjects  \
# 0              rewarded         NaN          70402.0   [6.1, 6.3]
# 1              rewarded         NaN         150402.0   [6.1, 6.3]
# 2              rewarded         NaN         240402.0   [6.1, 6.3]
# 3              omission         NaN         320402.0   [6.1, 6.3]
# 4              rewarded         NaN         395402.0   [6.1, 6.3]
#
#   current_subject trial_outcome
# 0             6.1      rewarded
# 1             6.1      rewarded
# 2             6.1      rewarded
# 3             6.1      omission
# 4             6.1      rewarded

# %%
CHANNEL_MAPPING_DF
# Out:
#    Cohort Subject  eib_mPFC  eib_vHPC  eib_BLA  eib_LH  eib_MD  \
# 0       1     6.1       NaN        15       14      13      31
# 1       1     6.2       NaN        15       14      13      31
# 2       1     6.3       NaN        15       14      13      31
# 3       1     6.4       NaN        15       14      13      31
# 4       2     1.1       NaN        16       17      18      19
# 5       2     1.2       NaN        31       30      29      28
# 6       2     1.3       NaN        15       14      13      12
# 7       2     1.4       NaN        15       14      13      12
#
#    spike_interface_mPFC  spike_interface_vHPC  spike_interface_BLA  \
# 0                  21.0                  15.0                 14.0
# 1                   NaN                   NaN                  NaN
# 2                   NaN                   NaN                  NaN
# 3                   NaN                   NaN                  NaN
# 4                   5.0                  31.0                 30.0
# 5                  10.0                  31.0                 30.0
# 6                   9.0                  31.0                 30.0
# 7                  15.0                  31.0                 30.0
#
#    spike_interface_LH  spike_interface_MD
# 0                13.0                16.0
# 1                 NaN                 NaN
# 2                 NaN                 NaN
# 3                 NaN                 NaN
# 4                29.0                28.0
# 5                29.0                28.0
# 6                29.0                28.0
# 7                29.0                28.0

# %% [markdown]
# - Adding all the brain region to ch information

# %%
channel_map_and_all_trials_df = all_trials_df.merge(CHANNEL_MAPPING_DF, left_on="current_subject", right_on="Subject", how="left")

# %% [markdown]
# - Linking up all LFP calculations with all the trials

# %%
channel_map_and_all_trials_df["all_ch_lfp"] = channel_map_and_all_trials_df["recording_file"].map(recording_name_to_all_ch_lfp)

# %%
channel_map_and_all_trials_df.head()
# Out:
#          time  state                            recording_dir  \
# 0   4359951.0    1.0  20221214_125409_om_and_comp_6_1_and_6_3
# 1   5959954.0    1.0  20221214_125409_om_and_comp_6_1_and_6_3
# 2   7759946.0    1.0  20221214_125409_om_and_comp_6_1_and_6_3
# 3   9359945.0    1.0  20221214_125409_om_and_comp_6_1_and_6_3
# 4  10859943.0    1.0  20221214_125409_om_and_comp_6_1_and_6_3
#
#                                       recording_file           din  \
# 0  20221214_125409_om_and_comp_6_1_top_1_base_2_v...  dio_ECU_Din1
# 1  20221214_125409_om_and_comp_6_1_top_1_base_2_v...  dio_ECU_Din1
# 2  20221214_125409_om_and_comp_6_1_top_1_base_2_v...  dio_ECU_Din1
# 3  20221214_125409_om_and_comp_6_1_top_1_base_2_v...  dio_ECU_Din1
# 4  20221214_125409_om_and_comp_6_1_top_1_base_2_v...  dio_ECU_Din1
#
#    time_stamp_index                                         video_file  \
# 0         1408048.0  20221214_125409_om_and_comp_6_1_and_6_3.1.vide...
# 1         3008051.0  20221214_125409_om_and_comp_6_1_and_6_3.1.vide...
# 2         4808043.0  20221214_125409_om_and_comp_6_1_and_6_3.1.vide...
# 3         6408042.0  20221214_125409_om_and_comp_6_1_and_6_3.1.vide...
# 4         7908040.0  20221214_125409_om_and_comp_6_1_and_6_3.1.vide...
#
#    video_frame  video_number             subject_info  ... eib_vHPC eib_BLA  \
# 0       1405.0           1.0  6_1_top_1_base_2_vs_6_3  ...       15      14
# 1       3002.0           1.0  6_1_top_1_base_2_vs_6_3  ...       15      14
# 2       4798.0           1.0  6_1_top_1_base_2_vs_6_3  ...       15      14
# 3       6395.0           1.0  6_1_top_1_base_2_vs_6_3  ...       15      14
# 4       7892.0           1.0  6_1_top_1_base_2_vs_6_3  ...       15      14
#
#   eib_LH  eib_MD spike_interface_mPFC spike_interface_vHPC  \
# 0     13      31                 21.0                 15.0
# 1     13      31                 21.0                 15.0
# 2     13      31                 21.0                 15.0
# 3     13      31                 21.0                 15.0
# 4     13      31                 21.0                 15.0
#
#   spike_interface_BLA  spike_interface_LH spike_interface_MD  \
# 0                14.0                13.0               16.0
# 1                14.0                13.0               16.0
# 2                14.0                13.0               16.0
# 3                14.0                13.0               16.0
# 4                14.0                13.0               16.0
#
#                                           all_ch_lfp
# 0  ZScoreRecording: 32 channels - 1 segments - 1....
# 1  ZScoreRecording: 32 channels - 1 segments - 1....
# 2  ZScoreRecording: 32 channels - 1 segments - 1....
# 3  ZScoreRecording: 32 channels - 1 segments - 1....
# 4  ZScoreRecording: 32 channels - 1 segments - 1....
#
# [5 rows x 30 columns]

# %% [markdown]
# - Getting the LFP indexes for each trial before and after the tone

# %%
channel_map_and_all_trials_df["resampled_index"] = channel_map_and_all_trials_df["resampled_index"].astype(int)

# %%
# Getting the LFP index for the trial portion
trial_channel_map_and_all_trials_df = channel_map_and_all_trials_df.copy()
trial_channel_map_and_all_trials_df["trial_or_baseline"] = "trial"
trial_channel_map_and_all_trials_df["trial_or_baseline_entire_lfp_index"] = trial_channel_map_and_all_trials_df["resampled_index"].apply(lambda x: (x, x+RESAMPLE_RATE*TRIAL_DURATION,))

# Getting the LFP index for the baseline portion
baseline_channel_map_and_all_trials_df = channel_map_and_all_trials_df.copy()
baseline_channel_map_and_all_trials_df["trial_or_baseline"] = "baseline"
baseline_channel_map_and_all_trials_df["trial_or_baseline_entire_lfp_index"] = baseline_channel_map_and_all_trials_df["resampled_index"].apply(lambda x: (x-RESAMPLE_RATE*TRIAL_DURATION, x))

# %% [markdown]
# - Combining the dataframe for the trial and baseline portions

# %%
channel_map_and_all_trials_df = pd.concat([trial_channel_map_and_all_trials_df, baseline_channel_map_and_all_trials_df])

# %%
channel_map_and_all_trials_df["trial_or_baseline_entire_lfp_index"].head()
# Out:
# 0      (70402, 80402)
# 1    (150402, 160402)
# 2    (240402, 250402)
# 3    (320402, 330402)
# 4    (395402, 405402)
# Name: trial_or_baseline_entire_lfp_index, dtype: object

# %% [markdown]
# - Getting the LFP for each brain region

# %%
channel_columns = sorted([col for col in channel_map_and_all_trials_df.columns if "spike" in col])

# %%
channel_columns
# Out:
# ['spike_interface_BLA',
#  'spike_interface_LH',
#  'spike_interface_MD',
#  'spike_interface_mPFC',
#  'spike_interface_vHPC']

# %%
for col in channel_columns:
    print(col)
    channel_map_and_all_trials_df["{}_trace".format(col.strip("spike_interface").strip("_"))] = channel_map_and_all_trials_df.apply(lambda x: 
x["all_ch_lfp"].get_traces(channel_ids=[str(int(x[col]))], start_frame=x["trial_or_baseline_entire_lfp_index"][0], end_frame=x["trial_or_baseline_entire_lfp_index"][-1] ).T[0][:RESAMPLE_RATE*TRIAL_DURATION], axis=1)
# Out:
# spike_interface_BLA
# spike_interface_LH
# spike_interface_MD
# spike_interface_mPFC
# spike_interface_vHPC

# %% [markdown]
# ## Power calculation for each trial for each brain region

# %%
raise ValueError()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 raise ValueError()
#
# ValueError:

# %%
trace_columns = [col for col in channel_map_and_all_trials_df.columns if "trace" in col]

# %%
trace_columns
# Out:
# ['BLA_trace', 'LH_trace', 'MD_trace', 'mPFC_trace', 'vHPC_trace']

# %% [raw]
# for region in trace_columns:
#     region_base_name = "{}".format(region.strip("trace").strip("_"))
#     print(region_base_name)
#     # Getting the multitaper from each brain region
#     multitaper_col = "{}_multitaper".format(region_base_name)
#     channel_map_and_all_trials_df[multitaper_col] = channel_map_and_all_trials_df[region].apply(lambda x: Multitaper(time_series=x, sampling_frequency=RESAMPLE_RATE))
#     # Getting the connectivity from each brain region,
#     # which has the power for the trace
#     connectivity_col = "{}_connectivity".format(region_base_name)
#     channel_map_and_all_trials_df[connectivity_col] = channel_map_and_all_trials_df[multitaper_col].apply(lambda x: Connectivity.from_multitaper(x))
#     channel_map_and_all_trials_df["{}_power".format(region_base_name)] = channel_map_and_all_trials_df[connectivity_col].apply(lambda x: x.power().squeeze())
#     # Getting the frequencies for each power
#     channel_map_and_all_trials_df["{}_frequencies".format(region_base_name)] = channel_map_and_all_trials_df[connectivity_col].apply(lambda x: x.frequencies)

# %% [raw]
# for region in trace_columns:
#     region_base_name = "{}".format(region.strip("trace").strip("_"))
#
#     connectivity_col = "{}_connectivity".format(region_base_name)
#
#     channel_map_and_all_trials_df["{}_power".format(region_base_name)] = channel_map_and_all_trials_df[connectivity_col].apply(lambda x: x.power().squeeze())

# %% [raw]
# - Averaging the powers for each band

# %% [raw]
# ALL_BANDS

# %% [raw]
# BAND_TO_FREQ

# %% [raw]
# for region in trace_columns:
#     region_base_name = "{}".format(region.strip("trace").strip("_"))
#     print(region_base_name)
#
#     for band in ALL_BANDS:
#         channel_map_and_all_trials_df["{}_averaged_{}_power".format(region_base_name, band)] = channel_map_and_all_trials_df["{}_power".format(region_base_name)].apply(lambda x: np.mean(x[BAND_TO_FREQ[band]["low_freq"]*10:BAND_TO_FREQ[band]["high_freq"]*10+1]))

# %% [markdown]
# ## Power correlation between brain regions calculation

# %% [markdown]
# - Combining the trial/baseline and outcome label for coloring

# %%
channel_map_and_all_trials_df["outcome_and_trial_or_baseline"] = channel_map_and_all_trials_df.apply(lambda x: "_".join([x["trial_outcome"], x["trial_or_baseline"]]), axis=1)

# %%
from statsmodels.tsa.stattools import grangercausalitytests

# %%
channel_map_and_all_trials_df.columns
# Out:
# Index(['time', 'state', 'recording_dir', 'recording_file', 'din',
#        'time_stamp_index', 'video_file', 'video_frame', 'video_number',
#        'subject_info', 'condition', 'competition_closeness', 'Unnamed: 13',
#        'resampled_index', 'all_subjects', 'current_subject', 'trial_outcome',
#        'Cohort', 'Subject', 'eib_mPFC', 'eib_vHPC', 'eib_BLA', 'eib_LH',
#        'eib_MD', 'spike_interface_mPFC', 'spike_interface_vHPC',
#        'spike_interface_BLA', 'spike_interface_LH', 'spike_interface_MD',
#        'all_ch_lfp', 'trial_or_baseline', 'trial_or_baseline_entire_lfp_index',
#        'BLA_trace', 'LH_trace', 'MD_trace', 'mPFC_trace', 'vHPC_trace',
#        'outcome_and_trial_or_baseline'],
#       dtype='object')

# %%
trace_columns = [col for col in channel_map_and_all_trials_df.columns if "trace" in col]

# %%
trace_columns
# Out:
# ['BLA_trace', 'LH_trace', 'MD_trace', 'mPFC_trace', 'vHPC_trace']

# %%
brain_region_pairs = generate_pairs(trace_columns)

# %%
brain_region_pairs
# Out:
# [('BLA_trace', 'LH_trace'),
#  ('BLA_trace', 'MD_trace'),
#  ('BLA_trace', 'mPFC_trace'),
#  ('BLA_trace', 'vHPC_trace'),
#  ('LH_trace', 'MD_trace'),
#  ('LH_trace', 'mPFC_trace'),
#  ('LH_trace', 'vHPC_trace'),
#  ('MD_trace', 'mPFC_trace'),
#  ('MD_trace', 'vHPC_trace'),
#  ('mPFC_trace', 'vHPC_trace')]

# %%
grangercausalitytests(df[['column1', 'column2']], maxlag=[3])

# %%
channel_map_and_all_trials_df[region_1].iloc[0]
# Out:
# array([ 0.02984513,  0.19697787,  0.42579055, ..., -1.5957198 ,
#        -1.6693377 , -1.484298  ], dtype=float32)

# %%
def granger

# %%
for region_1, region_2 in brain_region_pairs:
    pair_base_name = "{}_{}".format(region_1.strip("trace").strip("_"), region_2.strip("trace").strip("_"))
    print(pair_base_name)
    try:
        
        # granger_value = grangercausalitytests(channel_map_and_all_trials_df[[region_1, region_2]], maxlag=[3])
        channel_map_and_all_trials_df["{}_granger".format(pair_base_name)] = channel_map_and_all_trials_df.apply(lambda row: grangercausalitytests(np.array([row[region_1], row[region_2]]).T, maxlag=[3]), axis=1)
        print()
    except Exception as e: 
        print(e)
    break
# Out:
# BLA_LH
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=628.0128, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1885.3585, p=0.0000  , df=3
# likelihood ratio test: chi2=1727.1794, p=0.0000  , df=3
# parameter F test:         F=628.0128, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=558.7703, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1677.4856, p=0.0000  , df=3
# likelihood ratio test: chi2=1550.7416, p=0.0000  , df=3
# parameter F test:         F=558.7703, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=426.7804, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1281.2382, p=0.0000  , df=3
# likelihood ratio test: chi2=1205.5382, p=0.0000  , df=3
# parameter F test:         F=426.7804, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=411.5579, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1235.5389, p=0.0000  , df=3
# likelihood ratio test: chi2=1164.9482, p=0.0000  , df=3
# parameter F test:         F=411.5579, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=394.3282, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1183.8136, p=0.0000  , df=3
# likelihood ratio test: chi2=1118.8061, p=0.0000  , df=3
# parameter F test:         F=394.3282, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=444.3558, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1334.0014, p=0.0000  , df=3
# likelihood ratio test: chi2=1252.1983, p=0.0000  , df=3
# parameter F test:         F=444.3558, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=943.9174, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=2833.7365, p=0.0000  , df=3
# likelihood ratio test: chi2=2494.8366, p=0.0000  , df=3
# parameter F test:         F=943.9174, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=398.6651, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1196.8334, p=0.0000  , df=3
# likelihood ratio test: chi2=1130.4407, p=0.0000  , df=3
# parameter F test:         F=398.6651, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=393.3942, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1181.0095, p=0.0000  , df=3
# likelihood ratio test: chi2=1116.2986, p=0.0000  , df=3
# parameter F test:         F=393.3942, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=453.0685, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1360.1579, p=0.0000  , df=3
# likelihood ratio test: chi2=1275.2488, p=0.0000  , df=3
# parameter F test:         F=453.0685, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=603.0974, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1810.5598, p=0.0000  , df=3
# likelihood ratio test: chi2=1664.0501, p=0.0000  , df=3
# parameter F test:         F=603.0974, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=847.1231, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=2543.1499, p=0.0000  , df=3
# likelihood ratio test: chi2=2265.8245, p=0.0000  , df=3
# parameter F test:         F=847.1231, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=569.3260, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1709.1749, p=0.0000  , df=3
# likelihood ratio test: chi2=1577.8407, p=0.0000  , df=3
# parameter F test:         F=569.3260, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=552.2318, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1657.8562, p=0.0000  , df=3
# likelihood ratio test: chi2=1533.9185, p=0.0000  , df=3
# parameter F test:         F=552.2318, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=959.9035, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=2881.7284, p=0.0000  , df=3
# likelihood ratio test: chi2=2532.1596, p=0.0000  , df=3
# parameter F test:         F=959.9035, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=501.0867, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1504.3135, p=0.0000  , df=3
# likelihood ratio test: chi2=1401.3414, p=0.0000  , df=3
# parameter F test:         F=501.0867, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=448.8978, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1347.6369, p=0.0000  , df=3
# likelihood ratio test: chi2=1264.2213, p=0.0000  , df=3
# parameter F test:         F=448.8978, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=418.1016, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1255.1838, p=0.0000  , df=3
# likelihood ratio test: chi2=1182.4170, p=0.0000  , df=3
# parameter F test:         F=418.1016, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=440.8320, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1323.4228, p=0.0000  , df=3
# likelihood ratio test: chi2=1242.8607, p=0.0000  , df=3
# parameter F test:         F=440.8320, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=413.5502, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1241.5199, p=0.0000  , df=3
# likelihood ratio test: chi2=1170.2699, p=0.0000  , df=3
# parameter F test:         F=413.5502, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=403.5828, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1211.5969, p=0.0000  , df=3
# likelihood ratio test: chi2=1143.6170, p=0.0000  , df=3
# parameter F test:         F=403.5828, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=532.7885, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1599.4854, p=0.0000  , df=3
# likelihood ratio test: chi2=1483.7249, p=0.0000  , df=3
# parameter F test:         F=532.7885, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=409.1766, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1228.3899, p=0.0000  , df=3
# likelihood ratio test: chi2=1158.5835, p=0.0000  , df=3
# parameter F test:         F=409.1766, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=477.7726, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1434.3222, p=0.0000  , df=3
# likelihood ratio test: chi2=1340.3188, p=0.0000  , df=3
# parameter F test:         F=477.7726, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=625.4946, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1877.7987, p=0.0000  , df=3
# likelihood ratio test: chi2=1720.8171, p=0.0000  , df=3
# parameter F test:         F=625.4946, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=566.2227, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1699.8585, p=0.0000  , df=3
# likelihood ratio test: chi2=1569.8814, p=0.0000  , df=3
# parameter F test:         F=566.2227, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=963.0309, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=2891.1172, p=0.0000  , df=3
# likelihood ratio test: chi2=2539.4448, p=0.0000  , df=3
# parameter F test:         F=963.0309, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1327.7872, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=3986.1527, p=0.0000  , df=3
# likelihood ratio test: chi2=3354.6751, p=0.0000  , df=3
# parameter F test:         F=1327.7872, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1108.6578, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=3328.3039, p=0.0000  , df=3
# likelihood ratio test: chi2=2872.9352, p=0.0000  , df=3
# parameter F test:         F=1108.6578, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1290.9195, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=3875.4721, p=0.0000  , df=3
# likelihood ratio test: chi2=3275.2311, p=0.0000  , df=3
# parameter F test:         F=1290.9195, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=503.4675, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1511.4607, p=0.0000  , df=3
# likelihood ratio test: chi2=1407.5519, p=0.0000  , df=3
# parameter F test:         F=503.4675, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1424.0286, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=4275.0794, p=0.0000  , df=3
# likelihood ratio test: chi2=3559.1328, p=0.0000  , df=3
# parameter F test:         F=1424.0286, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1386.6677, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=4162.9181, p=0.0000  , df=3
# likelihood ratio test: chi2=3480.2582, p=0.0000  , df=3
# parameter F test:         F=1386.6677, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=369.3293, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1108.7642, p=0.0000  , df=3
# likelihood ratio test: chi2=1051.4767, p=0.0000  , df=3
# parameter F test:         F=369.3293, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=429.9168, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1290.6542, p=0.0000  , df=3
# likelihood ratio test: chi2=1213.8811, p=0.0000  , df=3
# parameter F test:         F=429.9168, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=327.0020, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=981.6935, p=0.0000  , df=3
# likelihood ratio test: chi2=936.4329, p=0.0000  , df=3
# parameter F test:         F=327.0020, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=502.8764, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1509.6862, p=0.0000  , df=3
# likelihood ratio test: chi2=1406.0103, p=0.0000  , df=3
# parameter F test:         F=502.8764, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=399.3406, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1198.8612, p=0.0000  , df=3
# likelihood ratio test: chi2=1132.2515, p=0.0000  , df=3
# parameter F test:         F=399.3406, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=343.8083, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1032.1477, p=0.0000  , df=3
# likelihood ratio test: chi2=982.2704, p=0.0000  , df=3
# parameter F test:         F=343.8083, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=348.3792, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1045.8700, p=0.0000  , df=3
# likelihood ratio test: chi2=994.7008, p=0.0000  , df=3
# parameter F test:         F=348.3792, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=374.7365, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1124.9974, p=0.0000  , df=3
# likelihood ratio test: chi2=1066.0785, p=0.0000  , df=3
# parameter F test:         F=374.7365, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=362.3020, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1087.6677, p=0.0000  , df=3
# likelihood ratio test: chi2=1032.4684, p=0.0000  , df=3
# parameter F test:         F=362.3020, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=319.2997, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=958.5704, p=0.0000  , df=3
# likelihood ratio test: chi2=915.3552, p=0.0000  , df=3
# parameter F test:         F=319.2997, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=425.2951, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1276.7793, p=0.0000  , df=3
# likelihood ratio test: chi2=1201.5850, p=0.0000  , df=3
# parameter F test:         F=425.2951, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=569.0920, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1708.4724, p=0.0000  , df=3
# likelihood ratio test: chi2=1577.2408, p=0.0000  , df=3
# parameter F test:         F=569.0920, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=457.1409, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1372.3837, p=0.0000  , df=3
# likelihood ratio test: chi2=1286.0046, p=0.0000  , df=3
# parameter F test:         F=457.1409, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=396.2122, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1189.4693, p=0.0000  , df=3
# likelihood ratio test: chi2=1123.8618, p=0.0000  , df=3
# parameter F test:         F=396.2122, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=373.1912, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1120.3580, p=0.0000  , df=3
# likelihood ratio test: chi2=1061.9076, p=0.0000  , df=3
# parameter F test:         F=373.1912, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=413.9124, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1242.6072, p=0.0000  , df=3
# likelihood ratio test: chi2=1171.2370, p=0.0000  , df=3
# parameter F test:         F=413.9124, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=346.9913, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1041.7033, p=0.0000  , df=3
# likelihood ratio test: chi2=990.9279, p=0.0000  , df=3
# parameter F test:         F=346.9913, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=380.1169, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1141.1498, p=0.0000  , df=3
# likelihood ratio test: chi2=1080.5866, p=0.0000  , df=3
# parameter F test:         F=380.1169, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1181.4140, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=3546.7256, p=0.0000  , df=3
# likelihood ratio test: chi2=3035.4724, p=0.0000  , df=3
# parameter F test:         F=1181.4140, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=579.2722, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1739.0344, p=0.0000  , df=3
# likelihood ratio test: chi2=1603.3081, p=0.0000  , df=3
# parameter F test:         F=579.2722, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=632.7567, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1899.6003, p=0.0000  , df=3
# likelihood ratio test: chi2=1739.1543, p=0.0000  , df=3
# parameter F test:         F=632.7567, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=372.3926, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1117.9606, p=0.0000  , df=3
# likelihood ratio test: chi2=1059.7515, p=0.0000  , df=3
# parameter F test:         F=372.3926, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=522.9665, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1569.9988, p=0.0000  , df=3
# likelihood ratio test: chi2=1458.2730, p=0.0000  , df=3
# parameter F test:         F=522.9665, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=510.0037, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1531.0832, p=0.0000  , df=3
# likelihood ratio test: chi2=1424.5828, p=0.0000  , df=3
# parameter F test:         F=510.0037, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=548.9916, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1648.1290, p=0.0000  , df=3
# likelihood ratio test: chi2=1525.5715, p=0.0000  , df=3
# parameter F test:         F=548.9916, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=386.6948, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1160.8972, p=0.0000  , df=3
# likelihood ratio test: chi2=1098.2951, p=0.0000  , df=3
# parameter F test:         F=386.6948, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=485.6885, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1458.0865, p=0.0000  , df=3
# likelihood ratio test: chi2=1361.0798, p=0.0000  , df=3
# parameter F test:         F=485.6885, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=442.5887, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1328.6963, p=0.0000  , df=3
# likelihood ratio test: chi2=1247.5167, p=0.0000  , df=3
# parameter F test:         F=442.5887, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=507.1329, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1522.4646, p=0.0000  , df=3
# likelihood ratio test: chi2=1417.1061, p=0.0000  , df=3
# parameter F test:         F=507.1329, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=569.8368, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1710.7083, p=0.0000  , df=3
# likelihood ratio test: chi2=1579.1502, p=0.0000  , df=3
# parameter F test:         F=569.8368, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=477.0413, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1432.1268, p=0.0000  , df=3
# likelihood ratio test: chi2=1338.3987, p=0.0000  , df=3
# parameter F test:         F=477.0413, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=565.8423, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1698.7164, p=0.0000  , df=3
# likelihood ratio test: chi2=1568.9053, p=0.0000  , df=3
# parameter F test:         F=565.8423, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=881.4229, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=2646.1215, p=0.0000  , df=3
# likelihood ratio test: chi2=2347.5782, p=0.0000  , df=3
# parameter F test:         F=881.4229, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=296.1981, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=889.2169, p=0.0000  , df=3
# likelihood ratio test: chi2=851.8687, p=0.0000  , df=3
# parameter F test:         F=296.1981, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=589.5992, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1770.0371, p=0.0000  , df=3
# likelihood ratio test: chi2=1629.6821, p=0.0000  , df=3
# parameter F test:         F=589.5992, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=842.2212, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=2528.4340, p=0.0000  , df=3
# likelihood ratio test: chi2=2254.0861, p=0.0000  , df=3
# parameter F test:         F=842.2212, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=450.6803, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1352.9884, p=0.0000  , df=3
# likelihood ratio test: chi2=1268.9359, p=0.0000  , df=3
# parameter F test:         F=450.6803, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=512.1309, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1537.4692, p=0.0000  , df=3
# likelihood ratio test: chi2=1430.1191, p=0.0000  , df=3
# parameter F test:         F=512.1309, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=287.9272, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=864.3869, p=0.0000  , df=3
# likelihood ratio test: chi2=829.0409, p=0.0000  , df=3
# parameter F test:         F=287.9272, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=459.2535, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1378.7258, p=0.0000  , df=3
# likelihood ratio test: chi2=1291.5796, p=0.0000  , df=3
# parameter F test:         F=459.2535, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=140.3573, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=421.3670, p=0.0000  , df=3
# likelihood ratio test: chi2=412.7288, p=0.0000  , df=3
# parameter F test:         F=140.3573, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=143.0189, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=429.3574, p=0.0000  , df=3
# likelihood ratio test: chi2=420.3930, p=0.0000  , df=3
# parameter F test:         F=143.0189, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=230.1934, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=691.0641, p=0.0000  , df=3
# likelihood ratio test: chi2=668.2251, p=0.0000  , df=3
# parameter F test:         F=230.1934, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=15.9338 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=47.8349 , p=0.0000  , df=3
# likelihood ratio test: chi2=47.7208 , p=0.0000  , df=3
# parameter F test:         F=15.9338 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=284.4397, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=853.9172, p=0.0000  , df=3
# likelihood ratio test: chi2=819.3997, p=0.0000  , df=3
# parameter F test:         F=284.4397, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=124.2657, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=373.0583, p=0.0000  , df=3
# likelihood ratio test: chi2=366.2660, p=0.0000  , df=3
# parameter F test:         F=124.2657, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=385.7320, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1158.0070, p=0.0000  , df=3
# likelihood ratio test: chi2=1095.7053, p=0.0000  , df=3
# parameter F test:         F=385.7320, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=48.4204 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=145.3631, p=0.0000  , df=3
# likelihood ratio test: chi2=144.3164, p=0.0000  , df=3
# parameter F test:         F=48.4204 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=445.1832, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1336.4853, p=0.0000  , df=3
# likelihood ratio test: chi2=1254.3895, p=0.0000  , df=3
# parameter F test:         F=445.1832, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=320.2915, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=961.5477, p=0.0000  , df=3
# likelihood ratio test: chi2=918.0717, p=0.0000  , df=3
# parameter F test:         F=320.2915, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=185.7837, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=557.7417, p=0.0000  , df=3
# likelihood ratio test: chi2=542.7387, p=0.0000  , df=3
# parameter F test:         F=185.7837, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=107.7143, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=323.3694, p=0.0000  , df=3
# likelihood ratio test: chi2=318.2495, p=0.0000  , df=3
# parameter F test:         F=107.7143, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=166.7677, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=500.6535, p=0.0000  , df=3
# likelihood ratio test: chi2=488.5205, p=0.0000  , df=3
# parameter F test:         F=166.7677, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=276.6301, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=830.4717, p=0.0000  , df=3
# likelihood ratio test: chi2=797.7759, p=0.0000  , df=3
# parameter F test:         F=276.6301, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=658.9398, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1978.2045, p=0.0000  , df=3
# likelihood ratio test: chi2=1804.9901, p=0.0000  , df=3
# parameter F test:         F=658.9398, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=30.6884 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=92.1297 , p=0.0000  , df=3
# likelihood ratio test: chi2=91.7077 , p=0.0000  , df=3
# parameter F test:         F=30.6884 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=244.8474, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=735.0570, p=0.0000  , df=3
# likelihood ratio test: chi2=709.2891, p=0.0000  , df=3
# parameter F test:         F=244.8474, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=298.4290, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=895.9144, p=0.0000  , df=3
# likelihood ratio test: chi2=858.0172, p=0.0000  , df=3
# parameter F test:         F=298.4290, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=215.6907, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=647.5256, p=0.0000  , df=3
# likelihood ratio test: chi2=627.4186, p=0.0000  , df=3
# parameter F test:         F=215.6907, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=160.3896, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=481.5059, p=0.0000  , df=3
# likelihood ratio test: chi2=470.2694, p=0.0000  , df=3
# parameter F test:         F=160.3896, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=236.8205, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=710.9594, p=0.0000  , df=3
# likelihood ratio test: chi2=686.8168, p=0.0000  , df=3
# parameter F test:         F=236.8205, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=285.8896, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=858.2699, p=0.0000  , df=3
# likelihood ratio test: chi2=823.4091, p=0.0000  , df=3
# parameter F test:         F=285.8896, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=356.3810, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1069.8920, p=0.0000  , df=3
# likelihood ratio test: chi2=1016.4240, p=0.0000  , df=3
# parameter F test:         F=356.3810, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=330.9397, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=993.5148, p=0.0000  , df=3
# likelihood ratio test: chi2=947.1913, p=0.0000  , df=3
# parameter F test:         F=330.9397, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=43.4142 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=130.3337, p=0.0000  , df=3
# likelihood ratio test: chi2=129.4914, p=0.0000  , df=3
# parameter F test:         F=43.4142 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=373.9318, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1122.5813, p=0.0000  , df=3
# likelihood ratio test: chi2=1063.9066, p=0.0000  , df=3
# parameter F test:         F=373.9318, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=152.6809, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=458.3636, p=0.0000  , df=3
# likelihood ratio test: chi2=448.1662, p=0.0000  , df=3
# parameter F test:         F=152.6809, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=174.6510, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=524.3200, p=0.0000  , df=3
# likelihood ratio test: chi2=511.0329, p=0.0000  , df=3
# parameter F test:         F=174.6510, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=688.3078, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=2066.3703, p=0.0000  , df=3
# likelihood ratio test: chi2=1878.3220, p=0.0000  , df=3
# parameter F test:         F=688.3078, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=37.3437 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=112.1096, p=0.0000  , df=3
# likelihood ratio test: chi2=111.4856, p=0.0000  , df=3
# parameter F test:         F=37.3437 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=372.9488, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1119.6305, p=0.0000  , df=3
# likelihood ratio test: chi2=1061.2534, p=0.0000  , df=3
# parameter F test:         F=372.9488, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=622.4721, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1868.7249, p=0.0000  , df=3
# likelihood ratio test: chi2=1713.1752, p=0.0000  , df=3
# parameter F test:         F=622.4721, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=299.5724, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=899.3470, p=0.0000  , df=3
# likelihood ratio test: chi2=861.1671, p=0.0000  , df=3
# parameter F test:         F=299.5724, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=82.0311 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=246.2657, p=0.0000  , df=3
# likelihood ratio test: chi2=243.2814, p=0.0000  , df=3
# parameter F test:         F=82.0311 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=43.7333 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=131.2917, p=0.0000  , df=3
# likelihood ratio test: chi2=130.4371, p=0.0000  , df=3
# parameter F test:         F=43.7333 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=94.4761 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=283.6270, p=0.0000  , df=3
# likelihood ratio test: chi2=279.6781, p=0.0000  , df=3
# parameter F test:         F=94.4761 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=60.5237 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=181.6983, p=0.0000  , df=3
# likelihood ratio test: chi2=180.0668, p=0.0000  , df=3
# parameter F test:         F=60.5237 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=86.6203 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=260.0431, p=0.0000  , df=3
# likelihood ratio test: chi2=256.7185, p=0.0000  , df=3
# parameter F test:         F=86.6203 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=76.5019 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=229.6665, p=0.0000  , df=3
# likelihood ratio test: chi2=227.0681, p=0.0000  , df=3
# parameter F test:         F=76.5019 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=73.7764 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=221.4843, p=0.0000  , df=3
# likelihood ratio test: chi2=219.0664, p=0.0000  , df=3
# parameter F test:         F=73.7764 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=42.7759 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=128.4177, p=0.0000  , df=3
# likelihood ratio test: chi2=127.5999, p=0.0000  , df=3
# parameter F test:         F=42.7759 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=44.5341 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=133.6959, p=0.0000  , df=3
# likelihood ratio test: chi2=132.8098, p=0.0000  , df=3
# parameter F test:         F=44.5341 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=62.6883 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=188.1967, p=0.0000  , df=3
# likelihood ratio test: chi2=186.4471, p=0.0000  , df=3
# parameter F test:         F=62.6883 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=53.3207 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=160.0742, p=0.0000  , df=3
# likelihood ratio test: chi2=158.8061, p=0.0000  , df=3
# parameter F test:         F=53.3207 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=42.9967 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=129.0806, p=0.0000  , df=3
# likelihood ratio test: chi2=128.2544, p=0.0000  , df=3
# parameter F test:         F=42.9967 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=60.2651 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=180.9220, p=0.0000  , df=3
# likelihood ratio test: chi2=179.3043, p=0.0000  , df=3
# parameter F test:         F=60.2651 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=66.1191 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=198.4963, p=0.0000  , df=3
# likelihood ratio test: chi2=196.5514, p=0.0000  , df=3
# parameter F test:         F=66.1191 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=37.3471 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=112.1197, p=0.0000  , df=3
# likelihood ratio test: chi2=111.4956, p=0.0000  , df=3
# parameter F test:         F=37.3471 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=151.5518, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=454.9739, p=0.0000  , df=3
# likelihood ratio test: chi2=444.9245, p=0.0000  , df=3
# parameter F test:         F=151.5518, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=109.5565, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=328.8997, p=0.0000  , df=3
# likelihood ratio test: chi2=323.6051, p=0.0000  , df=3
# parameter F test:         F=109.5565, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=81.4090 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=244.3981, p=0.0000  , df=3
# likelihood ratio test: chi2=241.4585, p=0.0000  , df=3
# parameter F test:         F=81.4090 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=47.3698 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=142.2089, p=0.0000  , df=3
# likelihood ratio test: chi2=141.2069, p=0.0000  , df=3
# parameter F test:         F=47.3698 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=63.8832 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=191.7838, p=0.0000  , df=3
# likelihood ratio test: chi2=189.9674, p=0.0000  , df=3
# parameter F test:         F=63.8832 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=61.5871 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=184.8909, p=0.0000  , df=3
# likelihood ratio test: chi2=183.2019, p=0.0000  , df=3
# parameter F test:         F=61.5871 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=42.4273 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=127.3711, p=0.0000  , df=3
# likelihood ratio test: chi2=126.5665, p=0.0000  , df=3
# parameter F test:         F=42.4273 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=60.4624 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=181.5143, p=0.0000  , df=3
# likelihood ratio test: chi2=179.8862, p=0.0000  , df=3
# parameter F test:         F=60.4624 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=54.8322 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=164.6117, p=0.0000  , df=3
# likelihood ratio test: chi2=163.2712, p=0.0000  , df=3
# parameter F test:         F=54.8322 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=67.0724 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=201.3582, p=0.0000  , df=3
# likelihood ratio test: chi2=199.3571, p=0.0000  , df=3
# parameter F test:         F=67.0724 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=74.2870 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=223.0173, p=0.0000  , df=3
# likelihood ratio test: chi2=220.5661, p=0.0000  , df=3
# parameter F test:         F=74.2870 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=60.0449 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=180.2610, p=0.0000  , df=3
# likelihood ratio test: chi2=178.6551, p=0.0000  , df=3
# parameter F test:         F=60.0449 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=74.1398 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=222.5752, p=0.0000  , df=3
# likelihood ratio test: chi2=220.1337, p=0.0000  , df=3
# parameter F test:         F=74.1398 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=91.7163 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=275.3418, p=0.0000  , df=3
# likelihood ratio test: chi2=271.6182, p=0.0000  , df=3
# parameter F test:         F=91.7163 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=58.0663 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=174.3209, p=0.0000  , df=3
# likelihood ratio test: chi2=172.8185, p=0.0000  , df=3
# parameter F test:         F=58.0663 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=70.9133 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=212.8890, p=0.0000  , df=3
# likelihood ratio test: chi2=210.6539, p=0.0000  , df=3
# parameter F test:         F=70.9133 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=69.3033 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=208.0556, p=0.0000  , df=3
# likelihood ratio test: chi2=205.9201, p=0.0000  , df=3
# parameter F test:         F=69.3033 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=62.3946 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=187.3150, p=0.0000  , df=3
# likelihood ratio test: chi2=185.5817, p=0.0000  , df=3
# parameter F test:         F=62.3946 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=78.3313 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=235.1586, p=0.0000  , df=3
# likelihood ratio test: chi2=232.4354, p=0.0000  , df=3
# parameter F test:         F=78.3313 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=75.5082 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=226.6835, p=0.0000  , df=3
# likelihood ratio test: chi2=224.1516, p=0.0000  , df=3
# parameter F test:         F=75.5082 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=53.9624 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=162.0008, p=0.0000  , df=3
# likelihood ratio test: chi2=160.7022, p=0.0000  , df=3
# parameter F test:         F=53.9624 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=79.1198 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=237.5256, p=0.0000  , df=3
# likelihood ratio test: chi2=234.7477, p=0.0000  , df=3
# parameter F test:         F=79.1198 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=67.9077 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=203.8659, p=0.0000  , df=3
# likelihood ratio test: chi2=201.8151, p=0.0000  , df=3
# parameter F test:         F=67.9077 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=87.7282 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=263.3690, p=0.0000  , df=3
# likelihood ratio test: chi2=259.9595, p=0.0000  , df=3
# parameter F test:         F=87.7282 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=94.7841 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=284.5515, p=0.0000  , df=3
# likelihood ratio test: chi2=280.5770, p=0.0000  , df=3
# parameter F test:         F=94.7841 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=296.1981, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=889.2169, p=0.0000  , df=3
# likelihood ratio test: chi2=851.8687, p=0.0000  , df=3
# parameter F test:         F=296.1981, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=589.5992, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1770.0371, p=0.0000  , df=3
# likelihood ratio test: chi2=1629.6821, p=0.0000  , df=3
# parameter F test:         F=589.5992, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=842.2212, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=2528.4340, p=0.0000  , df=3
# likelihood ratio test: chi2=2254.0861, p=0.0000  , df=3
# parameter F test:         F=842.2212, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=450.6803, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1352.9884, p=0.0000  , df=3
# likelihood ratio test: chi2=1268.9359, p=0.0000  , df=3
# parameter F test:         F=450.6803, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=512.1309, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1537.4692, p=0.0000  , df=3
# likelihood ratio test: chi2=1430.1191, p=0.0000  , df=3
# parameter F test:         F=512.1309, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=287.9272, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=864.3869, p=0.0000  , df=3
# likelihood ratio test: chi2=829.0409, p=0.0000  , df=3
# parameter F test:         F=287.9272, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=459.2535, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=1378.7258, p=0.0000  , df=3
# likelihood ratio test: chi2=1291.5796, p=0.0000  , df=3
# parameter F test:         F=459.2535, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=140.3573, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=421.3670, p=0.0000  , df=3
# likelihood ratio test: chi2=412.7288, p=0.0000  , df=3
# parameter F test:         F=140.3573, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=143.0189, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=429.3574, p=0.0000  , df=3
# likelihood ratio test: chi2=420.3930, p=0.0000  , df=3
# parameter F test:         F=143.0189, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=230.1934, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=691.0641, p=0.0000  , df=3
# likelihood ratio test: chi2=668.2251, p=0.0000  , df=3
# parameter F test:         F=230.1934, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=15.9338 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=47.8349 , p=0.0000  , df=3
# likelihood ratio test: chi2=47.7208 , p=0.0000  , df=3
# parameter F test:         F=15.9338 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ...
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=203.8938, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=612.1099, p=0.0000  , df=3
# likelihood ratio test: chi2=594.1018, p=0.0000  , df=3
# parameter F test:         F=203.8938, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=189.4769, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=568.8290, p=0.0000  , df=3
# likelihood ratio test: chi2=553.2347, p=0.0000  , df=3
# parameter F test:         F=189.4769, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=153.0984, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=459.6169, p=0.0000  , df=3
# likelihood ratio test: chi2=449.3644, p=0.0000  , df=3
# parameter F test:         F=153.0984, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=305.6588, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=917.6191, p=0.0000  , df=3
# likelihood ratio test: chi2=877.9170, p=0.0000  , df=3
# parameter F test:         F=305.6588, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=222.6658, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=668.4656, p=0.0000  , df=3
# likelihood ratio test: chi2=647.0654, p=0.0000  , df=3
# parameter F test:         F=222.6658, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=284.7411, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=854.8217, p=0.0000  , df=3
# likelihood ratio test: chi2=820.2330, p=0.0000  , df=3
# parameter F test:         F=284.7411, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=263.6624, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=791.5414, p=0.0000  , df=3
# likelihood ratio test: chi2=761.7668, p=0.0000  , df=3
# parameter F test:         F=263.6624, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=263.0460, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=789.6909, p=0.0000  , df=3
# likelihood ratio test: chi2=760.0520, p=0.0000  , df=3
# parameter F test:         F=263.0460, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=161.7151, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=485.4852, p=0.0000  , df=3
# likelihood ratio test: chi2=474.0652, p=0.0000  , df=3
# parameter F test:         F=161.7151, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=177.8066, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=533.7937, p=0.0000  , df=3
# likelihood ratio test: chi2=520.0305, p=0.0000  , df=3
# parameter F test:         F=177.8066, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=195.7740, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=587.7336, p=0.0000  , df=3
# likelihood ratio test: chi2=571.1055, p=0.0000  , df=3
# parameter F test:         F=195.7740, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=205.8181, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=617.8871, p=0.0000  , df=3
# likelihood ratio test: chi2=599.5442, p=0.0000  , df=3
# parameter F test:         F=205.8181, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=83.9118 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=251.9118, p=0.0000  , df=3
# likelihood ratio test: chi2=248.7902, p=0.0000  , df=3
# parameter F test:         F=83.9118 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=303.7020, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=911.7443, p=0.0000  , df=3
# likelihood ratio test: chi2=872.5347, p=0.0000  , df=3
# parameter F test:         F=303.7020, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=139.1021, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=417.5988, p=0.0000  , df=3
# likelihood ratio test: chi2=409.1122, p=0.0000  , df=3
# parameter F test:         F=139.1021, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=45.9130 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=137.8357, p=0.0000  , df=3
# likelihood ratio test: chi2=136.8941, p=0.0000  , df=3
# parameter F test:         F=45.9130 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=31.0602 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=93.2459 , p=0.0000  , df=3
# likelihood ratio test: chi2=92.8137 , p=0.0000  , df=3
# parameter F test:         F=31.0602 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=31.6901 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=95.1370 , p=0.0000  , df=3
# likelihood ratio test: chi2=94.6871 , p=0.0000  , df=3
# parameter F test:         F=31.6901 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=73.5609 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=220.8374, p=0.0000  , df=3
# likelihood ratio test: chi2=218.4335, p=0.0000  , df=3
# parameter F test:         F=73.5609 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=39.3696 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=118.1917, p=0.0000  , df=3
# likelihood ratio test: chi2=117.4985, p=0.0000  , df=3
# parameter F test:         F=39.3696 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=40.7425 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=122.3131, p=0.0000  , df=3
# likelihood ratio test: chi2=121.5709, p=0.0000  , df=3
# parameter F test:         F=40.7425 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=63.4333 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=190.4331, p=0.0000  , df=3
# likelihood ratio test: chi2=188.6420, p=0.0000  , df=3
# parameter F test:         F=63.4333 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=89.0884 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=267.4524, p=0.0000  , df=3
# likelihood ratio test: chi2=263.9374, p=0.0000  , df=3
# parameter F test:         F=89.0884 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=44.6533 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=134.0537, p=0.0000  , df=3
# likelihood ratio test: chi2=133.1629, p=0.0000  , df=3
# parameter F test:         F=44.6533 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=36.0454 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=108.2118, p=0.0000  , df=3
# likelihood ratio test: chi2=107.6304, p=0.0000  , df=3
# parameter F test:         F=36.0454 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=40.6242 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=121.9579, p=0.0000  , df=3
# likelihood ratio test: chi2=121.2200, p=0.0000  , df=3
# parameter F test:         F=40.6242 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=60.3480 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=181.1708, p=0.0000  , df=3
# likelihood ratio test: chi2=179.5488, p=0.0000  , df=3
# parameter F test:         F=60.3480 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=43.2869 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=129.9518, p=0.0000  , df=3
# likelihood ratio test: chi2=129.1144, p=0.0000  , df=3
# parameter F test:         F=43.2869 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=33.2998 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=99.9693 , p=0.0000  , df=3
# likelihood ratio test: chi2=99.4727 , p=0.0000  , df=3
# parameter F test:         F=33.2998 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=39.8196 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=119.5425, p=0.0000  , df=3
# likelihood ratio test: chi2=118.8334, p=0.0000  , df=3
# parameter F test:         F=39.8196 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=116.3352, p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=349.2503, p=0.0000  , df=3
# likelihood ratio test: chi2=343.2881, p=0.0000  , df=3
# parameter F test:         F=116.3352, p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=27.8668 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=83.6589 , p=0.0000  , df=3
# likelihood ratio test: chi2=83.3108 , p=0.0000  , df=3
# parameter F test:         F=27.8668 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=76.8836 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=230.8123, p=0.0000  , df=3
# likelihood ratio test: chi2=228.1881, p=0.0000  , df=3
# parameter F test:         F=76.8836 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=39.4186 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=118.3388, p=0.0000  , df=3
# likelihood ratio test: chi2=117.6439, p=0.0000  , df=3
# parameter F test:         F=39.4186 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=50.6648 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=152.1008, p=0.0000  , df=3
# likelihood ratio test: chi2=150.9553, p=0.0000  , df=3
# parameter F test:         F=50.6648 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=65.6561 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=197.1064, p=0.0000  , df=3
# likelihood ratio test: chi2=195.1884, p=0.0000  , df=3
# parameter F test:         F=65.6561 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=28.3357 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=85.0667 , p=0.0000  , df=3
# likelihood ratio test: chi2=84.7068 , p=0.0000  , df=3
# parameter F test:         F=28.3357 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=54.0839 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=162.3653, p=0.0000  , df=3
# likelihood ratio test: chi2=161.0609, p=0.0000  , df=3
# parameter F test:         F=54.0839 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=63.5939 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=190.9154, p=0.0000  , df=3
# likelihood ratio test: chi2=189.1153, p=0.0000  , df=3
# parameter F test:         F=63.5939 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=22.2612 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=66.8303 , p=0.0000  , df=3
# likelihood ratio test: chi2=66.6079 , p=0.0000  , df=3
# parameter F test:         F=22.2612 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=58.1460 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=174.5603, p=0.0000  , df=3
# likelihood ratio test: chi2=173.0538, p=0.0000  , df=3
# parameter F test:         F=58.1460 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=60.6775 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=182.1601, p=0.0000  , df=3
# likelihood ratio test: chi2=180.5204, p=0.0000  , df=3
# parameter F test:         F=60.6775 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=23.1552 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=69.5142 , p=0.0000  , df=3
# likelihood ratio test: chi2=69.2736 , p=0.0000  , df=3
# parameter F test:         F=23.1552 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=50.9898 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=153.0766, p=0.0000  , df=3
# likelihood ratio test: chi2=151.9165, p=0.0000  , df=3
# parameter F test:         F=50.9898 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=32.6008 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=97.8711 , p=0.0000  , df=3
# likelihood ratio test: chi2=97.3951 , p=0.0000  , df=3
# parameter F test:         F=32.6008 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=49.3204 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=148.0649, p=0.0000  , df=3
# likelihood ratio test: chi2=146.9792, p=0.0000  , df=3
# parameter F test:         F=49.3204 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=28.2762 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=84.8881 , p=0.0000  , df=3
# likelihood ratio test: chi2=84.5297 , p=0.0000  , df=3
# parameter F test:         F=28.2762 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=36.3506 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=109.1281, p=0.0000  , df=3
# likelihood ratio test: chi2=108.5367, p=0.0000  , df=3
# parameter F test:         F=36.3506 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=47.3382 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=142.1141, p=0.0000  , df=3
# likelihood ratio test: chi2=141.1134, p=0.0000  , df=3
# parameter F test:         F=47.3382 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=57.2895 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=171.9890, p=0.0000  , df=3
# likelihood ratio test: chi2=170.5263, p=0.0000  , df=3
# parameter F test:         F=57.2895 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=25.0712 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=75.2662 , p=0.0000  , df=3
# likelihood ratio test: chi2=74.9842 , p=0.0000  , df=3
# parameter F test:         F=25.0712 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=80.0755 , p=0.0000  , df_denom=9990, df_num=3
# ssr based chi2 test:   chi2=240.3948, p=0.0000  , df=3
# likelihood ratio test: chi2=237.5500, p=0.0000  , df=3
# parameter F test:         F=80.0755 , p=0.0000  , df_denom=9990, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# The x values include a column with constant values and so the test statistic cannot be computed.

# %%
channel_map_and_all_trials_df[""]
# Out:
# 0      [0.029845133, 0.19697787, 0.42579055, 0.869488...
# 1      [-0.5013982, -0.55511945, 0.105452806, 0.65858...
# 2      [-1.7310177, -1.96182, -1.9240162, -1.9379439,...
# 3      [-0.60287166, -0.23279203, 0.055710915, -0.240...
# 4      [-0.49741888, -0.11142183, -0.027855458, -0.44...
#                              ...
# 632    [1.2422042, 2.207114, 2.5181334, 2.0459833, 1....
# 633    [-1.4220709, -1.6881236, -1.6899972, -1.588822...
# 634    [0.17049861, 0.19485556, 0.31101945, 0.7026042...
# 635    [0.2192125, 0.09742778, -0.41406804, -0.861861...
# 636    [-1.28155, -1.3433791, -1.1297874, -0.9424264,...
# Name: BLA_trace, Length: 1274, dtype: object

# %%
channel_map_and_all_trials_df
# Out:
#            time  state                                      recording_dir  \
# 0     4359951.0    1.0            20221214_125409_om_and_comp_6_1_and_6_3
# 1     5959954.0    1.0            20221214_125409_om_and_comp_6_1_and_6_3
# 2     7759946.0    1.0            20221214_125409_om_and_comp_6_1_and_6_3
# 3     9359945.0    1.0            20221214_125409_om_and_comp_6_1_and_6_3
# 4    10859943.0    1.0            20221214_125409_om_and_comp_6_1_and_6_3
# ..          ...    ...                                                ...
# 632  29281401.0    1.0  20230621_111240_standard_comp_to_omission_D5_s...
# 633  30881425.0    1.0  20230621_111240_standard_comp_to_omission_D5_s...
# 634  32281440.0    1.0  20230621_111240_standard_comp_to_omission_D5_s...
# 635  34481464.0    1.0  20230621_111240_standard_comp_to_omission_D5_s...
# 636  35681479.0    1.0  20230621_111240_standard_comp_to_omission_D5_s...
#
#                                         recording_file           din  \
# 0    20221214_125409_om_and_comp_6_1_top_1_base_2_v...  dio_ECU_Din1
# 1    20221214_125409_om_and_comp_6_1_top_1_base_2_v...  dio_ECU_Din1
# 2    20221214_125409_om_and_comp_6_1_top_1_base_2_v...  dio_ECU_Din1
# 3    20221214_125409_om_and_comp_6_1_top_1_base_2_v...  dio_ECU_Din1
# 4    20221214_125409_om_and_comp_6_1_top_1_base_2_v...  dio_ECU_Din1
# ..                                                 ...           ...
# 632  20230621_111240_standard_comp_to_omission_D5_s...  dio_ECU_Din1
# 633  20230621_111240_standard_comp_to_omission_D5_s...  dio_ECU_Din1
# 634  20230621_111240_standard_comp_to_omission_D5_s...  dio_ECU_Din1
# 635  20230621_111240_standard_comp_to_omission_D5_s...  dio_ECU_Din1
# 636  20230621_111240_standard_comp_to_omission_D5_s...  dio_ECU_Din1
#
#      time_stamp_index                                         video_file  \
# 0           1408048.0  20221214_125409_om_and_comp_6_1_and_6_3.1.vide...
# 1           3008051.0  20221214_125409_om_and_comp_6_1_and_6_3.1.vide...
# 2           4808043.0  20221214_125409_om_and_comp_6_1_and_6_3.1.vide...
# 3           6408042.0  20221214_125409_om_and_comp_6_1_and_6_3.1.vide...
# 4           7908040.0  20221214_125409_om_and_comp_6_1_and_6_3.1.vide...
# ..                ...                                                ...
# 632        26088357.0  20230621_111240_standard_comp_to_omission_D5_s...
# 633        27688381.0  20230621_111240_standard_comp_to_omission_D5_s...
# 634        29088396.0  20230621_111240_standard_comp_to_omission_D5_s...
# 635        31288420.0  20230621_111240_standard_comp_to_omission_D5_s...
# 636        32488435.0  20230621_111240_standard_comp_to_omission_D5_s...
#
#      video_frame  video_number             subject_info  ...  \
# 0         1405.0           1.0  6_1_top_1_base_2_vs_6_3  ...
# 1         3002.0           1.0  6_1_top_1_base_2_vs_6_3  ...
# 2         4798.0           1.0  6_1_top_1_base_2_vs_6_3  ...
# 3         6395.0           1.0  6_1_top_1_base_2_vs_6_3  ...
# 4         7892.0           1.0  6_1_top_1_base_2_vs_6_3  ...
# ..           ...           ...                      ...  ...
# 632      26040.0           2.0           1-4_t3b3L_box1  ...
# 633      27636.0           2.0           1-4_t3b3L_box1  ...
# 634      29033.0           2.0           1-4_t3b3L_box1  ...
# 635      31230.0           2.0           1-4_t3b3L_box1  ...
# 636      32427.0           2.0           1-4_t3b3L_box1  ...
#
#     spike_interface_MD                                         all_ch_lfp  \
# 0                 16.0  ZScoreRecording: 32 channels - 1 segments - 1....
# 1                 16.0  ZScoreRecording: 32 channels - 1 segments - 1....
# 2                 16.0  ZScoreRecording: 32 channels - 1 segments - 1....
# 3                 16.0  ZScoreRecording: 32 channels - 1 segments - 1....
# 4                 16.0  ZScoreRecording: 32 channels - 1 segments - 1....
# ..                 ...                                                ...
# 632               28.0  ZScoreRecording: 32 channels - 1 segments - 1....
# 633               28.0  ZScoreRecording: 32 channels - 1 segments - 1....
# 634               28.0  ZScoreRecording: 32 channels - 1 segments - 1....
# 635               28.0  ZScoreRecording: 32 channels - 1 segments - 1....
# 636               28.0  ZScoreRecording: 32 channels - 1 segments - 1....
#
#     trial_or_baseline  trial_or_baseline_entire_lfp_index  \
# 0               trial                      (70402, 80402)
# 1               trial                    (150402, 160402)
# 2               trial                    (240402, 250402)
# 3               trial                    (320402, 330402)
# 4               trial                    (395402, 405402)
# ..                ...                                 ...
# 632          baseline                  (1294417, 1304417)
# 633          baseline                  (1374419, 1384419)
# 634          baseline                  (1444419, 1454419)
# 635          baseline                  (1554421, 1564421)
# 636          baseline                  (1614421, 1624421)
#
#                                              BLA_trace  \
# 0    [0.029845133, 0.19697787, 0.42579055, 0.869488...
# 1    [-0.5013982, -0.55511945, 0.105452806, 0.65858...
# 2    [-1.7310177, -1.96182, -1.9240162, -1.9379439,...
# 3    [-0.60287166, -0.23279203, 0.055710915, -0.240...
# 4    [-0.49741888, -0.11142183, -0.027855458, -0.44...
# ..                                                 ...
# 632  [1.2422042, 2.207114, 2.5181334, 2.0459833, 1....
# 633  [-1.4220709, -1.6881236, -1.6899972, -1.588822...
# 634  [0.17049861, 0.19485556, 0.31101945, 0.7026042...
# 635  [0.2192125, 0.09742778, -0.41406804, -0.861861...
# 636  [-1.28155, -1.3433791, -1.1297874, -0.9424264,...
#
#                                               LH_trace  \
# 0    [-1.2876818, -1.2059243, -1.2297702, -1.073068...
# 1    [-0.9027399, -1.2536162, -0.5382374, 0.2078005...
# 2    [-2.3266842, -2.7286592, -2.3266842, -1.972401...
# 3    [-2.759318, -2.1631691, -1.7475681, -2.1529496...
# 4    [0.14988889, 0.5859293, 0.7596641, 0.27252525,...
# ..                                                 ...
# 632  [-0.72688836, -0.42565534, 0.3045073, 0.124422...
# 633  [-0.03601699, -0.36016992, -0.5697233, -0.6450...
# 634  [1.1918349, 1.3784684, 1.4897937, 1.3948398, 1...
# 635  [-0.68432283, -1.01175, -1.0313957, -0.5893689...
# 636  [-2.167568, -2.2003107, -1.9187233, -1.7058957...
#
#                                               MD_trace  \
# 0    [-0.6062626, -0.34118676, -0.020996109, 0.4094...
# 1    [-1.0498054, -1.2781382, -0.76898247, -0.47503...
# 2    [-1.5878308, -1.7689222, -1.5852063, -1.658692...
# 3    [-2.4670427, -2.4145525, -2.2360857, -2.493288...
# 4    [-0.59314007, 0.1338502, 0.47503698, -0.002624...
# ..                                                 ...
# 632  [-0.8399434, -0.62995756, 0.14635377, -0.00636...
# 633  [-0.3404316, -0.71267927, -0.9640259, -1.03083...
# 634  [1.3521816, 1.4985354, 1.5748938, 1.4794457, 1...
# 635  [-0.65541035, -0.9385731, -1.0531108, -0.85585...
# 636  [-1.9853208, -2.0903137, -1.9057807, -1.670342...
#
#                                             mPFC_trace  \
# 0    [-1.2641292, -1.3847351, -1.3154984, -0.913478...
# 1    [-1.0474851, -1.7934552, -1.9832981, -1.876092...
# 2    [-1.8693924, -1.8693924, -1.404836, -1.1167219...
# 3    [-2.5952616, -2.0860364, -1.5879785, -1.748786...
# 4    [0.5672947, 0.8576424, 0.92911255, 0.39531955,...
# ..                                                 ...
# 632  [-1.5326667, -1.3743334, -0.7758333, -1.095666...
# 633  [-0.09183333, -0.47183332, -0.817, -1.0735, -1...
# 634  [1.5706667, 1.4028333, 1.1653334, 1.1843333, 1...
# 635  [1.7036667, 1.2951666, 0.836, 0.95316666, 1.16...
# 636  [-1.3078333, -1.4566667, -1.2761667, -0.915166...
#
#                                             vHPC_trace  \
# 0    [-0.78455, -0.7881, -0.6674, -0.5029167, -0.30...
# 1    [-1.4981, -1.7051834, -1.5123, -1.2365834, -1....
# 2    [-1.6412834, -1.6341833, -1.45905, -1.3939667,...
# 3    [-0.98808336, -0.8756667, -0.65675, -0.5845666...
# 4    [0.7798167, 0.7526, 0.57865, 0.29228333, 0.196...
# ..                                                 ...
# 632  [-0.57296234, -0.91625625, -0.85098207, -0.863...
# 633  [-0.47142473, -0.82438886, -1.0153763, -1.1217...
# 634  [-0.58505017, -0.44483155, -0.2465914, -0.0531...
# 635  [-0.43757886, -0.3747222, -0.27801973, -0.2054...
# 636  [-1.5448226, -1.5351523, -1.4215269, -1.281308...
#
#      outcome_and_trial_or_baseline
# 0                   rewarded_trial
# 1                   rewarded_trial
# 2                   rewarded_trial
# 3                   omission_trial
# 4                   rewarded_trial
# ..                             ...
# 632                  lose_baseline
# 633                  lose_baseline
# 634                  lose_baseline
# 635                  lose_baseline
# 636                  lose_baseline
#
# [1274 rows x 38 columns]

# %%
granger_value
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 granger_value
#
# NameError: name 'granger_value' is not defined

# %% [markdown]
# - Filtering out the outliers

# %%
band_to_power_correlation = defaultdict(dict)
for band in ALL_BANDS:
    # Getting all the pairs of brain regions
    band_averaged_columns = [col for col in channel_map_and_all_trials_df.columns if "averaged_{}".format(band) in col]
    band_to_power_correlation[band]["brain_region_pairs"] = generate_pairs(band_averaged_columns)
    print(band_to_power_correlation[band]["brain_region_pairs"])

    # Removing rows that are outliers
    filtered_df = channel_map_and_all_trials_df.copy()
    
    for col in band_averaged_columns:
        # filtered_df = filtered_df[filtered_df[col] <= 3]
        # Assuming data is a 1D numpy array
        Q1 = np.percentile(filtered_df[col], 25)
        Q3 = np.percentile(filtered_df[col], 75)
        IQR = Q3 - Q1
        band_to_power_correlation[band]["outlier_removed_df"] = filtered_df[(filtered_df[col] >= Q1 - 1.5 * IQR) & (filtered_df[col] <= Q3 + 1.5 * IQR)]


    
    # Getting the mean and standard deviation

# %%
band_to_power_correlation = defaultdict(dict)
for band in ALL_BANDS:
    # Getting all the pairs of brain regions
    band_averaged_columns = [col for col in channel_map_and_all_trials_df.columns if "averaged_{}".format(band) in col]
    band_to_power_correlation[band]["brain_region_pairs"] = generate_pairs(band_averaged_columns)
    print(band_to_power_correlation[band]["brain_region_pairs"])

    # Removing rows that are outliers
    filtered_df = channel_map_and_all_trials_df.copy()
    
    for col in band_averaged_columns:
        # filtered_df = filtered_df[filtered_df[col] <= 3]
        # Assuming data is a 1D numpy array
        Q1 = np.percentile(filtered_df[col], 25)
        Q3 = np.percentile(filtered_df[col], 75)
        IQR = Q3 - Q1
        filtered_df = filtered_df[(filtered_df[col] >= Q1 - 1.5 * IQR) & (filtered_df[col] <= Q3 + 1.5 * IQR)]
    band_to_power_correlation[band]["outlier_removed_df"] = filtered_df

# %% [raw]
# band_to_power_correlation = defaultdict(dict)
# for band in ALL_BANDS:
#     # Getting all the pairs of brain regions
#     band_averaged_columns = [col for col in channel_map_and_all_trials_df.columns if "averaged_{}".format(band) in col]
#     band_to_power_correlation[band]["brain_region_pairs"] = generate_pairs(band_averaged_columns)
#     print(band_to_power_correlation[band]["brain_region_pairs"])
#
#     # code to filter based on std
#     filtered_df = channel_map_and_all_trials_df.copy()
#     for col in band_averaged_columns:
#         # Assuming data is a 1D numpy array
#         threshold = 1
#         mean = np.median(filtered_df[col])
#         std = np.std(filtered_df[col])
#         filtered_df = filtered_df[np.abs(filtered_df[col] - mean) < threshold * std]
#     band_to_power_correlation[band]["outlier_removed_df"] = filtered_df

# %%
channel_map_and_all_trials_df.shape

# %%
band_to_power_correlation[band]["outlier_removed_df"].shape

# %% [raw]
# # code to filter based on std
# filtered_df = channel_map_and_all_trials_df.copy()
# for col in averaged_col:
#     # Assuming data is a 1D numpy array
#     threshold = 3.5
#     mean = np.mean(filtered_df[col])
#     std = np.std(filtered_df[col])
#     filtered_df = filtered_df[np.abs(filtered_df[col] - mean) < threshold * std]

# %% [markdown]
# - Plotting all of the conditions

# %%
for band in ALL_BANDS:
    for region_1, region_2 in band_to_power_correlation[band]["brain_region_pairs"]:
        region_1_basename = region_1.split("_")[0]
        region_2_basename = region_2.split("_")[0]
        x = band_to_power_correlation[band]["outlier_removed_df"][region_1]
        y = band_to_power_correlation[band]["outlier_removed_df"][region_2]
        
        # Perform linear regression to get the slope, intercept and r-value (correlation coefficient)
        slope, intercept, r_value, p_value, std_err = linregress(x, y)
        
        # Create a line of best fit using the slope and intercept
        line = slope * x + intercept
        
        # Create scatter plot
        sns.scatterplot(x=x, y=y, data=band_to_power_correlation[band]["outlier_removed_df"], hue='outcome_and_trial_or_baseline', palette=BASELINE_OUTCOME_TO_COLOR)
        
        # Plot line of best fit
        plt.plot(x, line, color='red')
        
        # Add R² value to the plot
        plt.text(0.1, 0.9, f'R = {r_value:.2f}', transform=plt.gca().transAxes)
        
        # Add labels and legend
        plt.title("Power correlation of Z-scored {} band LFP: {} and {}".format(band, region_2_basename, region_1_basename))
        plt.xlabel('{} {} power of Z-scored LFP'.format(band, region_1_basename))
        plt.ylabel('{} {} power of Z-scored LFP'.format(band, region_2_basename))
        plt.legend(loc="lower right")
        plt.tight_layout()
        plt.savefig("./proc/power_correlation/zscored/{}/all_condition_{}_{}_power_correlation_of_zscored_{}_lfp.png".format(band, region_1_basename, region_2_basename, band))
        # Display the plot
        plt.show()

# %%
raise ValueError()

# %%
channel_map_and_all_trials_df = filtered_df

# %%
channel_map_and_all_trials_df["trial_outcome"].unique()

# %%
channel_map_and_all_trials_df["trial_or_baseline"]

# %% [raw]
# for band in ALL_BANDS:
#     for region_1, region_2 in band_to_power_correlation[band]["brain_region_pairs"]:
#         region_1_basename = region_1.split("_")[0]
#         region_2_basename = region_2.split("_")[0]
#         x = band_to_power_correlation[band]["outlier_removed_df"][region_1]
#         y = band_to_power_correlation[band]["outlier_removed_df"][region_2]
#
#         # Perform linear regression to get the slope, intercept and r-value (correlation coefficient)
#         slope, intercept, r_value, p_value, std_err = linregress(x, y)
#
#         # Create a line of best fit using the slope and intercept
#         line = slope * x + intercept
#
#         # Create scatter plot
#         sns.scatterplot(x=x, y=y, data=band_to_power_correlation[band]["outlier_removed_df"], hue='outcome_and_trial_or_baseline', palette=BASELINE_OUTCOME_TO_COLOR)
#
#         # Plot line of best fit
#         plt.plot(x, line, color='red')
#
#         # Add R² value to the plot
#         plt.text(0.1, 0.9, f'R = {r_value:.2f}', transform=plt.gca().transAxes)
#
#         # Add labels and legend
#         plt.title("Power correlation of Z-scored {} band LFP: {} and {}".format(band, region_2_basename, region_1_basename))
#         plt.xlabel('{} {} power of Z-scored LFP'.format(band, region_1_basename))
#         plt.ylabel('{} {} power of Z-scored LFP'.format(band, region_2_basename))
#         plt.legend(loc="lower right")
#         # plt.savefig("./proc/power_correlation/zscored/all_condition_{}_{}_power_correlation_of_zscored_theta_lfp.png".format(region_1_basename, region_2_basename))
#         # Display the plot
#         plt.show()

# %%
for band in ALL_BANDS:
    band_df = band_to_power_correlation[band]["outlier_removed_df"]
    band_to_power_correlation[band]["region_pair_to_outcome_to_r2"] = defaultdict(nested_dict)
    for outcome in band_df["trial_outcome"].unique():
        outcome_df = band_df[band_df["trial_outcome"] == outcome]
        for region_1, region_2 in brain_region_pairs:
            region_1_basename = region_1.split("_")[0]
            region_2_basename = region_2.split("_")[0]
            
            x = outcome_df[region_1]
            y = outcome_df[region_2]
            
            # Perform linear regression to get the slope, intercept and r-value (correlation coefficient)
            slope, intercept, r_value, p_value, std_err = linregress(x, y)
            # Square the r value to get the r squared value
            r2_value = r_value**2
            band_to_power_correlation[band]["region_pair_to_outcome_to_r2"]["{}_{}".format(region_1.split("_")[0], region_2.split("_")[0])][outcome]["r"] = r_value
            band_to_power_correlation[band]["region_pair_to_outcome_to_r2"]["{}_{}".format(region_1.split("_")[0], region_2.split("_")[0])][outcome]["std"] = std_err
            
            # Create a line of best fit using the slope and intercept
            line = slope * x + intercept
            
            # Create scatter plot
            sns.scatterplot(x=x, y=y, data=outcome_df, hue='outcome_and_trial_or_baseline', palette=BASELINE_OUTCOME_TO_COLOR, style='outcome_and_trial_or_baseline', markers=['^', 'o'])
            
            # Plot line of best fit
            plt.plot(x, line, color='red')
            
            # Add R² value to the plot
            plt.text(0.1, 0.9, f'R = {r_value:.2f}', transform=plt.gca().transAxes)
            
            # Add labels and legend
            plt.title("Power Correlation of Z-scored {} LFP: {} and {}".format(band, region_2_basename, region_1_basename))
            plt.xlabel('{} {} Power of Z-scored LFP'.format(region_1_basename, band))
            plt.ylabel('{} {} Power of Z-scored LFP'.format(region_2_basename, band))
            plt.legend(loc="lower right")
            plt.tight_layout()
            plt.savefig("./proc/power_correlation/zscored/{}/{}_{}_{}_power_correlation_of_zscored_{}_lfp.png".format(band, outcome, region_1_basename, region_2_basename, band))
            # Display the plot
            plt.show()

# %%
for band in ALL_BANDS:
    # Convert the nested dictionary to a DataFrame
    data = []
    for group_name, group_data in band_to_power_correlation[band]['region_pair_to_outcome_to_r2'].items():
        for bar_name, bar_dict in group_data.items():
            data.append({"Group": group_name, "Bar": bar_name, "r": bar_dict["r"], "std": bar_dict["std"]})
    df = pd.DataFrame(data)
    
    # Create the bar plot using seaborn
    # sns.catplot(
    #     data=df, 
    #     x='Group', 
    #     y='r2', 
    #     hue='Bar', 
    #     kind='bar', 
    #     height=4, 
    #     aspect=2,
    #     legend=False,
    #     # yerr=df['std'].values,  # This line adds the SEM bars
    #     # capsize=0.1  # This line adds caps on the error bars
    # )
    
    # Create barplot
    ax = sns.barplot(x='Group', y='r', hue='Bar', data=df, ci=None)
    
    # Adding error bars
    groups = df['Group'].unique()
    bars_per_group = df['Bar'].nunique()
    bar_width = 0.8 / bars_per_group
    x_positions = []
    
    for i, group in enumerate(groups):
        num_bars = df[df['Group'] == group].shape[0]
        group_positions = np.linspace(i - bar_width*(num_bars-1)/2, i + bar_width*(num_bars-1)/2, num_bars)
        x_positions.extend(group_positions)
    
    for i, (r2, sem) in enumerate(zip(df['r'], df['std'])):
        plt.errorbar(x_positions[i], r2, yerr=sem, fmt='none', color='black', capsize=5)
    
    
    plt.xticks(rotation=90)
    plt.xlabel("Brain region pairs")
    plt.ylabel("Power correlation r")
    plt.legend(title="Trial Conditions")
    plt.title("{} Power correlations".format(band))
    plt.tight_layout()
    plt.grid()
    
    plt.savefig("./proc/power_correlation/zscored/all_zscored_{}_lfp_power_correlation.png".format(band))
    # Show the plot
    plt.show()

# %%
# Convert the nested dictionary to a DataFrame
data = []
for group_name, group_data in region_pair_to_outcome_to_r2.items():
    for bar_name, bar_dict in group_data.items():
        data.append({"Group": group_name, "Bar": bar_name, "r": bar_dict["r"], "std": bar_dict["std"]})
df = pd.DataFrame(data)

# Create the bar plot using seaborn
# sns.catplot(
#     data=df, 
#     x='Group', 
#     y='r2', 
#     hue='Bar', 
#     kind='bar', 
#     height=4, 
#     aspect=2,
#     legend=False,
#     # yerr=df['std'].values,  # This line adds the SEM bars
#     # capsize=0.1  # This line adds caps on the error bars
# )

# Create barplot
ax = sns.barplot(x='Group', y='r', hue='Bar', data=df, ci=None)

# Adding error bars
groups = df['Group'].unique()
bars_per_group = df['Bar'].nunique()
bar_width = 0.8 / bars_per_group
x_positions = []

for i, group in enumerate(groups):
    num_bars = df[df['Group'] == group].shape[0]
    group_positions = np.linspace(i - bar_width*(num_bars-1)/2, i + bar_width*(num_bars-1)/2, num_bars)
    x_positions.extend(group_positions)

for i, (r2, sem) in enumerate(zip(df['r'], df['std'])):
    plt.errorbar(x_positions[i], r2, yerr=sem, fmt='none', color='black', capsize=5)


plt.xticks(rotation=90)
plt.xlabel("Brain region pairs")
plt.ylabel("Power correlation r")
plt.legend(title="Trial Conditions")
plt.title("Power correlations")
plt.tight_layout()
plt.grid()

plt.savefig("./proc/power_correlation/zscored/all_zscored_lfp_power_correlation.png")
# Show the plot
plt.show()
