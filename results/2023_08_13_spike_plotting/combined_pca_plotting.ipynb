# %% [markdown]
# # Spike Gadgets Ephys and Video Syncing

# %%
import os
import re
import sys
from collections import defaultdict
import random
from random import randrange
import glob
import warnings
import string

# %%
import numpy as np
import pandas as pd
# import cv2
from IPython.display import Video
import matplotlib
import matplotlib.pyplot as plt

# %%
# setting path
sys.path.append('../../../src')

# %%
# %matplotlib inline

# %%
font = {"family": 'Arial'}
        #'size'   : 18}
#        'weight' : 'bold',}

matplotlib.rc('font', **font)

# %%
import spikeinterface

# %%
import spikeinterface as si  # import core only
import spikeinterface.extractors as se
import spikeinterface.toolkit as st
import spikeinterface.sorters as ss
import spikeinterface.comparison as sc
import spikeinterface.widgets as sw
# Out:
# /tmp/ipykernel_2730888/634830499.py:3: DeprecationWarning: The 'toolkit' module is deprecated. Use spikeinterface.preprocessing/postptocessing/qualitymetrics instead
#   import spikeinterface.toolkit as st

# %%
import spikeinterface.core

# %%
from probeinterface import get_probe
from probeinterface.plotting import plot_probe, plot_probe_group
from probeinterface import write_prb, read_prb

# %%
import spikeinterface.full as si

# %% [markdown]
# # Plotting Configurations

# %%
size_ratio = 1

# %%
# Plot Specifics
TITLESIZE = 60 * size_ratio
AXESLABEL = 60 * size_ratio
AXESTICKS = 45 * size_ratio
MARKERSIZE = 300 * size_ratio
LINWID = 5
DOTS = 25 * size_ratio
LEGSIZE = 40 * size_ratio

# %% [markdown]
# # Getting average firing rate from all sessions

# %%
all_neuron_to_bin_firing_rate_path = glob.glob("./**/proc/*neuron_to_bin_firing_rate_df.csv", recursive=True)

# %%
all_neuron_to_bin_firing_rate_path
# Out:
# ['./subject_6_3/20221215/proc/20221215_145401_comp_amd_om_6_3_top_1_base_2_vs_6_3_neuron_to_bin_firing_rate_df.csv',
#  './subject_6_3/20221214/proc/20221214_125409_om_and_comp_6_3_top_4_base_3_vs_6_1_neuron_to_bin_firing_rate_df.csv',
#  './subject_6_1/20221215/proc/20221215_145401_comp_amd_om_6_1_top_4_base_3_neuron_to_bin_firing_rate_df.csv',
#  './subject_6_1/20221214/proc/20221214_125409_om_and_comp_6_1_top_1_base_2_vs_6_3_neuron_to_bin_firing_rate_df.csv']

# %%
all_neuron_to_bin_firing_rate_df = [pd.read_csv(path, index_col=0) for path in all_neuron_to_bin_firing_rate_path]

# %%
all_neuron_to_bin_firing_rate_df[0].columns.difference(all_neuron_to_bin_firing_rate_df[1].columns)
# Out:
# Index(['-10.0 loss', '-10.0 omission', '-10.0 rewarded', '-10.0 win'], dtype='object')

# %%
pivoted_averaged_firing_rate_df = pd.concat(all_neuron_to_bin_firing_rate_df).reset_index(drop=True)
pivoted_averaged_firing_rate_df = pivoted_averaged_firing_rate_df.fillna(value=0)

# %% [raw]
# pivoted_averaged_firing_rate_df = pivoted_averaged_firing_rate_df[pivoted_averaged_firing_rate_df["recording_date"] == 20221214].copy()

# %% [raw]
# pivoted_averaged_firing_rate_df = pivoted_averaged_firing_rate_df[pivoted_averaged_firing_rate_df["subject_id"] == 6.3].copy()

# %% [markdown]
# - So that we can avoid using the subject id and recording date

# %%
dropped_pivoted_averaged_firing_rate_df = pivoted_averaged_firing_rate_df.drop(columns=["subject_id", "recording_date"])

# %% [markdown]
# - Turning the dataframe into an array to be usable

# %%
resetted_averaged_firing_rate_array = dropped_pivoted_averaged_firing_rate_df.values

# %%
resetted_averaged_firing_rate_array[:5]
# Out:
# array([[0.33333333, 0.        , 0.5       , ..., 0.33333333, 0.        ,
#         0.        ],
#        [0.11111111, 0.        , 0.        , ..., 0.        , 0.2       ,
#         0.        ],
#        [0.5       , 0.5       , 0.16666667, ..., 0.        , 0.3       ,
#         1.        ],
#        [0.11111111, 0.        , 0.        , ..., 0.33333333, 0.        ,
#         0.        ],
#        [2.33333333, 0.        , 2.33333333, ..., 1.66666667, 1.2       ,
#         1.        ]])

# %% [markdown]
# # PCA with Neuron Rows

# %% [markdown]
# ## Standarizing the Data

# %%
from sklearn.preprocessing import StandardScaler

# %%
dropped_pivoted_averaged_firing_rate_df.head()
# Out:
#    -0.1 loss  -0.1 omission  -0.1 rewarded  -0.1 win  -0.2 loss  \
# 0   0.333333            0.0       0.500000       0.0   0.111111
# 1   0.111111            0.0       0.000000       0.0   0.222222
# 2   0.500000            0.5       0.166667       0.0   0.166667
# 3   0.111111            0.0       0.000000       0.0   0.111111
# 4   2.333333            0.0       2.333333       0.0   2.777778
#
#    -0.2 omission  -0.2 rewarded  -0.2 win  -0.3 loss  -0.3 omission  ...  \
# 0            0.0            0.5       1.0   0.111111            0.0  ...
# 1            0.0            0.1       0.0   0.111111            0.0  ...
# 2            1.0            0.2       0.0   0.166667            0.0  ...
# 3            0.0            0.0       0.0   0.277778            0.0  ...
# 4            0.0            1.7       3.0   2.111111            0.5  ...
#
#    9.7 rewarded  9.7 win  9.8 loss  9.8 omission  9.8 rewarded  9.8 win  \
# 0         0.000      0.0  0.333333      0.666667         0.000      0.0
# 1         0.000      0.0  0.222222      0.000000         0.125      0.0
# 2         0.125      0.0  0.277778      0.666667         0.000      0.0
# 3         0.125      0.0  0.166667      0.000000         0.250      0.0
# 4         0.750      0.0  2.166667      1.333333         1.250      0.0
#
#    9.9 loss  9.9 omission  9.9 rewarded  9.9 win
# 0  0.222222      0.333333           0.0      0.0
# 1  0.166667      0.000000           0.2      0.0
# 2  0.388889      0.000000           0.3      1.0
# 3  0.111111      0.333333           0.0      0.0
# 4  2.166667      1.666667           1.2      1.0
#
# [5 rows x 804 columns]

# %%
# Separating out the features
x = resetted_averaged_firing_rate_array#.loc[:].values# Separating out the target
resetted_averaged_firing_rate_array = StandardScaler().fit_transform(x)

# %% [markdown]
# ## Calculating the PCA

# %%
from sklearn.decomposition import PCA

# %% [markdown]
# - Getting the PC Coeffecients

# %%
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(resetted_averaged_firing_rate_array)
principal_df = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])

# %%
principal_df.head()
# Out:
#    principal component 1  principal component 2
# 0              -0.280335               3.085513
# 1             -14.507755               0.987161
# 2             -10.049556               2.692326
# 3             -13.029887               2.689439
# 4              70.277435              42.085447

# %%
principal_df["principal component 1"]
# Out:
# 0     -0.280335
# 1    -14.507755
# 2    -10.049556
# 3    -13.029887
# 4     70.277435
# 5     35.222285
# 6    -14.677817
# 7    -15.365743
# 8      0.526449
# 9     14.324340
# 10   -15.951731
# 11    -8.009427
# 12    -9.980231
# 13     3.428650
# 14   -14.797695
# 15   -13.343695
# 16   -15.066702
# 17   -14.315441
# 18   -13.594064
# 19   -14.359608
# 20   -16.705518
# 21   -11.011112
# 22    60.146924
# 23    -3.125694
# 24    -3.249454
# 25    44.392903
# 26    64.666742
# 27   -14.173763
# 28    -7.938127
# 29    -7.094384
# 30   -11.955694
# 31   -12.761481
# 32     1.221441
# 33     5.631732
# 34     9.451017
# 35     3.468066
# 36    -0.786817
# 37    -4.534725
# 38   -13.677180
# 39   -13.460025
# 40   -13.290462
# 41   -13.224656
# 42   -13.512354
# 43   -14.887714
# 44   -12.898908
# 45    24.279487
# 46    11.489608
# 47   -11.916403
# 48   -10.654001
# 49    18.435594
# 50    -5.870167
# 51    -4.697706
# 52   -13.104982
# 53    -7.728903
# 54    62.456969
# 55   -15.557824
# 56    30.187767
# 57   -14.459668
# Name: principal component 1, dtype: float64

# %%
pc1_product = dropped_pivoted_averaged_firing_rate_df.reset_index(drop=True).multiply(principal_df["principal component 1"], axis="index")

# %%
pc1_product
# Out:
#      -0.1 loss  -0.1 omission  -0.1 rewarded    -0.1 win   -0.2 loss  \
# 0    -0.093445      -0.000000      -0.140167   -0.000000   -0.031148
# 1    -1.611973      -0.000000      -0.000000   -0.000000   -3.223946
# 2    -5.024778      -5.024778      -1.674926   -0.000000   -1.674926
# 3    -1.447765      -0.000000      -0.000000   -0.000000   -1.447765
# 4   163.980682       0.000000     163.980682    0.000000  195.215098
# 5    46.963047      17.611143      23.481523   35.222285   52.833428
# 6    -4.077171      -0.000000      -0.000000   -0.000000   -0.815434
# 7    -1.707305      -0.000000      -0.000000   -0.000000   -0.853652
# 8     0.175483       0.000000       0.131612    0.150414    0.263225
# 9     4.774780       0.000000       7.162170   12.278006   14.324340
# 10   -0.000000      -0.000000      -0.000000   -0.000000   -0.000000
# 11   -2.669809      -8.009427      -0.000000   -0.000000   -2.002357
# 12   -0.000000      -0.000000      -0.000000   -4.277242   -0.000000
# 13    2.857208       3.428650       1.714325    0.489807    0.857162
# 14   -1.233141      -0.000000      -1.849712   -2.113956   -0.000000
# 15   -0.000000      -0.000000      -0.000000   -0.000000   -1.667962
# 16   -1.255559      -0.000000      -1.883338   -0.000000   -0.000000
# 17   -1.192953      -0.000000      -3.578860   -0.000000   -0.000000
# 18   -0.000000      -0.000000      -0.000000   -3.884018   -0.000000
# 19   -1.196634      -0.000000      -0.000000   -0.000000   -3.589902
# 20   -0.000000      -0.000000      -0.000000   -0.000000   -0.000000
# 21   -0.000000      -0.000000      -1.001010   -1.835185  -11.011112
# 22    0.000000      20.048975      60.146924   66.829916  240.587696
# 23   -0.000000      -2.083796      -0.568308   -0.347299   -0.000000
# 24   -0.000000      -2.166303      -0.886215   -0.361050   -0.000000
# 25   88.785807      29.595269      40.357185   41.926631    0.000000
# 26   64.666742      21.555581     135.212278  129.333483   64.666742
# 27   -0.000000      -0.000000      -1.288524   -0.000000   -0.000000
# 28   -0.000000      -0.000000      -0.000000   -0.000000   -0.000000
# 29   -0.000000      -4.729589      -3.224720   -0.788265   -0.000000
# 30  -11.955694      -0.000000      -1.086881   -1.328410   -0.000000
# 31   -0.000000      -0.000000      -3.480404   -0.708971   -0.000000
# 32    0.000000       0.814294       0.666241    0.407147    0.000000
# 33    0.000000       7.508976       3.071854    2.502992   22.526928
# 34    9.451017       3.150339       3.436733    5.250565    9.451017
# 35    0.000000       0.000000       1.576394    2.119374    0.000000
# 36   -0.786817      -0.000000      -0.000000   -0.393408   -0.000000
# 37   -0.000000      -4.534725      -0.412248   -0.503858   -0.000000
# 38   -0.000000      -4.559060      -0.000000   -0.000000   -0.000000
# 39   -0.000000      -0.000000      -1.223639   -1.495558   -0.000000
# 40  -13.290462      -0.000000      -2.416448   -1.476718   -0.000000
# 41   -0.000000      -4.408219      -1.202241   -1.469406   -0.000000
# 42  -13.512354      -0.000000      -1.228396   -1.501373   -0.000000
# 43   -0.000000      -0.000000      -1.353429   -0.827095   -0.000000
# 44   -3.685402      -0.000000      -0.000000   -0.000000   -3.685402
# 45    3.468498       0.000000      19.865035    4.046581    0.000000
# 46    0.000000       3.829869       5.222549    7.659738    3.282745
# 47   -1.702343      -0.000000      -0.000000   -2.979101   -1.702343
# 48   -0.000000      -3.551334      -0.000000   -3.551334   -3.044000
# 49   15.801938      18.435594      18.435594   18.435594   23.702907
# 50   -0.838595      -0.000000      -0.000000   -0.978361   -0.000000
# 51   -2.013303      -0.000000      -1.708257   -1.565902   -1.342202
# 52   -0.000000      -4.368327      -1.191362   -0.000000   -3.744281
# 53   -0.000000      -2.576301      -5.621020   -1.288150   -0.000000
# 54   71.379393      41.637979      90.846501   93.685454   80.301818
# 55   -2.222546      -0.000000      -0.000000   -0.000000   -0.000000
# 56   34.500305      20.125178      30.187767   12.578236   34.500305
# 57   -0.000000      -0.000000      -0.000000   -0.000000   -0.000000
#
#     -0.2 omission  -0.2 rewarded    -0.2 win   -0.3 loss  -0.3 omission  ...  \
# 0       -0.000000      -0.140167   -0.280335   -0.031148      -0.000000  ...
# 1       -0.000000      -1.450776   -0.000000   -1.611973      -0.000000  ...
# 2      -10.049556      -2.009911   -0.000000   -1.674926      -0.000000  ...
# 3       -0.000000      -0.000000   -0.000000   -3.619413      -0.000000  ...
# 4        0.000000     119.471640  210.832306  148.363474      35.138718  ...
# 5        0.000000      31.700057   35.222285   70.444570      35.222285  ...
# 6       -0.000000      -0.000000  -14.677817   -0.000000      -0.000000  ...
# 7       -0.000000      -1.536574   -0.000000   -0.853652      -0.000000  ...
# 8        0.000000       0.000000    0.105290    0.307095       0.000000  ...
# 9        0.000000       2.864868   11.459472    4.774780       7.162170  ...
# 10      -0.000000      -0.000000   -0.000000   -0.000000      -0.000000  ...
# 11      -0.000000      -1.601885   -1.601885   -2.669809      -4.004714  ...
# 12      -0.000000      -0.000000   -0.000000   -0.831686      -0.000000  ...
# 13       0.000000       0.685730    0.685730    2.000046       0.000000  ...
# 14      -0.000000      -0.000000   -5.919078   -1.233141      -0.000000  ...
# 15      -6.671847      -0.000000   -0.000000   -2.223949      -6.671847  ...
# 16      -0.000000      -0.000000   -0.000000   -0.000000      -0.000000  ...
# 17      -7.157721      -2.863088   -0.000000   -0.000000      -0.000000  ...
# 18      -0.000000      -2.718813   -2.718813   -0.000000      -0.000000  ...
# 19      -0.000000      -0.000000   -0.000000   -3.589902      -0.000000  ...
# 20      -0.000000      -0.000000   -0.000000   -0.000000      -0.000000  ...
# 21      -3.670371      -0.000000   -2.446914   -0.000000      -0.000000  ...
# 22     100.244873      65.614826   93.561882  120.293848      80.195899  ...
# 23      -0.000000      -0.284154   -0.173650   -0.000000      -3.125694  ...
# 24      -2.166303      -0.886215   -0.541576   -3.249454      -1.083151  ...
# 25      14.797634      60.535777   32.061541    0.000000       0.000000  ...
# 26     129.333483      76.424331  118.555693   64.666742     107.777903  ...
# 27      -0.000000      -1.288524   -0.787431   -0.000000      -0.000000  ...
# 28      -0.000000      -0.721648   -2.205035   -0.000000      -0.000000  ...
# 29      -2.364795      -2.579776   -3.547192   -0.000000      -2.364795  ...
# 30      -0.000000      -2.173763   -1.992616   -0.000000      -0.000000  ...
# 31      -0.000000      -1.160135   -3.544856   -0.000000      -0.000000  ...
# 32       0.814294       0.888321    0.203574    0.000000       1.221441  ...
# 33       1.877244       2.559878    2.502992   11.263464       1.877244  ...
# 34       6.300678       6.873467    4.725508    9.451017       0.000000  ...
# 35       0.000000       1.891673    2.312044    0.000000       0.000000  ...
# 36      -0.262272      -0.429173   -0.524544   -0.000000      -0.000000  ...
# 37      -1.511575      -1.236743   -1.259646   -0.000000      -1.511575  ...
# 38      -0.000000      -0.000000   -1.519687   -0.000000      -4.559060  ...
# 39      -0.000000      -0.000000   -1.495558   -0.000000      -0.000000  ...
# 40      -0.000000      -1.208224   -2.953436   -0.000000      -4.430154  ...
# 41      -0.000000      -1.202241   -1.469406   -0.000000      -0.000000  ...
# 42      -0.000000      -0.000000   -0.750686   -0.000000      -0.000000  ...
# 43      -0.000000      -1.353429   -0.827095   -0.000000      -4.962571  ...
# 44      -0.000000      -0.000000   -0.000000   -3.685402      -0.000000  ...
# 45       8.093162      13.243357   16.186325   10.405494       0.000000  ...
# 46       3.829869       5.222549   12.447075    0.000000       3.829869  ...
# 47      -3.972134      -0.000000   -1.986067   -0.000000      -3.972134  ...
# 48      -0.000000      -0.000000   -0.887833   -3.044000      -0.000000  ...
# 49      12.290396      15.083668    9.217797   15.801938       6.145198  ...
# 50      -0.000000      -1.067303   -0.000000   -0.000000      -0.000000  ...
# 51      -3.131804      -0.854128   -0.782951   -1.342202      -1.565902  ...
# 52      -0.000000      -0.000000   -3.276245   -0.000000      -0.000000  ...
# 53      -0.000000      -4.918393   -3.220376   -0.000000      -0.000000  ...
# 54      62.456969     119.236032  119.709191   62.456969       0.000000  ...
# 55      -0.000000      -2.828695   -0.000000   -0.000000      -5.185941  ...
# 56      30.187767      32.932109   27.672119   51.750457      30.187767  ...
# 57      -0.000000      -0.000000   -0.000000   -2.065667      -0.000000  ...
#
#     9.7 rewarded     9.7 win    9.8 loss  9.8 omission  9.8 rewarded  \
# 0      -0.000000   -0.000000   -0.093445     -0.186890     -0.000000
# 1      -0.000000   -0.000000   -3.223946     -0.000000     -1.813469
# 2      -1.256195   -0.000000   -2.791543     -6.699704     -0.000000
# 3      -1.628736   -0.000000   -2.171648     -0.000000     -3.257472
# 4      52.708076    0.000000  152.267776     93.703247     87.846794
# 5      35.222285    0.000000   45.006253     46.963047      4.402786
# 6      -0.000000   -0.000000   -0.815434     -9.785211     -0.000000
# 7      -0.000000   -0.000000   -2.560957     -0.000000     -1.920718
# 8       0.105290    0.000000    0.467955      0.000000      0.131612
# 9       8.594604   14.324340    1.591593     14.324340      7.162170
# 10     -3.190346   -0.000000   -1.772415     -0.000000     -0.000000
# 11     -3.203771   -1.601885   -1.779873     -0.000000     -0.000000
# 12     -0.000000   -1.996046   -3.326744     -0.000000     -0.000000
# 13      0.685730    1.371460    3.047689      0.000000      1.714325
# 14     -0.000000   -0.000000   -1.644188     -0.000000     -3.699424
# 15     -0.000000   -0.000000   -4.447898     -0.000000     -0.000000
# 16     -3.013340   -0.000000   -0.000000     -0.000000     -0.000000
# 17     -0.000000   -0.000000   -1.590605     -0.000000     -3.578860
# 18     -0.000000   -2.718813   -3.020903     -0.000000     -0.000000
# 19     -0.000000   -0.000000   -1.595512     -0.000000     -0.000000
# 20     -0.000000   -0.000000   -0.000000     -0.000000     -0.000000
# 21     -2.002020   -1.835185   -0.000000     -0.000000     -0.000000
# 22    103.890141   93.561882  120.293848     60.146924     71.082728
# 23     -1.136616   -0.868248   -3.125694     -1.041898     -0.568308
# 24     -1.477025   -0.541576   -3.249454     -0.000000     -0.886215
# 25     76.678651   91.252079    0.000000     44.392903     84.750088
# 26     64.666742   86.222322  129.333483     43.111161    123.454689
# 27     -0.000000   -0.787431   -0.000000     -0.000000     -2.577048
# 28     -0.000000   -0.000000   -0.000000     -0.000000     -0.000000
# 29     -0.000000   -0.788265   -0.000000     -0.000000     -0.000000
# 30     -2.173763   -1.992616   -0.000000     -0.000000     -1.086881
# 31     -1.160135   -0.708971   -0.000000     -0.000000     -1.160135
# 32      1.110401    0.475005    0.000000      1.221441      0.555201
# 33      3.071854    4.380236    0.000000      3.754488      2.047903
# 34      2.577550    5.250565    0.000000      3.150339      6.014283
# 35      2.522230    2.312044    0.000000      1.156022      2.522230
# 36     -0.071529   -0.568256   -0.000000     -0.262272     -0.286115
# 37     -0.824495   -1.763504   -0.000000     -0.000000     -0.412248
# 38     -1.243380   -0.759843   -0.000000     -0.000000     -1.243380
# 39     -0.000000   -1.495558   -0.000000     -0.000000     -0.000000
# 40     -0.000000   -1.476718   -0.000000     -0.000000     -2.416448
# 41     -0.000000   -0.000000   -0.000000     -0.000000     -0.000000
# 42     -1.228396   -0.750686   -0.000000     -4.504118     -1.228396
# 43     -1.353429   -1.654190   -0.000000     -0.000000     -0.000000
# 44     -1.172628   -3.224727   -0.000000     -0.000000     -2.345256
# 45     39.730070   30.349359   17.342491     16.186325     33.108391
# 46      3.133529   12.447075   13.130980      3.829869      5.222549
# 47     -1.083309   -0.993034   -3.404687     -0.000000     -2.166619
# 48     -2.905637   -2.663500   -1.522000     -3.551334     -0.968546
# 49     11.731742    7.681498   21.069250      6.145198      6.703852
# 50     -1.067303   -0.489181   -1.677191     -0.000000     -1.067303
# 51     -0.854128   -1.957378   -0.000000     -1.565902     -1.281193
# 52     -1.191362   -1.092082   -1.872140     -0.000000     -1.191362
# 53     -2.107883   -0.000000   -0.000000     -2.576301     -1.405255
# 54    107.880220  130.118686   44.612121    145.732928    119.236032
# 55     -0.000000   -0.000000   -0.000000     -5.185941     -1.414348
# 56     21.954739   30.187767   38.812843     10.062589     13.721712
# 57     -0.000000   -0.000000   -2.065667     -4.819889     -0.000000
#
#        9.8 win    9.9 loss  9.9 omission  9.9 rewarded     9.9 win
# 0    -0.000000   -0.062297     -0.093445     -0.000000   -0.000000
# 1    -0.000000   -2.417959     -0.000000     -2.901551   -0.000000
# 2    -0.000000   -3.908161     -0.000000     -3.014867  -10.049556
# 3    -0.000000   -1.447765     -4.343296     -0.000000   -0.000000
# 4     0.000000  152.267776    117.129059     84.332922   70.277435
# 5     0.000000   60.660602     23.481523     24.655600    0.000000
# 6    -0.000000   -2.446303     -0.000000     -0.000000   -0.000000
# 7    -0.000000   -1.707305     -0.000000     -0.000000   -0.000000
# 8     0.000000    0.263225      0.000000      0.000000    0.000000
# 9    14.324340    4.774780      0.000000      8.594604    3.581085
# 10   -0.000000   -1.329311     -0.000000     -0.000000   -0.000000
# 11   -2.002357   -2.669809     -0.000000     -3.203771   -0.000000
# 12   -0.000000   -2.495058     -0.000000     -0.000000   -0.000000
# 13    0.857162    2.000046      0.000000      1.371460    2.571487
# 14   -3.699424   -2.466283     -0.000000     -0.000000   -0.000000
# 15   -0.000000   -2.223949    -13.343695     -0.000000   -0.000000
# 16   -0.000000   -0.000000     -0.000000     -0.000000   -0.000000
# 17   -0.000000   -1.192953     -0.000000     -0.000000   -0.000000
# 18   -0.000000   -2.265677     -0.000000     -0.000000   -0.000000
# 19   -3.589902   -2.393268     -0.000000     -0.000000   -3.589902
# 20   -0.000000   -2.784253     -0.000000     -0.000000   -0.000000
# 21   -1.223457   -0.000000     -0.000000     -2.002020   -1.223457
# 22   90.220386  180.440772     80.195899    103.890141  110.269361
# 23   -0.694599   -3.125694     -0.000000     -0.852462   -0.694599
# 24   -1.444202   -0.000000     -1.083151     -0.886215   -1.263677
# 25   98.650896    0.000000     59.190538     80.714370   61.656810
# 26   46.703758   64.666742     86.222322     76.424331   82.629725
# 27   -0.000000   -0.000000     -0.000000     -1.288524   -0.787431
# 28   -0.882014   -0.000000     -0.000000     -0.000000   -0.882014
# 29   -0.788265   -0.000000     -0.000000     -0.000000   -1.182397
# 30   -0.664205   -0.000000     -0.000000     -0.000000   -2.656821
# 31   -2.835885   -0.000000     -0.000000     -0.000000   -2.835885
# 32    0.135716    0.000000      0.407147      0.666241    0.678579
# 33    3.128740    0.000000      1.877244      2.047903    4.380236
# 34    3.150339    0.000000      0.000000      7.732650    4.725508
# 35    1.926704    0.000000      0.000000      3.152788    3.468066
# 36   -0.699392   -0.000000     -0.000000     -0.143058   -0.699392
# 37   -0.755788   -0.000000     -0.000000     -0.824495   -1.259646
# 38   -1.519687   -0.000000     -0.000000     -2.486760   -0.000000
# 39   -2.243337   -0.000000     -0.000000     -0.000000   -0.747779
# 40   -0.738359   -0.000000     -0.000000     -2.416448   -2.215077
# 41   -2.204109   -0.000000     -0.000000     -1.202241   -0.734703
# 42   -0.000000   -0.000000     -0.000000     -1.228396   -1.501373
# 43   -2.481286   -0.000000     -0.000000     -1.353429   -0.827095
# 44   -5.374545   -0.000000     -0.000000     -0.000000   -5.374545
# 45   22.256196   20.810989     32.372649     22.072261   28.326068
# 46   10.532140    9.848235      7.659738      4.178039   15.319477
# 47   -0.993034   -5.107030     -0.000000     -2.166619   -0.993034
# 48   -0.887833   -1.522000     -0.000000     -2.905637   -0.000000
# 49   10.754097   13.168282     12.290396      8.379816    7.681498
# 50   -1.467542   -1.677191     -3.913445     -0.533652   -0.489181
# 51   -0.391476   -0.000000     -1.565902     -3.416514   -2.348853
# 52   -2.184164   -0.000000     -0.000000     -0.000000   -0.000000
# 53   -0.644075   -0.000000     -2.576301     -1.405255   -1.288150
# 54  114.504444   53.534545    104.094949     79.490688  145.732928
# 55   -0.000000   -2.222546     -0.000000     -0.000000   -0.000000
# 56   30.187767   21.562691     50.312945     49.398164   20.125178
# 57   -1.204972   -2.065667     -0.000000     -1.314515   -0.000000
#
# [58 rows x 804 columns]

# %%
pc1_product.mean()
# Out:
# -0.1 loss         7.504946
# -0.1 omission     2.443620
# -0.1 rewarded     9.801298
# -0.1 win          6.883475
# -0.2 loss        12.115120
#                    ...
# 9.8 win           6.995151
# 9.9 loss          9.249452
# 9.9 omission      9.453710
# 9.9 rewarded      8.992337
# 9.9 win           8.927222
# Length: 804, dtype: float64

# %%
pc2_product = dropped_pivoted_averaged_firing_rate_df.reset_index(drop=True).multiply(principal_df["principal component 2"], axis="index")

# %%
pc2_product.head()
# Out:
#    -0.1 loss  -0.1 omission  -0.1 rewarded  -0.1 win   -0.2 loss  \
# 0   1.028504       0.000000       1.542757       0.0    0.342835
# 1   0.109685       0.000000       0.000000       0.0    0.219369
# 2   1.346163       1.346163       0.448721       0.0    0.448721
# 3   0.298827       0.000000       0.000000       0.0    0.298827
# 4  98.199377       0.000000      98.199377       0.0  116.904020
#
#    -0.2 omission  -0.2 rewarded    -0.2 win  -0.3 loss  -0.3 omission  ...  \
# 0       0.000000       1.542757    3.085513   0.342835       0.000000  ...
# 1       0.000000       0.098716    0.000000   0.109685       0.000000  ...
# 2       2.692326       0.538465    0.000000   0.448721       0.000000  ...
# 3       0.000000       0.000000    0.000000   0.747066       0.000000  ...
# 4       0.000000      71.545260  126.256341  88.847055      21.042724  ...
#
#    9.7 rewarded  9.7 win   9.8 loss  9.8 omission  9.8 rewarded  9.8 win  \
# 0      0.000000      0.0   1.028504      2.057009      0.000000      0.0
# 1      0.000000      0.0   0.219369      0.000000      0.123395      0.0
# 2      0.336541      0.0   0.747868      1.794884      0.000000      0.0
# 3      0.336180      0.0   0.448240      0.000000      0.672360      0.0
# 4     31.564085      0.0  91.185135     56.113930     52.606809      0.0
#
#     9.9 loss  9.9 omission  9.9 rewarded    9.9 win
# 0   0.685670      1.028504      0.000000   0.000000
# 1   0.164527      0.000000      0.197432   0.000000
# 2   1.047016      0.000000      0.807698   2.692326
# 3   0.298827      0.896480      0.000000   0.000000
# 4  91.185135     70.142412     50.502537  42.085447
#
# [5 rows x 804 columns]

# %%
pc2_product.mean()
# Out:
# -0.1 loss        0.896580
# -0.1 omission   -0.221980
# -0.1 rewarded    0.524752
# -0.1 win        -1.053249
# -0.2 loss        1.574119
#                    ...
# 9.8 win         -2.192550
# 9.9 loss         1.311554
# 9.9 omission    -0.266116
# 9.9 rewarded    -0.723833
# 9.9 win         -1.477325
# Length: 804, dtype: float64

# %%
pc_product = pd.concat([pc1_product.mean(), pc2_product.mean()], axis=1)#.reset_index()

# %%
pc_product
# Out:
#                        0         1
# -0.1 loss       7.504946  0.896580
# -0.1 omission   2.443620 -0.221980
# -0.1 rewarded   9.801298  0.524752
# -0.1 win        6.883475 -1.053249
# -0.2 loss      12.115120  1.574119
# ...                  ...       ...
# 9.8 win         6.995151 -2.192550
# 9.9 loss        9.249452  1.311554
# 9.9 omission    9.453710 -0.266116
# 9.9 rewarded    8.992337 -0.723833
# 9.9 win         8.927222 -1.477325
#
# [804 rows x 2 columns]

# %%
pc_product = pc_product.reset_index()
pc_product["bin_time"] = pc_product["index"].apply(lambda x: float(x.split()[0]))
pc_product["trial_type"] = pc_product["index"].apply(lambda x: string.capwords(x.split()[1]))

# %%
pc_product.head()
# Out:
#            index          0         1  bin_time trial_type
# 0      -0.1 loss   7.504946  0.896580      -0.1       Loss
# 1  -0.1 omission   2.443620 -0.221980      -0.1   Omission
# 2  -0.1 rewarded   9.801298  0.524752      -0.1   Rewarded
# 3       -0.1 win   6.883475 -1.053249      -0.1        Win
# 4      -0.2 loss  12.115120  1.574119      -0.2       Loss

# %%
pc_product.head()
# Out:
#            index          0         1  bin_time trial_type
# 0      -0.1 loss   7.504946  0.896580      -0.1       Loss
# 1  -0.1 omission   2.443620 -0.221980      -0.1   Omission
# 2  -0.1 rewarded   9.801298  0.524752      -0.1   Rewarded
# 3       -0.1 win   6.883475 -1.053249      -0.1        Win
# 4      -0.2 loss  12.115120  1.574119      -0.2       Loss

# %% [raw]
# def get_before_during_after(x):
#     floated_x = float(x)
#     if -10 <= floated_x < -5:
#         return "-10s to 5s"
#     elif -5 <= floated_x < 0:
#         return "-5s to 0s"
#     elif 0 <= floated_x < 5:
#         return "0s to 5s"
#     elif 5 <= floated_x <= 10:
#         return "5s to 10s"
#     else:
#         return np.nan

# %%
def get_before_during_after(x):
    floated_x = float(x)
    if -10 <= floated_x < -5:
        return "-10s to 5s"
    elif -5 <= floated_x < 0:
        return "-5s to 0s"
    elif 0 <= floated_x < 4:
        return "0s to 4s"
    elif 4 <= floated_x < 5:
        return "4s to 5s"
    elif 5 <= floated_x <= 9:
        return "5s to 9s"
    elif 9 <= floated_x <= 10:
        return "9s to 10s"
    else:
        return str(np.nan)

# %%
pc_product["before_during_after"] = pc_product["bin_time"].apply(lambda x: get_before_during_after(x))

# %%
pc_product.head()
# Out:
#            index          0         1  bin_time trial_type before_during_after
# 0      -0.1 loss   7.504946  0.896580      -0.1       Loss           -5s to 0s
# 1  -0.1 omission   2.443620 -0.221980      -0.1   Omission           -5s to 0s
# 2  -0.1 rewarded   9.801298  0.524752      -0.1   Rewarded           -5s to 0s
# 3       -0.1 win   6.883475 -1.053249      -0.1        Win           -5s to 0s
# 4      -0.2 loss  12.115120  1.574119      -0.2       Loss           -5s to 0s

# %%
pc_product["outcome_and_when"] = pc_product.apply(lambda x: x["before_during_after"] + " " + x["trial_type"], axis=1)

# %%
pc_product.head()
# Out:
#            index          0         1  bin_time trial_type  \
# 0      -0.1 loss   7.504946  0.896580      -0.1       Loss
# 1  -0.1 omission   2.443620 -0.221980      -0.1   Omission
# 2  -0.1 rewarded   9.801298  0.524752      -0.1   Rewarded
# 3       -0.1 win   6.883475 -1.053249      -0.1        Win
# 4      -0.2 loss  12.115120  1.574119      -0.2       Loss
#
#   before_during_after    outcome_and_when
# 0           -5s to 0s      -5s to 0s Loss
# 1           -5s to 0s  -5s to 0s Omission
# 2           -5s to 0s  -5s to 0s Rewarded
# 3           -5s to 0s       -5s to 0s Win
# 4           -5s to 0s      -5s to 0s Loss

# %% [markdown]
# - Getting only rows from -5 to 5 seconds

# %%
pc_product = pc_product[pc_product["bin_time"] >= -5]

# %%
omission_categories = [name for name in sorted(pc_product["outcome_and_when"].unique()) if "omission" in name]
rewarded_categories = [name for name in sorted(pc_product["outcome_and_when"].unique()) if "rewarded" in name]
win_categories = [name for name in sorted(pc_product["outcome_and_when"].unique()) if "win" in name]
loss_categories = [name for name in sorted(pc_product["outcome_and_when"].unique()) if "loss" in name]

# %%
pc_product
# Out:
#              index          0         1  bin_time trial_type  \
# 0        -0.1 loss   7.504946  0.896580      -0.1       Loss
# 1    -0.1 omission   2.443620 -0.221980      -0.1   Omission
# 2    -0.1 rewarded   9.801298  0.524752      -0.1   Rewarded
# 3         -0.1 win   6.883475 -1.053249      -0.1        Win
# 4        -0.2 loss  12.115120  1.574119      -0.2       Loss
# ..             ...        ...       ...       ...        ...
# 799        9.8 win   6.995151 -2.192550       9.8        Win
# 800       9.9 loss   9.249452  1.311554       9.9       Loss
# 801   9.9 omission   9.453710 -0.266116       9.9   Omission
# 802   9.9 rewarded   8.992337 -0.723833       9.9   Rewarded
# 803        9.9 win   8.927222 -1.477325       9.9        Win
#
#     before_during_after    outcome_and_when
# 0             -5s to 0s      -5s to 0s Loss
# 1             -5s to 0s  -5s to 0s Omission
# 2             -5s to 0s  -5s to 0s Rewarded
# 3             -5s to 0s       -5s to 0s Win
# 4             -5s to 0s      -5s to 0s Loss
# ..                  ...                 ...
# 799           9s to 10s       9s to 10s Win
# 800           9s to 10s      9s to 10s Loss
# 801           9s to 10s  9s to 10s Omission
# 802           9s to 10s  9s to 10s Rewarded
# 803           9s to 10s       9s to 10s Win
#
# [604 rows x 7 columns]

# %%
omission_pc = pc_product[pc_product["trial_type"] == "omission"]

# %%
omission_pc
# Out:
# Empty DataFrame
# Columns: [index, 0, 1, bin_time, trial_type, before_during_after, outcome_and_when]
# Index: []

# %%
averaged_omission_pc = omission_pc.groupby(np.arange(len(omission_pc))//3).mean().reset_index()
# Out:
# /tmp/ipykernel_2730888/866166829.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   averaged_omission_pc = omission_pc.groupby(np.arange(len(omission_pc))//3).mean().reset_index()

# %%
averaged_omission_pc
# Out:
# Empty DataFrame
# Columns: [index, 0, 1, bin_time]
# Index: []

# %%
rewarded_pc = pc_product[pc_product["trial_type"] == "rewarded"]

# %%
averaged_rewarded_pc = rewarded_pc.groupby(np.arange(len(rewarded_pc))//3).mean().reset_index()
# Out:
# /tmp/ipykernel_2730888/1512505606.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   averaged_rewarded_pc = rewarded_pc.groupby(np.arange(len(rewarded_pc))//3).mean().reset_index()

# %%
plt.scatter(averaged_omission_pc[0], averaged_omission_pc[1], c=averaged_omission_pc["index"], cmap='Reds')
plt.scatter(averaged_rewarded_pc[0], averaged_rewarded_pc[1], c=averaged_rewarded_pc["index"], cmap='Greens')

plt.show()

# %%
all_categories = sorted(pc_product["outcome_and_when"].unique())

# %%
all_categories = [category for category in all_categories if not "-10" in category]

# %%
all_categories
# Out:
# ['-5s to 0s Loss',
#  '-5s to 0s Omission',
#  '-5s to 0s Rewarded',
#  '-5s to 0s Win',
#  '0s to 4s Loss',
#  '0s to 4s Omission',
#  '0s to 4s Rewarded',
#  '0s to 4s Win',
#  '4s to 5s Loss',
#  '4s to 5s Omission',
#  '4s to 5s Rewarded',
#  '4s to 5s Win',
#  '5s to 9s Loss',
#  '5s to 9s Omission',
#  '5s to 9s Rewarded',
#  '5s to 9s Win',
#  '9s to 10s Loss',
#  '9s to 10s Omission',
#  '9s to 10s Rewarded',
#  '9s to 10s Win']

# %% [markdown]
# win: blue
# loss: yellow
# rewarded: green
# omission: red

# %%
all_colors = ["gold", "pink", "lightgreen", "lightblue", "orange", "red", "green", "cyan", "darkorange", "darkred", "darkgreen", "darkcyan"]

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('principal component 1', fontsize = 15)
ax.set_ylabel('principal component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = rewarded_categories
colors = ["lightblue", "cyan", "darkcyan"]
for target, color in zip(all_categories, all_colors):
    indicesToKeep = pc_product['outcome_and_when'] == target
    ax.scatter(pc_product.loc[indicesToKeep, 0]
               , pc_product.loc[indicesToKeep, 1]
               , c = color
               , s = 50)
ax.legend(all_categories)
ax.grid()

# %% [markdown]
# ## Looking at each plot individually across time

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('principal component 1', fontsize = 15)
ax.set_ylabel('principal component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = omission_categories
colors = ["pink", "red", "darkred"]
for target, color in zip(targets,colors):
    indicesToKeep = pc_product['outcome_and_when'] == target
    ax.scatter(pc_product.loc[indicesToKeep, 0]
               , pc_product.loc[indicesToKeep, 1]
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('principal component 1', fontsize = 15)
ax.set_ylabel('principal component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = rewarded_categories
colors = ["lightgreen", "green", "darkgreen"]
for target, color in zip(targets,colors):
    indicesToKeep = pc_product['outcome_and_when'] == target
    ax.scatter(pc_product.loc[indicesToKeep, 0]
               , pc_product.loc[indicesToKeep, 1]
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('principal component 1', fontsize = 15)
ax.set_ylabel('principal component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = win_categories
colors = ["lightblue", "cyan", "darkcyan"]
for target, color in zip(targets,colors):
    indicesToKeep = pc_product['outcome_and_when'] == target
    ax.scatter(pc_product.loc[indicesToKeep, 0]
               , pc_product.loc[indicesToKeep, 1]
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('principal component 1', fontsize = 15)
ax.set_ylabel('principal component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = loss_categories
colors = ["gold", "orange", "darkorange"]
for target, color in zip(targets,colors):
    indicesToKeep = pc_product['outcome_and_when'] == target
    ax.scatter(pc_product.loc[indicesToKeep, 0]
               , pc_product.loc[indicesToKeep, 1]
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

# %% [markdown]
# # Comparing all trials with each time frame

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from matplotlib.colors import ListedColormap

# %%
pclabcol = ['#15616F','#FFAF00', '#792910','#001424']
#15616F: Dark Turqoise: Win
#FFAF00: Golden Yellow: Rewarded
#792910: Dark Red/Brown: Loss
#001424: Black Omitted

# %%
fig, ax = plt.subplots(figsize = (6,6))

targets = ['-5s to 0s omission', '-5s to 0s rewarded', '-5s to 0s loss', '-5s to 0s win']
colors = ["#001424", "#FFAF00", "#792910", "#15616F"]
for target, color in zip(targets,colors):
    indicesToKeep = pc_product['outcome_and_when'] == target
    ax.scatter(pc_product.loc[indicesToKeep, 0]
               , pc_product.loc[indicesToKeep, 1]
               , c = color
               , s = 50)
    
ax.set_title('Major overlap with all\ntrial types at baseline', fontsize = TITLESIZE)
plt.xticks(fontsize=AXESTICKS)
plt.yticks(fontsize=AXESTICKS)
plt.xlabel('Principal Component 1', fontsize = AXESLABEL)
plt.ylabel('Principal Component 2', fontsize = AXESLABEL)
plt.xlim((3, 15))
plt.ylim((-3, 4))

plt.legend(targets, fontsize=LEGSIZE, loc='upper center', bbox_to_anchor=(0.5, 0.975),
          ncol=2, fancybox=True, shadow=True)
plt.tight_layout()
ax.grid()

plt.savefig("./proc/plots/all_trials_-5s_0s.png", bbox_inches='tight')
plt.savefig("./proc/plots/all_trials_-5s_0s.svg", bbox_inches='tight')
# Out:
# /tmp/ipykernel_2730888/179461515.py:22: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize = (8,8))

targets = ['0s to 5s omission', '0s to 5s rewarded', '0s to 5s loss', '0s to 5s win']
colors = ["#001424", "#FFAF00", "#792910", "#15616F"]
for target, color in zip(targets,colors):
    indicesToKeep = pc_product['outcome_and_when'] == target
    ax.scatter(pc_product.loc[indicesToKeep, 0]
               , pc_product.loc[indicesToKeep, 1]
               , c = color
               , s = 50)
    
ax.set_title('Decreasing overlap after\nreward tone plays', fontsize = TITLESIZE)
plt.xticks(fontsize=AXESTICKS)
plt.yticks(fontsize=AXESTICKS)
plt.xlabel('Principal Component 1', fontsize = AXESLABEL)
plt.ylabel('Principal Component 2', fontsize = AXESLABEL)
plt.xlim((3, 15))
plt.ylim((-3, 4))

plt.legend(targets, fontsize=LEGSIZE, loc='upper center', bbox_to_anchor=(0.5, 0.975),
          ncol=2, fancybox=True, shadow=True)
plt.tight_layout()
ax.grid()

plt.savefig("./proc/plots/all_trials_0s_5s.png", bbox_inches='tight')
plt.savefig("./proc/plots/all_trials_0s_5s.svg", bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize = (8,8))

targets = ['5s to 10s omission', '5s to 10s rewarded', '5s to 10s loss', '5s to 10s win']
colors = ["#001424", "#FFAF00", "#792910", "#15616F"]
for target, color in zip(targets,colors):
    indicesToKeep = pc_product['outcome_and_when'] == target
    ax.scatter(pc_product.loc[indicesToKeep, 0]
               , pc_product.loc[indicesToKeep, 1]
               , c = color
               , s = 50)
    
ax.set_title('Further separation after time of\nexpected reward delivery', fontsize = TITLESIZE)
plt.xticks(fontsize=AXESTICKS)
plt.yticks(fontsize=AXESTICKS)
plt.xlabel('Principal Component 1', fontsize = AXESLABEL)
plt.ylabel('Principal Component 2', fontsize = AXESLABEL)
plt.xlim((3, 15))
plt.ylim((-3, 4))

plt.legend(targets, fontsize=LEGSIZE, loc='upper center', bbox_to_anchor=(0.5, 0.975),
          ncol=2, fancybox=True, shadow=True)
plt.tight_layout()
ax.grid()

plt.savefig("./proc/plots/all_trials_5s_10s.png", bbox_inches='tight')
plt.savefig("./proc/plots/all_trials_5s_10s.svg", bbox_inches='tight')

# %% [markdown]
# # Comparing Omission/Losing and Rewarded/Winning

# %%
pclabcol = ['#15616F','#FFAF00', '#792910','#001424']
#15616F: Dark Turqoise: Win
#FFAF00: Golden Yellow: Rewarded
#792910: Dark Red/Brown: Loss
#001424: Black Omitted

# %%
mylabels = ['-4s to 0s Omission', '-4s to 0s Loss', '1s to 5s Omission', '1s to 5s Loss']

# %%
plt.rcParams["figure.figsize"] = (10 * size_ratio, 10 * size_ratio)
fig, ax = plt.subplots()

targets = ['0s to 4s Omission', '0s to 4s Loss', '5s to 9s Omission', '5s to 9s Loss']
colors = ["#4e5865", "#ac6d58", "#001424", "#792910"]
shapes = ["x", "x", "o", "o"]
for target, color, marker in zip(targets,colors, shapes):
    indicesToKeep = pc_product['outcome_and_when'] == target
    ax.scatter(pc_product.loc[indicesToKeep, 0]
               , pc_product.loc[indicesToKeep, 1]
               , s = MARKERSIZE
               , c = color
              , marker=marker,
               linewidths=LINWID)
    
# ax.set_title('Separation with\nomission and loss\nwith no shift over time', fontsize = TITLESIZE)
plt.xticks(fontsize=AXESTICKS)
plt.yticks(fontsize=AXESTICKS)
plt.xlabel('PC 1', fontsize = AXESLABEL)
plt.ylabel('PC 2', fontsize = AXESLABEL)
plt.xlim((3, 15))
plt.ylim((-3, 4))

plt.legend(labels=mylabels, fontsize=LEGSIZE, loc='upper center',
          ncol=1, fancybox=True, shadow=True, columnspacing=0.0, bbox_to_anchor=(1.45, 0.75))

ax.grid()

plt.savefig("./proc/plots/om_and_loss_trials_baseline_and_after_tone.png", bbox_inches='tight')
plt.savefig("./proc/plots/om_and_loss_trials_baseline_and_after_tone.svg", bbox_inches='tight')

# %%
mylabels = ['-4s to 0s Rewarded', '-4s to 0s Win', '1s to 5s Rewarded', '1s to 5s Win']

# %%
plt.rcParams["figure.figsize"] = (10 * size_ratio, 10 * size_ratio)

fig, ax = plt.subplots()

targets = ['0s to 4s Rewarded', '0s to 4s Win', '5s to 9s Rewarded', '5s to 9s Win']
colors = ["#ffc96d", "#6b939d", "#FFAF00", "#15616F"]
shapes = ["x", "x", "o", "o"]
for target, color, marker in zip(targets,colors, shapes):
    indicesToKeep = pc_product['outcome_and_when'] == target
    ax.scatter(pc_product.loc[indicesToKeep, 0]
               , pc_product.loc[indicesToKeep, 1]
               , s = MARKERSIZE
               , c = color
              , marker=marker,
               linewidths=LINWID)
    
# ax.set_title('Overlap between\nwin and reward\nwith shift over time', fontsize = TITLESIZE)
# ax.set_title('Win and reward\nexpectation overlap with\na shift over time', fontsize = TITLESIZE)

plt.xticks(fontsize=AXESTICKS)
plt.yticks(fontsize=AXESTICKS)
plt.xlabel('PC 1', fontsize = AXESLABEL)
plt.ylabel('PC 2', fontsize = AXESLABEL)
plt.xlim((3, 15))
plt.ylim((-3, 4))

plt.legend(labels=mylabels, fontsize=LEGSIZE, loc='upper center',
          ncol=1, fancybox=True, shadow=True, columnspacing=0.0, bbox_to_anchor=(1.45, 0.75))
# plt.tight_layout()
ax.grid()

plt.savefig("./proc/plots/reward_and_win_trials_baseline_and_after_tone.png", bbox_inches='tight')
plt.savefig("./proc/plots/reward_and_win_trials_baseline_and_after_tone.svg", bbox_inches='tight')

# %%
"
    elif 4 <= floated_x < 5:
        return "4s to 5s"
    elif 5 <= floated_x <= 9:
        return "5s to 9s
# Out:
#   Cell In[73], line 1
#     "
#      ^
# SyntaxError: EOL while scanning string literal
